# %%
import os
import re

# %%
Rawpath = "../../lib/"
whatsappName = input("Whatsapp User id: ")

## Reading data
data = ""
inputPath = Rawpath
for file in os.listdir(inputPath):
    if file != 'Output':
        filePath = os.path.join(inputPath, file)
        with open(filePath, encoding = "utf8") as f:
            temp = f.read()
        data += " " + temp
# Out:
# Whatsapp User id: Subhasish Basak

# %%
inputPath
# Out:
# '../../lib/'

# %%
data
# Out:
# ' 24/03/20, 10:06 pm - Messages to this chat and calls are now secured with end-to-end encryption. Tap for more info.\n24/03/20, 10:06 pm - Subhasish Basak: I will disturb\n24/03/20, 10:07 pm - Trisha Dey: Permission granted XD\n24/03/20, 10:08 pm - Trisha Dey: Assignment kotdur?\n24/03/20, 10:09 pm - Subhasish Basak: Sobe toh shuru korlam\n24/03/20, 10:09 pm - Subhasish Basak: 5 April deadline jodio...onk tym acche\n24/03/20, 10:10 pm - Trisha Dey: Amar laptop e beshi kaaj korle matha dhore jae. Tora kikore korish 😓\n24/03/20, 10:11 pm - Subhasish Basak: <Media omitted>\n24/03/20, 10:16 pm - Trisha Dey: Scotch opomaanito holo.\n24/03/20, 10:22 pm - Subhasish Basak: Seriously\n24/03/20, 10:22 pm - Subhasish Basak: Seriously\n24/03/20, 10:22 pm - Subhasish Basak: Seri\n24/03/20, 10:22 pm - Subhasish Basak: Same kotha ta ami aritra k bolechilam...\n24/03/20, 10:22 pm - Subhasish Basak: Exactly the same words\n24/03/20, 10:23 pm - Subhasish Basak: 🙏🏻🙏🏻🙏🏻🙏🏻\n24/03/20, 10:23 pm - Subhasish Basak: Tomay pronam\n24/03/20, 10:23 pm - Subhasish Basak: 🙏🏻🙏🏻🙏🏻🙏🏻\n24/03/20, 10:23 pm - Trisha Dey: 🤣🤣🤣\n24/03/20, 10:23 pm - Trisha Dey: Arey ki birokto laagche\n24/03/20, 10:23 pm - Trisha Dey: R stock tulteo parbona\n24/03/20, 10:25 pm - Subhasish Basak: Ki jataah\n24/03/20, 10:26 pm - Subhasish Basak: Thug lyf hoye gelo😢\n24/03/20, 11:01 pm - Trisha Dey: 😭\n27/03/20, 8:13 pm - Subhasish Basak: Aaj kal khub busy monne hocche\U0001f9d0...online dekha jay na aapna k\n27/03/20, 8:14 pm - Subhasish Basak: Ki korre busy thaka jay...amader oo bol ektu\n27/03/20, 8:18 pm - Trisha Dey: Ghumiye ghumiye 🤣🤣\nDine 14 hours ghumocchi!!\n27/03/20, 8:19 pm - Trisha Dey: Tor assignment kotdur?\n27/03/20, 8:20 pm - Subhasish Basak: Assignment kotha theke chole elo abar😒\n27/03/20, 8:20 pm - Subhasish Basak: Assignment jali ..\n27/03/20, 8:21 pm - Trisha Dey: 🤣🤣\n27/03/20, 8:21 pm - Subhasish Basak: Amar toh raat eeo ghum aaseena😥...ki obostha... corona rr bazar ee insomnia hoye gelo mone hoy\n27/03/20, 8:21 pm - Trisha Dey: Tai naaki?\n27/03/20, 8:22 pm - Trisha Dey: E to amaro same obostha\n27/03/20, 8:22 pm - Subhasish Basak: Cmi tey thakte khub kom ghumatam\n27/03/20, 8:22 pm - Trisha Dey: Ami just bari theke berote chai\n27/03/20, 8:22 pm - Subhasish Basak: Tar ee effect hoyto\n27/03/20, 8:22 pm - Subhasish Basak: Sobai chai\n27/03/20, 8:22 pm - Trisha Dey: Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.\n27/03/20, 8:23 pm - Trisha Dey: Amar ghumiye ghumiye matha dhore jacche\n27/03/20, 8:23 pm - Trisha Dey: 😓\n27/03/20, 8:23 pm - Subhasish Basak: Ekhon kothaye tora ??\n27/03/20, 8:23 pm - Subhasish Basak: Mamar bari tei ?\n27/03/20, 8:23 pm - Trisha Dey: Na na. Barite.\n27/03/20, 8:23 pm - Trisha Dey: Mamarbari jete dicchena 😭\n27/03/20, 8:24 pm - Subhasish Basak: Kno mamar bari keno jabi ??\n27/03/20, 8:24 pm - Subhasish Basak: K acche ??\n27/03/20, 8:24 pm - Subhasish Basak: Or\n27/03/20, 8:24 pm - Subhasish Basak: Ki acche??\n27/03/20, 8:24 pm - Subhasish Basak: 🤔\n27/03/20, 8:24 pm - Trisha Dey: Kichuina. Just bari theke berote chai!!\n27/03/20, 8:24 pm - Trisha Dey: Ami pagol hoye jaabo\n27/03/20, 8:25 pm - Trisha Dey: 😭\n27/03/20, 8:25 pm - Subhasish Basak: 😆\n27/03/20, 8:25 pm - Subhasish Basak: Eto chap nis na\n27/03/20, 8:25 pm - Subhasish Basak: Aaste aaste sob habituated hoye jabo amra\n27/03/20, 8:25 pm - Subhasish Basak: Eta ekhono onk din ee cholbe ja monne hoy\n27/03/20, 8:25 pm - Trisha Dey: Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.\n27/03/20, 8:26 pm - Trisha Dey: Ami thaakte parchina r barite\n27/03/20, 8:26 pm - Subhasish Basak: Bari ta just hotel naki\U0001f92d\n27/03/20, 8:26 pm - Subhasish Basak: Papa\'s hotel\n27/03/20, 8:26 pm - Trisha Dey: Ei obostha hobe jaanle ektu booze o stock kore nitam 😭\n27/03/20, 8:26 pm - Trisha Dey: Almost 🤣🤣🤣\n27/03/20, 8:26 pm - Subhasish Basak: Babare...tui oo booze er jonno pagol hoye jacchis\n27/ ...

# %%
data = re.sub("\n[0-9]*/[0-9]*/[0-9]*, [0-9]*:[0-9]* [ap][m] - ", " #brk# ", data)
data = data.split(" #brk# ")[1:]

# %%
# <media omitted> issue addressed here

dataList = []
for line in data:
    line = line.replace("\n", " ")
    if line.split(": ")[1] == '<Media omitted>':
        dataList.append([line.split(": ")[0], 'I wish I could send an imgae for this!'])
    else:
        dataList.append(line.split(": "))

# %%
# Code for removing the text messages from the Whastapp user, from the very beginning (if exists)

index = 0
current_name = dataList[index][0]    

while current_name == whatsappName:
    index += 1
    current_name = dataList[index][0]

#print("Total number of messages deleted at the beginning : ", index)
dataList = dataList[index:]

# %%
dataList
# Out:
# [['Trisha Dey', 'Permission granted XD'],
#  ['Trisha Dey', 'Assignment kotdur?'],
#  ['Subhasish Basak', 'Sobe toh shuru korlam'],
#  ['Subhasish Basak', '5 April deadline jodio...onk tym acche'],
#  ['Trisha Dey',
#   'Amar laptop e beshi kaaj korle matha dhore jae. Tora kikore korish 😓'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Subhasish Basak', 'Seri'],
#  ['Subhasish Basak', 'Same kotha ta ami aritra k bolechilam...'],
#  ['Subhasish Basak', 'Exactly the same words'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#  ['Subhasish Basak', 'Tomay pronam'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Trisha Dey', 'Arey ki birokto laagche'],
#  ['Trisha Dey', 'R stock tulteo parbona'],
#  ['Subhasish Basak', 'Ki jataah'],
#  ['Subhasish Basak', 'Thug lyf hoye gelo😢'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak',
#   'Aaj kal khub busy monne hocche\U0001f9d0...online dekha jay na aapna k'],
#  ['Subhasish Basak', 'Ki korre busy thaka jay...amader oo bol ektu'],
#  ['Trisha Dey', 'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!'],
#  ['Trisha Dey', 'Tor assignment kotdur?'],
#  ['Subhasish Basak', 'Assignment kotha theke chole elo abar😒'],
#  ['Subhasish Basak', 'Assignment jali ..'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak',
#   'Amar toh raat eeo ghum aaseena😥...ki obostha... corona rr bazar ee insomnia hoye gelo mone hoy'],
#  ['Trisha Dey', 'Tai naaki?'],
#  ['Trisha Dey', 'E to amaro same obostha'],
#  ['Subhasish Basak', 'Cmi tey thakte khub kom ghumatam'],
#  ['Trisha Dey', 'Ami just bari theke berote chai'],
#  ['Subhasish Basak', 'Tar ee effect hoyto'],
#  ['Subhasish Basak', 'Sobai chai'],
#  ['Trisha Dey',
#   'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.'],
#  ['Trisha Dey', 'Amar ghumiye ghumiye matha dhore jacche'],
#  ['Trisha Dey', '😓'],
#  ['Subhasish Basak', 'Ekhon kothaye tora ??'],
#  ['Subhasish Basak', 'Mamar bari tei ?'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', 'Kno mamar bari keno jabi ??'],
#  ['Subhasish Basak', 'K acche ??'],
#  ['Subhasish Basak', 'Or'],
#  ['Subhasish Basak', 'Ki acche??'],
#  ['Subhasish Basak', '🤔'],
#  ['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#  ['Trisha Dey', 'Ami pagol hoye jaabo'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', '😆'],
#  ['Subhasish Basak', 'Eto chap nis na'],
#  ['Subhasish Basak', 'Aaste aaste sob habituated hoye jabo amra'],
#  ['Subhasish Basak', 'Eta ekhono onk din ee cholbe ja monne hoy'],
#  ['Trisha Dey',
#   'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.'],
#  ['Trisha Dey', 'Ami thaakte parchina r barite'],
#  ['Subhasish Basak', 'Bari ta just hotel naki\U0001f92d'],
#  ['Subhasish Basak', "Papa's hotel"],
#  ['Trisha Dey', 'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭'],
#  ['Trisha Dey', 'Almost 🤣🤣🤣'],
#  ['Subhasish Basak', 'Babare...tui oo booze er jonno pagol hoye jacchis'],
#  ['Subhasish Basak', 'Booze kintu control ee khete hobe...naholei case'],
#  ['Subhasish Basak', 'Besi booze khawa bhalo na😌'],
#  ['Trisha Dey', 'Jaani. 😓'],
#  ['Trisha Dey', 'But birokto laagche'],
#  ['Subhasish Basak', 'Tym paas kor'],
#  ['Trisha Dey', 'Ekta nip o thaakle roj ek drop kore khetam 🤣'],
#  ['Subhasish Basak', 'Any hobbies ?? Drawing movies etc!??'],
#  ['Subhasish Basak', 'Comics acche toh'],
#  ['Trisha Dey', 'I do sketch like Titir. But ajkal oitao korte lyadh laagche'],
#  ['Subhasish Basak', 'Hmm'],
#  ['Subhasish Basak', 'Cooking ???'],
#  ['Trisha Dey',
#   'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭'],
#  ['Trisha Dey', 'Sudhu chicken banate paari. 😅'],
#  ['Subhasish Basak', 'Arre dhur🙈'],
#  ['Subhasish Basak', 'Chicken banano toh 60ml peg bananor thekeo soja'],
#  ['Trisha Dey', 'Ekta sketch dekhbi?'],
#  ['Subhasish Basak', 'Lasagna ..pasta...esob bana'],
#  ['Subhasish Basak', 'Yes pls...😁'],
#  ['Trisha Dey', 'Eire. Otou shoja na!!!😶😶😶'],
#  ['Trisha Dey', 'Pasta banate pari'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak',
#   'When I say that...I mean not a single drop should fall out of the peg measure😌'],
#  ['Trisha Dey', 'Lasagna ta konodin try korini jodio'],
#  ['Subhasish Basak', '😮😮😮😮😮'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Subhasish Basak', 'U did that'],
#  ['Trisha Dey', 'Wait korchilam je kokhon eta bolbi 🤣🤣🤣'],
#  ['Trisha Dey', 'Yep 😝'],
#  ['Subhasish Basak', '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂'],
#  ['Subhasish Basak', 'Why why'],
#  ['Subhasish Basak', 'Keno'],
#  ['Trisha Dey', 'Eki? Keno, keno?'],
#  ['Subhasish Basak', 'Why wasting ur talent'],
#  ['Subhasish Basak', 'Eta over professional'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#  ['Subhasish Basak', 'Bolchi...'],
#  ['Subhasish Basak', 'Esob bolis na'],
#  ['Subhasish Basak', 'Just .. printed monne hocche'],
#  ['Subhasish Basak', 'Great job👏🏻👏🏻'],
#  ['Trisha Dey',
#   "Ek shomoy khub interest chilo art and animation niye kaaj korar. Tarpor bujhlam je oishob to shob shomoy korte parbo. And I don't want to work for someone else when it's something I love. I sketch for myself."],
#  ['Trisha Dey', 'Thanks! 😃'],
#  ['Subhasish Basak', 'Passion it is'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak',
#   'Ami onk friends der dekhechi.... drawing korte....but eta off the track chilo.... seriously'],
#  ['Subhasish Basak', 'Puro printed comics monne hocche'],
#  ['Subhasish Basak', 'Tym waste koris na... concentrate on drawing'],
#  ['Trisha Dey',
#   'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.'],
#  ['Subhasish Basak', 'Pen??'],
#  ['Subhasish Basak', 'Tar maane without any mistakes'],
#  ['Subhasish Basak', 'Eto level berei choleche'],
#  ['Trisha Dey',
#   'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Eta dekhe ekta gaan mone pore gelo..'],
#  ['Subhasish Basak',
#   'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970'],
#  ['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#  ['Subhasish Basak', 'Young ta dekhina...normal TBBT'],
#  ['Subhasish Basak', 'Tao kobe last dekhechi monne ney'],
#  ['Subhasish Basak', 'Lecture maane toh 1.5 hrs'],
#  ['Subhasish Basak', 'Eto puro ready made fast art😄'],
#  ['Trisha Dey', 'More or less'],
#  ['Trisha Dey', 'Amader 4 hours er o lecture thaake'],
#  ['Trisha Dey', '😭😭'],
#  ['Subhasish Basak', 'Ekjon ee professor ??'],
#  ['Trisha Dey', 'Abar ekjon professor ekdin 6 hours er o niyechilo.'],
#  ['Trisha Dey', 'Na. Dujon.'],
#  ['Trisha Dey', 'Eita ekjon professor.'],
#  ['Subhasish Basak', 'Salute to their devotion'],
#  ['Subhasish Basak', 'Erai paarbe Corona rr solution ber korte🤣'],
#  ['Trisha Dey', 'Amra pagol hoye jai'],
#  ['Trisha Dey', '😭'],
#  ['Trisha Dey', 'R enar under ei amar dissertation paper 🤣'],
#  ['Trisha Dey', 'Emni khubi bhalo porae. Kintu 6 hours ta newa jaena.'],
#  ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#  ['Trisha Dey',
#   'Abar amader bole je tomra majhe chaile giye cigarette coffee kheye esho.'],
#  ['Subhasish Basak', 'Class ei allow kore dik..😅'],
#  ['Trisha Dey',
#   'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.'],
#  ['Subhasish Basak', 'Tahole claass koris keno etokkhon dhore'],
#  ['Subhasish Basak', 'Bunk mar chill kor'],
#  ['Trisha Dey',
#   "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona."],
#  ['Trisha Dey', 'Baaki class gulo jokhon jokhon icche korena, korina.'],
#  ['Subhasish Basak',
#   'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...'],
#  ['Subhasish Basak', 'Kheye deye kaaj nei'],
#  ['Subhasish Basak', 'Kaatano oo jay na😒'],
#  ['Trisha Dey', 'Keno?'],
#  ['Trisha Dey', 'CMI er lokjon?'],
#  ['Subhasish Basak', 'Na na ...oder sathe kal k kotha bolchilam'],
#  ['Subhasish Basak', 'Kal k trina k bollam toke daaktey'],
#  ['Subhasish Basak', 'Byass'],
#  ['Trisha Dey', 'Na maane ototao chinishna moto lokjon?'],
#  ['Trisha Dey', 'Ami ghumocchilam tokhon XD'],
#  ['Subhasish Basak',
#   'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒'],
#  ['Trisha Dey', 'Arey ektu kotha bolei ne.'],
#  ['Subhasish Basak', 'Raat 8 pm ee ghumacchis ??'],
#  ['Trisha Dey', 'Dujoner e time pass hoe jaabe'],
#  ['Trisha Dey',
#   'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪'],
#  ['Subhasish Basak',
#   'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣'],
#  ['Subhasish Basak', '\U0001f971\U0001f971😴'],
#  ['Trisha Dey', 'Na na. Atou baaje hobena 🤣'],
#  ['Subhasish Basak',
#   'Dkh...jokhon cmi tey chilam...tokhon tokee bolchilam j 2 months por kolkatay giea amra party korbo'],
#  ['Subhasish Basak', 'Rr ekhon kolkatay acchi'],
#  ['Subhasish Basak', 'Kichu korte parchi na'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Ki obostha'],
#  ['Subhasish Basak', 'Let me guess'],
#  ['Subhasish Basak', 'Tiger caves er beach ta ??'],
#  ['Trisha Dey', 'Kostor sesh nei 2020 te 😪😪'],
#  ['Trisha Dey', 'Yes!'],
#  ['Subhasish Basak', 'Shei drive ta ami bhulbo na konodin'],
#  ['Trisha Dey', 'Puro trip e amar ei beach ta shob theke bhalo legechilo'],
#  ['Subhasish Basak', 'It was indeed'],
#  ['Subhasish Basak', 'Sob theke worst ki chilo ???'],
#  ['Trisha Dey', 'Second would be marina beach.'],
#  ['Trisha Dey', 'Third Mahabalipuram'],
#  ['Trisha Dey', 'Kovallam 🤣'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey',
#   'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.'],
#  ['Subhasish Basak', 'Hya.  ...jodio kichu chilo na'],
#  ['Subhasish Basak', 'Rr baki ??'],
#  ['Trisha Dey', 'R kon beach e gechilam?'],
#  ['Subhasish Basak', 'Not only beach'],
#  ['Subhasish Basak', 'Baki rr oo toh chilo onk kichu'],
#  ['Subhasish Basak', 'Trip ta tey'],
#  ['Trisha Dey',
#   'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#  ['Trisha Dey',
#   "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#  ['Subhasish Basak', 'I can totally relate to this'],
#  ['Subhasish Basak', "That's life my friend"],
#  ['Subhasish Basak', 'Dkh...duto option thake....'],
#  ['Subhasish Basak',
#   '1. Forget everything move on  2. Cherish your memories and create new memories'],
#  ['Trisha Dey',
#   'True. R ki kora jaabe. Aj ekhane achi kal okhane thaakbo. Eita niye kicchu korar nei. Aim is to never stop planning out more trips!'],
#  ['Subhasish Basak',
#   'Ami toh paarle lyf er each and every moment ta capture kore rakhtey chai... memories recapitulation is the best thing for me'],
#  ['Trisha Dey', 'Do you go back to them? Mane chobi gulo abar dekhish?'],
#  ['Subhasish Basak', 'Google photos ka naam suna hay ??'],
#  ['Subhasish Basak', '😌'],
#  ['Subhasish Basak',
#   'Ota amar most valuable asset....puro lyf acche ota tey amar'],
#  ['Trisha Dey', 'Yep. Akdom!'],
#  ['Trisha Dey', 'Ami atodin use e kortam na.'],
#  ['Trisha Dey',
#   'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#  ['Subhasish Basak', 'Kore fel'],
#  ['Subhasish Basak', '10 years pore dekhbi'],
#  ['Subhasish Basak',
#   'Chennai gieachilis...kichu pagol lok jon er sathe party korte'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey',
#   "Pagol to shobai. Sudhu different circumstances and variety'r 😌"],
#  ['Subhasish Basak', 'Yep'],
#  ['Subhasish Basak', '😓'],
#  ['Trisha Dey', '🤣'],
#  ['Trisha Dey', 'Ki korchish akhon?'],
#  ['Subhasish Basak', 'Talking to a friend'],
#  ['Trisha Dey', 'Accha'],
#  ['Trisha Dey', 'Kotha bole ne'],
#  ['Subhasish Basak', 'High hote iccha korche'],
#  ['Subhasish Basak', 'Any suggestions'],
#  ['Trisha Dey', 'Eire'],
#  ['Trisha Dey', 'Emni emni kikore high hobi?'],
#  ['Subhasish Basak', "That's why asking for an expert opinion"],
#  ['Subhasish Basak', 'Who else it could be'],
#  ['Subhasish Basak', 'Other than u'],
#  ['Trisha Dey', 'I am sure posto diye kichu na kichu ber kora jaabe 🤣🤣'],
#  ['Subhasish Basak', 'I want to fly in the sky like a bird 😘😗'],
#  ['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#  ['Subhasish Basak', "That's only imagination"],
#  ['Subhasish Basak', 'I want it in reality'],
#  ['Subhasish Basak', 'Just imagine... flying in the sky'],
#  ['Subhasish Basak', "Wouldn't it be fun"],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Go wherever u want'],
#  ['Subhasish Basak', 'Naaaaa'],
#  ['Subhasish Basak', 'Plz bol'],
#  ['Subhasish Basak', 'Plz'],
#  ['Subhasish Basak', 'Pz'],
#  ['Subhasish Basak', 'Plz'],
#  ['Subhasish Basak', 'Plz'],
#  ['Subhasish Basak', 'Plz'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻'],
#  ['Trisha Dey', 'Amar porer jonme pakhi hoar khub icche'],
#  ['Subhasish Basak', 'Ami ekhon ee pakhi hobo'],
#  ['Trisha Dey', 'Barite modh ache?'],
#  ['Subhasish Basak', 'Eagle 😎'],
#  ['Subhasish Basak', 'Jd acche'],
#  ['Subhasish Basak', 'Half khali'],
#  ['Trisha Dey', 'Boro game hoye jaabe to tahole?'],
#  ['Subhasish Basak', 'Tui asol kothaa bol na'],
#  ['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#  ['Subhasish Basak', 'Ektai bottle acche'],
#  ['Subhasish Basak', 'Tui bol na'],
#  ['Subhasish Basak', 'Ki korte hobe'],
#  ['Subhasish Basak', 'Aagun jalabo?'],
#  ['Trisha Dey', 'Beer ache barite?'],
#  ['Trisha Dey', 'Hyaat 🤣'],
#  ['Subhasish Basak', 'Bari eta re...bar noy🙈'],
#  ['Subhasish Basak', 'Sudhu ekta jd acche...byass'],
#  ['Subhasish Basak', 'Bol ebar'],
#  ['Trisha Dey', 'Jaani. Ektu apprehensive hocchilam 🤣'],
#  ['Subhasish Basak', '🤣🤣rr kost dis na'],
#  ['Trisha Dey',
#   'Taratari high hote gele duto peg 2 min e maar. Mere du tablespoon chini kheye ne.'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Chini ??'],
#  ['Trisha Dey', 'Tarpor dekh kotokhon uurish'],
#  ['Subhasish Basak', 'Chini???'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Trisha Dey', 'Modh kheye mishti khele faatiye nesha dae'],
#  ['Subhasish Basak', '2 peg khele toh abar jol meshate hobe jd tey'],
#  ['Trisha Dey', 'Why do you think they add so much sugar in shots?'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Okay'],
#  ['Subhasish Basak', 'Tui jokhon bole dieachis...aaj k korbo'],
#  ['Trisha Dey', 'Tahole ektai peg maar'],
#  ['Trisha Dey', 'But 30 30 kore maar'],
#  ['Subhasish Basak', 'Na ...ekta te amar toh kichu hobe na'],
#  ['Trisha Dey', 'Eishob korishna re! Aunty uncle dhorle maar khabina?'],
#  ['Subhasish Basak', 'Ghumiea porbe ektu pore...'],
#  ['Trisha Dey', 'Tao. Bujhbena?'],
#  ['Subhasish Basak', 'Tokhon ami jege uthbo🤓'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Trisha Dey', 'Eishob korishna re'],
#  ['Subhasish Basak',
#   'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche'],
#  ['Subhasish Basak', 'Kintu kinrr kora jabe'],
#  ['Subhasish Basak', 'Booze sobar opor ee'],
#  ['Trisha Dey', 'Moteo na 😒'],
#  ['Subhasish Basak', '???????????????????'],
#  ['Subhasish Basak', "U don't ask that"],
#  ['Subhasish Basak', '*say that'],
#  ['Trisha Dey', 'Booze er opor maa babar maar!!!! 😒'],
#  ['Subhasish Basak', '🙈🙈🙈'],
#  ['Trisha Dey', 'Dhere boyeshe maar khete bhalo lagbe tor?'],
#  ['Subhasish Basak', 'Maarbe naa ...etuku jani...but bishal jharbe😖'],
#  ['Trisha Dey', 'Tahole korishna'],
#  ['Subhasish Basak', 'But tui chini chara onno kichu bol na'],
#  ['Trisha Dey',
#   "I've been caught by my parents drunk. Ami jaani ki obostha hoy dhora porle 🤦🏽\u200d♀"],
#  ['Subhasish Basak', 'Sudhu Chini rr jonno eto ta risk nebo🤷🏻\u200d♂️'],
#  ['Trisha Dey', 'Barite mishti ache?'],
#  ['Subhasish Basak', 'Soan papri....laddu'],
#  ['Trisha Dey', 'Laddu will work.'],
#  ['Trisha Dey', 'Duto laddu kheye nish'],
#  ['Subhasish Basak', '🤣🤣🤣🤣'],
#  ['Subhasish Basak', 'Ki din eseche...'],
#  ['Trisha Dey', 'Also, khali pete thaakle bhalo.'],
#  ['Trisha Dey', "Kintu I'm guessing tui dinner kore felechish"],
#  ['Subhasish Basak',
#   'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣'],
#  ['Subhasish Basak', 'Hya...dinner complete'],
#  ['Trisha Dey', 'Tor kache to tao kichu ache. Amar konk stock e nei. 🤣'],
#  ['Subhasish Basak', 'Ki kore bujhli?'],
#  ['Trisha Dey', 'Then ektu raat er dike kha!'],
#  ['Trisha Dey', 'I can guess 😌'],
#  ['Subhasish Basak', 'Bari tey fix tym 9pm'],
#  ['Subhasish Basak', 'Khetey hole khao....nahole abar kal k 😅😂'],
#  ['Trisha Dey', 'Tai????? 🤣🤣🤣🤣'],
#  ['Subhasish Basak', 'Toder dinner done ??'],
#  ['Trisha Dey', 'Tor kono bhai ba bon ache?'],
#  ['Subhasish Basak', 'Cousins acche'],
#  ['Subhasish Basak', '7 jon total'],
#  ['Trisha Dey', 'Nope. Trina ghumocche! Also, eita amader shondhebela 😌'],
#  ['Trisha Dey', "We don't have dinner before 11 p.m."],
#  ['Trisha Dey', 'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!'],
#  ['Subhasish Basak', 'Amar saamne cupboard er moddhei acche'],
#  ['Subhasish Basak', 'Guard laagbe na😅'],
#  ['Trisha Dey', 'No. 7?'],
#  ['Subhasish Basak', 'Ami 3rd'],
#  ['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#  ['Subhasish Basak', '🤣🤣🤣'],
#  ['Subhasish Basak', 'Wait dara check korchi'],
#  ['Subhasish Basak', 'Eta ekjon baba k gift korechilo....porei acche....'],
#  ['Subhasish Basak', 'Duty free maal'],
#  ['Trisha Dey', 'Uncle khaena?'],
#  ['Subhasish Basak',
#   'Uncle ek somoy amar thekeo bishal passionate chilo booze niea....'],
#  ['Subhasish Basak', 'Cupboard ekta compartment ta k bar baniea chilo....'],
#  ['Trisha Dey', 'Tahole tor chaap ki??'],
#  ['Subhasish Basak', 'Ekhon seta r obostha dekhley amar ee kharap laage😓'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak',
#   'Biscuits Horlicks rr khali Scotch glass gulo rakha thake'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey', 'Eire 🤣'],
#  ['Subhasish Basak', 'Dara ami jd ta check korchi'],
#  ['Trisha Dey', 'Kor'],
#  ['Subhasish Basak', 'Arrey'],
#  ['Subhasish Basak', 'Ki luck amar'],
#  ['Subhasish Basak', 'Ki pelam dkh'],
#  ['Trisha Dey', 'Dekha'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', '🤤🤤😍😍'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Eita ki??'],
#  ['Subhasish Basak', 'Goa theke kinechilo baba......ekhon monne porlo...'],
#  ['Subhasish Basak', 'Local daru'],
#  ['Trisha Dey', 'Eire 🤣'],
#  ['Subhasish Basak', 'Eta khele toh ami aaj rocket'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', 'Kintu poblm ektai...'],
#  ['Subhasish Basak', 'Exactly'],
#  ['Subhasish Basak', 'Ki coincidence'],
#  ['Subhasish Basak', 'Etai bolte jacchilam'],
#  ['Subhasish Basak', '🙈🙈'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Trisha Dey', 'Kaju fenni ta baad de.'],
#  ['Subhasish Basak', 'Duto punch kore dbo??'],
#  ['Trisha Dey', 'Kikore korbi?'],
#  ['Trisha Dey', 'Sealed to'],
#  ['Subhasish Basak', 'Tahole toh bishmaal puro'],
#  ['Trisha Dey', 'Korle rocket er moto uthbi 🤣'],
#  ['Trisha Dey', 'Yes'],
#  ['Subhasish Basak', 'Hya...seal ta opn korlam...jol misiea dilam'],
#  ['Trisha Dey', 'Local daaru is bangla 🤣'],
#  ['Subhasish Basak', 'Alcohol ee jol meshlae chap nei toh'],
#  ['Trisha Dey', 'Uncle ki boka 😒😒'],
#  ['Subhasish Basak', 'Feni ta Goan daru'],
#  ['Subhasish Basak',
#   'Uncle er bondhu bandhob bari tey na ele uncle khabe na....'],
#  ['Subhasish Basak', 'Tao rare'],
#  ['Trisha Dey',
#   'Country liquor more or less shob jaegar eki khete hoy. Puro bish er moto. Jar jonno ami konodin khabona decide korechi.'],
#  ['Subhasish Basak', 'Rr ekhon toh beri tey keo aasbei na'],
#  ['Trisha Dey', 'But jedin dhorte parbe sedin ki hobe bhaab'],
#  ['Subhasish Basak', 'Kheyechis kono din??'],
#  ['Subhasish Basak', 'Ooh...oto k bhabe'],
#  ['Subhasish Basak', 'Tui bachiea dis ama k sedin🙏🏻'],
#  ['Trisha Dey', '😶😶'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Feni+jd+laddu+chini'],
#  ['Trisha Dey', 'Eita impossible. Nijekeo bachate parini 🤣🤣'],
#  ['Subhasish Basak', 'Ufff\U0001f92f'],
#  ['Trisha Dey', 'Chinni r laagbena.'],
#  ['Trisha Dey', 'More jaabi re.'],
#  ['Subhasish Basak', 'Raw khete hobe otai chap...smell berobe naki ??'],
#  ['Trisha Dey', 'Amader shonge r party korte parbina konodin.'],
#  ['Subhasish Basak', 'Bangla te toh smell hoy'],
#  ['Trisha Dey', 'Bhaab'],
#  ['Subhasish Basak', 'Na na'],
#  ['Subhasish Basak', 'Eta hobe na konodin'],
#  ['Trisha Dey', 'Raw khashna.'],
#  ['Trisha Dey', 'Jol mishiyei kha'],
#  ['Subhasish Basak', 'Arre uncle oo bojhe booze ki jinis😌'],
#  ['Trisha Dey', 'Tao 🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Tahole ekhon ee shuru kori naki??'],
#  ['Subhasish Basak', '😝'],
#  ['Trisha Dey', 'Na na'],
#  ['Trisha Dey', 'Akdom na'],
#  ['Subhasish Basak', 'Ami tor arr w8 korte parchi na'],
#  ['Trisha Dey', 'Pore!'],
#  ['Subhasish Basak', '🤤🤤'],
#  ['Trisha Dey', 'R ektu wait kore ja'],
#  ['Subhasish Basak', 'Koto w8 korabi'],
#  ['Subhasish Basak', '10 ta baaje'],
#  ['Trisha Dey',
#   'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣'],
#  ['Subhasish Basak', 'Jd ta ek dhok maarbo...trpor feni ta ek dhok'],
#  ['Subhasish Basak', 'Na na'],
#  ['Subhasish Basak', 'Pagol naki'],
#  ['Trisha Dey', 'Tui 11tae khash!'],
#  ['Subhasish Basak', 'Ok bolis na...'],
#  ['Subhasish Basak', 'Na na bolbe abar'],
#  ['Trisha Dey', 'Ami bolbona. Tui bolbi.'],
#  ['Trisha Dey', '😶'],
#  ['Subhasish Basak', 'Hurr'],
#  ['Trisha Dey', '😒😒'],
#  ['Trisha Dey', "We'll see"],
#  ['Subhasish Basak', 'Arrey...tui sudhu dekhtey thak...'],
#  ['Subhasish Basak', 'Amar game'],
#  ['Subhasish Basak', 'Aaj k kaju feni rr party hobe'],
#  ['Trisha Dey', '11tar agey warm up suru hobena'],
#  ['Trisha Dey', 'Deal?'],
#  ['Subhasish Basak', 'Ami idea peye gechi'],
#  ['Subhasish Basak', 'Bottle tai gayeb kore debo'],
#  ['Trisha Dey',
#   'E kirom party? Eka eka? Bhaab Aritra, Subhayan r Trina koto kosto paabe'],
#  ['Subhasish Basak', 'Bujhtei paarbe na🤣🤣'],
#  ['Trisha Dey', '😒😒'],
#  ['Trisha Dey', 'Akdom na.'],
#  ['Subhasish Basak', '😓 emotional blackmail😖😖'],
#  ['Subhasish Basak', 'Ki naa???'],
#  ['Subhasish Basak', 'Eita toh bhalo idea ??'],
#  ['Trisha Dey', 'Emotional blackmail na! Oder shotti kharap lagbe!'],
#  ['Trisha Dey', 'Akdom na!'],
#  ['Subhasish Basak', 'Tahole ki ami pakhi hotte parbo na'],
#  ['Subhasish Basak', 'Keno...??'],
#  ['Subhasish Basak', 'Full proof'],
#  ['Trisha Dey', 'Bottle gayeb korle tui du teen din e bottle sesh kore dibi'],
#  ['Subhasish Basak',
#   'Baba bhuleo geche j Orom kichu ekta chilo...just like amio bhule gechilam'],
#  ['Subhasish Basak', 'Hya ...ota toh rr oo moja😁😁🤤'],
#  ['Trisha Dey',
#   'Hoa uchit noe. Bhaab oder ekdin video call e rekhe pakhi hobi. That way orao anondo paabe'],
#  ['Trisha Dey', 'Toke idea shob diye rakhlam, implementation onno ekdin hok!'],
#  ['Subhasish Basak',
#   'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe'],
#  ['Trisha Dey', 'Tarpor to abar booze booze korbi! 🤦🏽\u200d♀'],
#  ['Trisha Dey', 'Arey shobai ghumiye porbe to!'],
#  ['Trisha Dey', 'Kal kha! Kalke video call e thaakbo shobai!'],
#  ['Subhasish Basak', 'Arre tui chap nicchis keno...chill'],
#  ['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#  ['Subhasish Basak', 'Kichu hobe na'],
#  ['Subhasish Basak', 'Chap nis na'],
#  ['Subhasish Basak', 'Chilll'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#  ['Subhasish Basak', 'Se toh hobei'],
#  ['Subhasish Basak', 'Taintoh bolchi'],
#  ['Subhasish Basak', 'Video call korbo ami'],
#  ['Subhasish Basak', 'Ok'],
#  ['Trisha Dey', 'Baakira jege thaakbe?'],
#  ['Subhasish Basak', 'Sobai jege thakbe'],
#  ['Subhasish Basak', '😁😁😁😁😁'],
#  ['Subhasish Basak', 'Wah wah'],
#  ['Subhasish Basak', 'Aaj may udega🤤'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', 'Chill'],
#  ['Subhasish Basak', 'Chill'],
#  ['Subhasish Basak', 'Just w8 & watch'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', "It's going to drop soon😆"],
#  ['Trisha Dey', 'Besh'],
#  ['Trisha Dey', 'Game suru hocche akhon?'],
#  ['Subhasish Basak', 'Still waiting for ur permission😓'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Khulbo???'],
#  ['Subhasish Basak', 'Plz??'],
#  ['Trisha Dey', '🤣'],
#  ['Trisha Dey', 'Na'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', 'Keno?????????????????'],
#  ['Subhasish Basak', 'Keno ???'],
#  ['Subhasish Basak', 'Agge bol keno????????'],
#  ['Subhasish Basak', 'Why'],
#  ['Subhasish Basak', '????'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', 'Subho kaaj ee deri keno???'],
#  ['Subhasish Basak', 'Done ami wait korchi till 10:30'],
#  ['Subhasish Basak', 'Trpor kintu ek dhok ee direct eto ta namabo'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', '🤤🤤🤤🤤'],
#  ['Trisha Dey', 'Chele pagol hoye geche'],
#  ['Subhasish Basak', 'Bhai maaro mujhe maaro'],
#  ['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#  ['Subhasish Basak', 'Dhak dhak...hocche amar'],
#  ['Subhasish Basak', 'Wai ekhon keno???'],
#  ['Subhasish Basak', 'Ei toh bolli 10:30'],
#  ['Subhasish Basak', 'Wai'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Trisha Dey', 'Bole rakh re'],
#  ['Subhasish Basak', 'Let me enjoy the moment'],
#  ['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#  ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#  ['Subhasish Basak', 'Mood aasbe emon ekta gaan bol'],
#  ['Subhasish Basak', 'Ooh peyechi'],
#  ['Subhasish Basak', 'Tor favourite song'],
#  ['Subhasish Basak', 'Ritviz'],
#  ['Trisha Dey', 'Dim the lights 😌'],
#  ['Trisha Dey', 'Arey!!!'],
#  ['Trisha Dey', 'Amar favourite party song'],
#  ['Subhasish Basak', "It's already dimmed"],
#  ['Trisha Dey', 'Let me guess. Liggi?'],
#  ['Trisha Dey', 'Naki udd gaye?'],
#  ['Subhasish Basak', 'Na na bol konta chalabo'],
#  ['Trisha Dey', 'Eita I guess'],
#  ['Trisha Dey', 'Udd gaaye 🤣🤣'],
#  ['Subhasish Basak', 'Ami toh bhablam...chalo chalei'],
#  ['Trisha Dey', 'Chala!'],
#  ['Subhasish Basak', 'Konta chalabo?? Ritviz naki dim the lights'],
#  ['Trisha Dey', 'Uurte chash tai udd gaye bollam'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Ritviz toh sune sune heziea geche'],
#  ['Subhasish Basak', 'Dim the lights ee chalai'],
#  ['Trisha Dey', 'Eita kon gaan?'],
#  ['Subhasish Basak', 'Ei toh bolli'],
#  ['Subhasish Basak', '???'],
#  ['Subhasish Basak', 'Ota ki gaan chilo na??'],
#  ['Trisha Dey', 'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣'],
#  ['Subhasish Basak', 'Seriously???'],
#  ['Subhasish Basak', '🙈🙈🙈'],
#  ['Trisha Dey', 'Eire. Tor to na kheyei obostha kharap'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Amio prothom ee tai bhablam......'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Subhasish Basak', 'Porre tui bolli eta'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Tai ami bhablam..ota seriously kono gaan'],
#  ['Trisha Dey', 'Ritviz er gaan gulo amar favourite party songs I meant!'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Ei toh...dim the lights'],
#  ['Trisha Dey', 'Eita ami jaantam e na 🤣'],
#  ['Subhasish Basak', 'Ki ????????'],
#  ['Subhasish Basak', 'Hey bhogoban🙈'],
#  ['Trisha Dey', 'Ei gaan ta exist kore jaantam na'],
#  ['Trisha Dey', 'Ki coincidence er khela hocche bhai!!!'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Chena gaan chala!'],
#  ['Subhasish Basak', 'Mood chole elo re'],
#  ['Subhasish Basak', 'Puro full mood'],
#  ['Trisha Dey', 'Elo?'],
#  ['Subhasish Basak', 'Etai chaichilam'],
#  ['Trisha Dey', 'R 4 mins'],
#  ['Subhasish Basak', 'Khaini ekhono monne acche'],
#  ['Trisha Dey', '😌'],
#  ['Subhasish Basak', 'Feelings tai toh ashol'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak', 'Moments guloi toh ashol'],
#  ['Trisha Dey', '3 mins'],
#  ['Subhasish Basak', 'Booze toh just puro process ta k fast koree...rr ki'],
#  ['Subhasish Basak', 'My eyes on the clock'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', '\U0001f9d0'],
#  ['Subhasish Basak', '😖😖😖😖'],
#  ['Subhasish Basak', '😩😩😩😫😫'],
#  ['Subhasish Basak', 'Tule nao'],
#  ['Subhasish Basak', 'Ama k tule nao'],
#  ['Trisha Dey', '1 min'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Party mood on'],
#  ['Trisha Dey', '♥'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'START!'],
#  ['Subhasish Basak', 'Timestamp 10:29'],
#  ['Subhasish Basak', "Let's start"],
#  ['Trisha Dey', '👏🏽'],
#  ['Trisha Dey', '😎'],
#  ['Trisha Dey', 'Kheli?'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Ki kopal amar'],
#  ['Subhasish Basak', 'Seal siddhi khule gelo'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak', '😂😂😂😂'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Byass rr chap nei....abar lagiea debo🤣🤣🤣🤣'],
#  ['Trisha Dey', 'Emni ektu taste kore dekh agey'],
#  ['Subhasish Basak', 'Bishal smell'],
#  ['Subhasish Basak', '\U0001f92e\U0001f92e'],
#  ['Subhasish Basak', 'Khaini ekhono'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Bish puro'],
#  ['Subhasish Basak', 'Bish'],
#  ['Subhasish Basak', 'Beche thakbo toh'],
#  ['Trisha Dey', 'Tahole khashna!!!'],
#  ['Subhasish Basak', 'Jai hok...bolechi jokhon ...khetey toh hobei'],
#  ['Trisha Dey', 'Whiskey ta kha'],
#  ['Subhasish Basak', 'Nna na a'],
#  ['Subhasish Basak', 'Na na'],
#  ['Trisha Dey', 'Akdom e na'],
#  ['Subhasish Basak', 'Aaj k etai khabo'],
#  ['Trisha Dey', '😒'],
#  ['Trisha Dey', 'Naa'],
#  ['Trisha Dey', 'Olpo kha'],
#  ['Subhasish Basak', '\U0001f92e\U0001f92e🤢'],
#  ['Subhasish Basak', 'Ki jali'],
#  ['Subhasish Basak', 'Jali rr jali'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Neshar dik theke positive naki negative?'],
#  ['Subhasish Basak', 'Puro jali\U0001f92e\U0001f92e'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Mukher bhetor ta jole gelo\U0001f92e'],
#  ['Trisha Dey', 'R khashna. Rakh ota. JD kha.'],
#  ['Subhasish Basak', 'Hmm.'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Trisha Dey', 'Mishti ta kha'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Thank u so much'],
#  ['Subhasish Basak', 'Monne koranor jonno'],
#  ['Trisha Dey', 'For what?'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Monne hocche....petrol kheye nieachi😖'],
#  ['Trisha Dey', 'Jol kha'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', '😶😶😶'],
#  ['Trisha Dey', 'R kichu khashna ajke'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Done and dusted'],
#  ['Subhasish Basak',
#   '5 mins por rr ek dhok khabo...asha korchi kaaj hoye jabe'],
#  ['Trisha Dey', 'Shera dokan er laddu to 😌'],
#  ['Trisha Dey', 'Hoye jawar kotha. Tar por aro ekta khash laddu'],
#  ['Subhasish Basak', 'Duto khelam kintu'],
#  ['Trisha Dey', 'Tahole r khashna'],
#  ['Subhasish Basak',
#   'Hobe toh botel....60moto kheyechi...tao abar...desi daru'],
#  ['Subhasish Basak', '😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁'],
#  ['Subhasish Basak', 'Ki moja'],
#  ['Trisha Dey', 'Koto boro bottle ta??'],
#  ['Subhasish Basak', 'Ki moja'],
#  ['Subhasish Basak', 'Kichu measure lekha nei'],
#  ['Subhasish Basak', 'Kintu bishmall puro'],
#  ['Subhasish Basak', 'Ki bolbo'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Issh'],
#  ['Subhasish Basak', 'Arrey lovely'],
#  ['Subhasish Basak', '😍'],
#  ['Trisha Dey', 'Koto boro bottle ta? Dekhe mone hocche pite.'],
#  ['Subhasish Basak', 'Hote parre'],
#  ['Subhasish Basak', 'Ac chalai...gorom gorom laagche kintu halka halka'],
#  ['Trisha Dey', 'Eitoh. Ebar ashol game 😌'],
#  ['Subhasish Basak', '60 neat desi daru'],
#  ['Subhasish Basak', '😁😁😁'],
#  ['Subhasish Basak', '😁😁😁'],
#  ['Subhasish Basak', '😁😁😁'],
#  ['Subhasish Basak', '😁😁😁'],
#  ['Subhasish Basak', 'Ki moja'],
#  ['Subhasish Basak', 'Thank u so much'],
#  ['Subhasish Basak', 'Idea tar jonno...'],
#  ['Subhasish Basak', 'Jd khele kichui hoto na....bekar'],
#  ['Subhasish Basak', 'Ei sob quarantine er din e desi daru chai'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Trisha Dey', 'Idea ta tor e chilo!'],
#  ['Trisha Dey', 'Amar idea to JD er chilo'],
#  ['Subhasish Basak', 'Mukher taste ta kemon change change hoye gelo....'],
#  ['Subhasish Basak', 'Jd khujtey giea ee toh....asol maal ta pelam'],
#  ['Trisha Dey', 'Modh e to eishob hoyna 😶😶'],
#  ['Subhasish Basak', 'Hidden gem\U0001f92d'],
#  ['Trisha Dey', 'Ekta chotto jinish korbi?'],
#  ['Subhasish Basak', 'Na na...kemon burnt taste'],
#  ['Subhasish Basak', 'Sob korbo'],
#  ['Subhasish Basak', 'Bol sudhu tui'],
#  ['Subhasish Basak', 'Bol'],
#  ['Subhasish Basak', 'Bol'],
#  ['Subhasish Basak', 'Bole fel'],
#  ['Subhasish Basak', 'Hoye jak'],
#  ['Subhasish Basak', 'Aaj k'],
#  ['Subhasish Basak', 'Bolei fel'],
#  ['Subhasish Basak', 'Hok'],
#  ['Subhasish Basak', 'Hok'],
#  ['Subhasish Basak', 'Aaj k hok'],
#  ['Trisha Dey',
#   'Neck er exercise e jerom matha ta ghorae ektu du teen rouch ghuriye shoja rakh. Tarpor dekh kirom laage 🤣  But shabdhane, khaat e matha abar thuke felishna.'],
#  ['Subhasish Basak', '😍😍😍😍😍😍😍😍😍😍😍😍😝😝😝😝😝😝😝😝😝😝😝😍😍😍😍'],
#  ['Trisha Dey', '*round'],
#  ['Subhasish Basak', 'Ki idea re'],
#  ['Subhasish Basak', 'Sabas'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Sabas'],
#  ['Subhasish Basak', 'Ekhhuni korchi'],
#  ['Trisha Dey', 'Careful'],
#  ['Trisha Dey', 'Matha thukishna kothao'],
#  ['Subhasish Basak', 'Ooooooooooooooooooooooo'],
#  ['Subhasish Basak', 'Ki dili'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Pagol hoye jabo amo'],
#  ['Trisha Dey', 'Eigulo cheap tricks'],
#  ['Subhasish Basak', 'Puro bishmaal'],
#  ['Subhasish Basak', 'Rr oo bol'],
#  ['Trisha Dey', 'Modh kom thaakle'],
#  ['Trisha Dey', 'Mishti ta r ekta cheap trick'],
#  ['Subhasish Basak', 'Ami Bonobo Kerala chalacchi'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Trisha Dey',
#   "R ekta is smoking. But I wouldn't suggest that to any non-smoker"],
#  ['Subhasish Basak', 'Mood'],
#  ['Trisha Dey', 'Kemon laagche?'],
#  ['Subhasish Basak', '😍'],
#  ['Subhasish Basak', 'Neck trick ta darun chilo'],
#  ['Subhasish Basak', 'Just sera'],
#  ['Subhasish Basak', '😘😘😘'],
#  ['Subhasish Basak', 'Pagol puro'],
#  ['Trisha Dey', 'Eita shob shomoy kaaj kore'],
#  ['Trisha Dey', '😎😎'],
#  ['Subhasish Basak', '🤤🤤🤤'],
#  ['Subhasish Basak', 'Iss'],
#  ['Trisha Dey', 'But r modh khashna.'],
#  ['Subhasish Basak', 'Isshhhhhhh'],
#  ['Trisha Dey', 'Ei shundor high ta thaak'],
#  ['Subhasish Basak', 'R ekbar'],
#  ['Subhasish Basak', 'Nahole puro ta mati hoye jabe'],
#  ['Trisha Dey', 'Abar kal khash!'],
#  ['Subhasish Basak', 'Ekhon just...peak hocche'],
#  ['Subhasish Basak', 'Halka aasche'],
#  ['Subhasish Basak', 'Halka'],
#  ['Trisha Dey', 'Tahole r olpo khabi'],
#  ['Subhasish Basak', 'Just halka'],
#  ['Subhasish Basak', 'Ami gems khacchi\U0001f92d\U0001f92d'],
#  ['Trisha Dey', 'Pagla hoye jaabi tui 🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Na na smell ta katatey hobe'],
#  ['Subhasish Basak', 'Rr chocolate to process ta k enhance oo korbe'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Trisha Dey', 'Eita ki chilo!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣'],
#  ['Subhasish Basak', 'Gems khacchi'],
#  ['Subhasish Basak', 'Cadbury gems'],
#  ['Subhasish Basak', 'Kire'],
#  ['Trisha Dey', 'Chocolate dopamine barae! Happy high!'],
#  ['Subhasish Basak', 'Gems khasni konodin'],
#  ['Subhasish Basak', '😁😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁'],
#  ['Subhasish Basak', '😁😁😁😁😁'],
#  ['Trisha Dey',
#   'Arey maane jei stunt ta korli, dekhe khub moja laaglo. Atogulo gems akshonge kheye nili'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Gems rrr oo achhe'],
#  ['Subhasish Basak', '2nd peg tar por khabo abar'],
#  ['Trisha Dey', 'R laagbena'],
#  ['Trisha Dey', 'Ebar second peg ta mere bottle ta rekhe de'],
#  ['Subhasish Basak', 'Ami sober thakte thakte ekta kotha bol'],
#  ['Trisha Dey', 'Bol'],
#  ['Subhasish Basak', 'Ami toh rr ekta peg maarbo'],
#  ['Trisha Dey', 'Yes'],
#  ['Trisha Dey', 'Not more than that'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Ok??'],
#  ['Trisha Dey', 'Okay. But tar theke beshi na'],
#  ['Subhasish Basak', 'Ok ok'],
#  ['Subhasish Basak', 'Shon ebar'],
#  ['Subhasish Basak', 'Ebar ami eta tey jodi jol misiea di'],
#  ['Subhasish Basak', 'Tahole jinis ta nosto hoye jabe na toh???'],
#  ['Subhasish Basak', 'Becoz ami half bottle ta rakhte parbo na'],
#  ['Trisha Dey',
#   'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.'],
#  ['Subhasish Basak', 'PLZZ plz'],
#  ['Subhasish Basak', 'Bol'],
#  ['Subhasish Basak', 'Ama k shei moto plan korte hobe...'],
#  ['Subhasish Basak', 'Nahole aaj kei sesh kore bottle ta fele debo'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Akdom na.'],
#  ['Trisha Dey', 'Bottle ta bondho kore nijer bag e rekhe de apatoto.'],
#  ['Trisha Dey', 'Ami kalke jerom bhabe bolbo, rekhe dibi bottle ta.'],
#  ['Subhasish Basak', 'Bag ta dhuye dieache maa...bag nei amar ekhon'],
#  ['Trisha Dey', 'Any locker that you have?'],
#  ['Subhasish Basak', 'Bottle ta jekhanee chilo okhanei rakhte hobe'],
#  ['Subhasish Basak', 'Jol mesano jay kinna bol'],
#  ['Trisha Dey', 'Accha'],
#  ['Trisha Dey', 'Dara'],
#  ['Subhasish Basak', 'Ami eta next 2 -3 te sitting ee sesh kore debo'],
#  ['Trisha Dey', 'Ajke r khabina'],
#  ['Subhasish Basak', 'In that case porer sitting gulo ektu diluted hobe'],
#  ['Subhasish Basak', 'Na keno'],
#  ['Subhasish Basak', 'Bollam toh ek peg'],
#  ['Trisha Dey', 'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.'],
#  ['Trisha Dey', 'Filtered water meshash'],
#  ['Subhasish Basak', 'Locker ee k rakhe...chabi ber korte gelei dhora porbo'],
#  ['Subhasish Basak', 'Ekhon abar filter chalatey hobe????'],
#  ['Subhasish Basak', '😫'],
#  ['Subhasish Basak', 'Emni jol  ??'],
#  ['Trisha Dey',
#   'Tahole porer sitting guloe diluted khash. Ajke r ek peg kheye rekhe de.'],
#  ['Trisha Dey', 'Bottle er jol o to filter er?'],
#  ['Subhasish Basak', 'Oh hya...same ee toh...tahole ki chap'],
#  ['Trisha Dey', 'Jol er bottle theke jol dhele de'],
#  ['Subhasish Basak', 'Ok tahole ota sorted'],
#  ['Subhasish Basak', 'Notun problem.'],
#  ['Subhasish Basak', 'Smell ta ki korbo???'],
#  ['Trisha Dey',
#   "Don't fill it to the brim though. Jerom modh er level chilo orom level obdhi jol diye rakh"],
#  ['Subhasish Basak', 'Rr ek peg khele bishal smell berobo😓'],
#  ['Trisha Dey', 'Gaa diye gondho berocche?'],
#  ['Trisha Dey', 'Deo'],
#  ['Trisha Dey', 'Perfume'],
#  ['Subhasish Basak', 'Seta ami jani😌'],
#  ['Trisha Dey', 'Puro AC er vent er shamne maar r nijer gaaye.'],
#  ['Subhasish Basak',
#   'Mukh theke smell aasche....jali smell...petrol er moto😥'],
#  ['Subhasish Basak', '😮😮😮'],
#  ['Subhasish Basak', 'Ki idea'],
#  ['Subhasish Basak', '👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻'],
#  ['Subhasish Basak', '👏🏻👏🏻👏🏻👏🏻👏🏻'],
#  ['Trisha Dey', 'Chips ache barite? Lays?'],
#  ['Subhasish Basak', 'Haldirams bhujia'],
#  ['Subhasish Basak', 'Acche'],
#  ['Trisha Dey', 'R ekta option'],
#  ['Trisha Dey', 'Mukhe ektu toothpaste r jol niye kulluchi kore fele de.'],
#  ['Subhasish Basak', 'Ooh....rr oo bhalo jinis acche 😍'],
#  ['Trisha Dey', 'Nahole orbit jaatiyo barite kichu thaakle kheye ne'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Ba listerine'],
#  ['Subhasish Basak', '😁😁😁'],
#  ['Trisha Dey', 'Arey! Chakna 😌'],
#  ['Subhasish Basak', 'Uff'],
#  ['Subhasish Basak', 'Ki mood😍😍😍'],
#  ['Trisha Dey', '😌😌'],
#  ['Trisha Dey', 'Eigulo amader university tricks.'],
#  ['Subhasish Basak', 'Jemon jemon???'],
#  ['Trisha Dey', 'We get exactly one hour to get high and then get that down'],
#  ['Trisha Dey', 'Toke ajke jotogulo trick bollam'],
#  ['Subhasish Basak', '🤣🤣🤣'],
#  ['Subhasish Basak',
#   '1.Neck trick 2. Laddu 3. Chocolate 4. Ritviz 5. Chakhna'],
#  ['Trisha Dey',
#   'Loke modh kheye nesha hole, komanor jonno lebu khae. Oita akdom bhul approach. Jhaal kichu khelei the work is done.'],
#  ['Subhasish Basak', 'Ebaba...papad ta toh jhal'],
#  ['Trisha Dey', 'Eita jene rakh. Life lesson.'],
#  ['Subhasish Basak', 'Ami khacchi keno😥'],
#  ['Trisha Dey', 'Beshi khashna then'],
#  ['Subhasish Basak', 'Fele dieachi😒'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Trisha Dey', 'Eki! Fele dili keno?'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'R khabo ma'],
#  ['Subhasish Basak', '*na'],
#  ['Trisha Dey', 'Oituku jhaal e kichu hobena!'],
#  ['Subhasish Basak',
#   'Halka j jinis ta esechilo....abar kintu shey cholle jacche😥'],
#  ['Subhasish Basak', 'Taake aatkabo ki kore ??'],
#  ['Trisha Dey', 'Peg ta maar'],
#  ['Trisha Dey', 'Mere repeat the tricks'],
#  ['Trisha Dey', 'Neck trick 😌'],
#  ['Subhasish Basak', 'Eto joldi...tahole toh party sesh 🙈'],
#  ['Subhasish Basak', 'Ota ami last er jonno bachiea rakhtey chai'],
#  ['Subhasish Basak', 'Right'],
#  ['Trisha Dey', 'Se to sesh hobei!'],
#  ['Subhasish Basak', 'With sage'],
#  ['Subhasish Basak', 'Naa 😭😭'],
#  ['Trisha Dey', 'Yep 😌'],
#  ['Trisha Dey', 'Party suru hole to sesh hobei?'],
#  ['Subhasish Basak', 'Arre dhur'],
#  ['Trisha Dey', 'Ki holo?'],
#  ['Subhasish Basak', 'Neck trick ta rr kaaj korche na'],
#  ['Subhasish Basak', '😭'],
#  ['Subhasish Basak', 'Eta teo resistance chole elo naki🙈'],
#  ['Trisha Dey', 'Korbena to! High hote hobe.'],
#  ['Subhasish Basak', 'Naaaqaaaa'],
#  ['Subhasish Basak', 'Naaaqaqq'],
#  ['Subhasish Basak', 'Nananaanann'],
#  ['Subhasish Basak', 'Nana'],
#  ['Subhasish Basak', 'Naan'],
#  ['Trisha Dey', 'Tahole abar ektu baade party suru korish 🤣'],
#  ['Subhasish Basak', 'Jeet sunchi'],
#  ['Trisha Dey', 'Shon'],
#  ['Subhasish Basak', 'Rr chobi dekchi...'],
#  ['Subhasish Basak', 'Jodi kichu hoy😓'],
#  ['Trisha Dey', 'Kisher chobi?'],
#  ['Trisha Dey', 'Ete hobena kichu! Ulte bad trip kheye jaabi!'],
#  ['Trisha Dey', 'Thik achish to?'],
#  ['Subhasish Basak', 'Chill'],
#  ['Subhasish Basak', 'Chap nei'],
#  ['Subhasish Basak', 'Neme geche puro ta...abar khela start korte hobe'],
#  ['Subhasish Basak', 'Khela hobe aaj k...'],
#  ['Subhasish Basak', 'Ekta jinis bujhlam'],
#  ['Subhasish Basak', 'Bishal jol teshta pacche...'],
#  ['Subhasish Basak', 'Dehydration hobe marattok'],
#  ['Trisha Dey', 'Jol kha'],
#  ['Subhasish Basak', 'Rr oo ek bottle jol laagbe raat e'],
#  ['Trisha Dey', 'Dehydration is what causes the hangover'],
#  ['Subhasish Basak', 'Last 30 min ee 1l jol khelam'],
#  ['Subhasish Basak', 'Smell chole geche'],
#  ['Subhasish Basak', 'Mood tao'],
#  ['Trisha Dey', 'Abar hobe mood'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Chalalam...'],
#  ['Subhasish Basak', 'Asha kori mood aasbe'],
#  ['Trisha Dey', 'Dekh ashe ki na'],
#  ['Subhasish Basak', 'Kokhon maarbo bol next peg ta ???'],
#  ['Subhasish Basak', 'Optimised ekta time bol'],
#  ['Trisha Dey', '12ta'],
#  ['Trisha Dey', 'Dot'],
#  ['Subhasish Basak', '😮😮'],
#  ['Subhasish Basak', 'Iccha nei...but monne hocche otai best hobe'],
#  ['Trisha Dey', 'Tahole khashna'],
#  ['Subhasish Basak', 'Sotti...salute to ur experience and suggestions'],
#  ['Trisha Dey', 'Jor kore khashna'],
#  ['Subhasish Basak', 'Wait korar iccha nei😒'],
#  ['Trisha Dey', '🤣'],
#  ['Trisha Dey', '11:45. Deal?'],
#  ['Subhasish Basak', 'Khawar iccha thakbena....ki bolis'],
#  ['Subhasish Basak', 'Na na 12...'],
#  ['Subhasish Basak', "Don't negotiate"],
#  ['Subhasish Basak', 'Ami nijeke control korchi'],
#  ['Subhasish Basak', 'Help kor'],
#  ['Trisha Dey', 'Eitoh. Good good. 😌'],
#  ['Subhasish Basak', 'Tui toh control bhenge dicchis'],
#  ['Trisha Dey', '12tar agey sudhu jol khaabi'],
#  ['Subhasish Basak', 'But ekta notul problem fell korchi'],
#  ['Subhasish Basak', 'Ok...sure ....ekdom'],
#  ['Trisha Dey', 'Amae control korate bolle ja routine debo, maante parbina.'],
#  ['Trisha Dey', 'Ki??'],
#  ['Subhasish Basak', 'Na na..ota porre. Ek din hobbe ..aaj na🙏🏻'],
#  ['Subhasish Basak', 'Bole fel....'],
#  ['Subhasish Basak', 'Tui toh guess korte paris'],
#  ['Subhasish Basak', "Let's c"],
#  ['Trisha Dey', 'Matha betha korche? Ba khub gorom laagche?'],
#  ['Subhasish Basak', 'Halka feel korchi'],
#  ['Subhasish Basak', 'Na na....gorom er problem solved'],
#  ['Trisha Dey', 'Naki bomi pacche?'],
#  ['Subhasish Basak', 'Na na....ami ki kiddo naki😒'],
#  ['Trisha Dey', 'Tui kiddo e 🤣🤣'],
#  ['Subhasish Basak', 'Ektu holeo experience acche'],
#  ['Subhasish Basak', 'Naaaaaaaaaaaaa'],
#  ['Subhasish Basak', 'Trina kiddo'],
#  ['Subhasish Basak', 'Ami na'],
#  ['Trisha Dey', 'Tui mon theke kiddo!'],
#  ['Subhasish Basak', 'Seta alada byapar'],
#  ['Subhasish Basak', 'But ami booze kiddo na'],
#  ['Subhasish Basak', 'Ami booze pro'],
#  ['Trisha Dey', 'Besh! Problem ki hocche bol'],
#  ['Subhasish Basak', 'Agge gaan bol'],
#  ['Subhasish Basak', 'Peye gechi'],
#  ['Subhasish Basak', 'In lamho k daman mey'],
#  ['Subhasish Basak', 'Bol tui bol'],
#  ['Subhasish Basak', 'Dekhi guessing power'],
#  ['Trisha Dey', 'R guess er baire chole jacche. Boleifel'],
#  ['Subhasish Basak', 'Buring🔥 halka'],
#  ['Subhasish Basak', 'Mild'],
#  ['Subhasish Basak', 'But acche'],
#  ['Trisha Dey', 'Oh'],
#  ['Subhasish Basak', 'Persistence'],
#  ['Trisha Dey', 'Heartburn hobei.'],
#  ['Subhasish Basak', 'Heart ee onk niche.... intestine er kache'],
#  ['Trisha Dey', 'Ghumonor agey ekta antacid kheye ghumiye porish.'],
#  ['Subhasish Basak', 'Heart is fit'],
#  ['Trisha Dey', 'Acid r gas hocche.'],
#  ['Subhasish Basak', 'Orebaba'],
#  ['Subhasish Basak', 'Eita ki game'],
#  ['Trisha Dey', 'Eita game er rules'],
#  ['Subhasish Basak',
#   'Antacid khujtey gele ekhon abar bawal hobe...ota amar room ee nei🙈'],
#  ['Subhasish Basak', 'Jigges korbe...ki hoyeche...keno kiser jonno'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Major missing....'],
#  ['Trisha Dey', 'Arey! ♥'],
#  ['Subhasish Basak', 'Oidin dokan ta tey giea amar mood ese gechilo😍'],
#  ['Trisha Dey', '😪'],
#  ['Trisha Dey', 'Abar hobe kokhono!'],
#  ['Subhasish Basak', 'Hay re hay'],
#  ['Trisha Dey', 'Yep'],
#  ['Subhasish Basak', 'Mast magan'],
#  ['Trisha Dey', 'Bhalo gaan!'],
#  ['Subhasish Basak', 'Ekhon rr bole ki hobe'],
#  ['Subhasish Basak', 'Sesh hoye gelo'],
#  ['Subhasish Basak', 'Bonobo type er kichu bol na...'],
#  ['Subhasish Basak', 'Music video ja kichu'],
#  ['Subhasish Basak', 'Mood ta halka fire pelam abar'],
#  ['Subhasish Basak', 'Purono prem er moto'],
#  ['Subhasish Basak', 'Aha😍'],
#  ['Trisha Dey', 'Ummm bhaabte de'],
#  ['Trisha Dey', 'O re piya?'],
#  ['Subhasish Basak', 'Hurr'],
#  ['Subhasish Basak', 'Ekta darun jinis dekhlam....'],
#  ['Trisha Dey', '🤣🤣🤣🤣'],
#  ['Subhasish Basak', 'Just dkh eta'],
#  ['Subhasish Basak', 'Ekbatmr'],
#  ['Subhasish Basak', 'Plzzz'],
#  ['Subhasish Basak', 'Ekbar'],
#  ['Trisha Dey', 'Dekha'],
#  ['Subhasish Basak', '2 min at lest dkh'],
#  ['Subhasish Basak', 'Puro pagol hoye jabi'],
#  ['Subhasish Basak', 'Use headphone'],
#  ['Trisha Dey', 'Patha'],
#  ['Subhasish Basak', 'Sound ta besi rrakis'],
#  ['Subhasish Basak', 'https://youtu.be/ebzEEEdjHj0'],
#  ['Subhasish Basak', 'Plzzz'],
#  ['Subhasish Basak', 'Dkh'],
#  ['Subhasish Basak', 'Puro out'],
#  ['Subhasish Basak', 'Poro'],
#  ['Subhasish Basak', 'Ami abar dekhchi'],
#  ['Trisha Dey', 'Trance chilo puro 😍'],
#  ['Subhasish Basak', '😁'],
#  ['Subhasish Basak', 'Maza aa gaya'],
#  ['Subhasish Basak', '6 mins'],
#  ['Subhasish Basak', 'Trpor'],
#  ['Trisha Dey', 'Shotti'],
#  ['Trisha Dey', '😌😌'],
#  ['Subhasish Basak', 'May udega'],
#  ['Subhasish Basak', "I'll fly"],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'In the sky'],
#  ['Subhasish Basak', 'Just to take off'],
#  ['Subhasish Basak', 'Boarding complete'],
#  ...]

# %%
# code for decomposing the conversations in blocks

blocks = []
temp = []
flag = False
index = 0

for i in dataList:
    if i[0] == whatsappName:
        flag = True
        temp.append(i)
    elif (i[0] != whatsappName and not flag):
        index += 1
        temp.append(i)
    else:
        blocks.append(temp + [index])
        temp = []
        index = 1
        temp.append(i)
        flag = False

# %%
blocks
# Out:
# [[['Trisha Dey', 'Permission granted XD'],
#   ['Trisha Dey', 'Assignment kotdur?'],
#   ['Subhasish Basak', 'Sobe toh shuru korlam'],
#   ['Subhasish Basak', '5 April deadline jodio...onk tym acche'],
#   2],
#  [['Trisha Dey',
#    'Amar laptop e beshi kaaj korle matha dhore jae. Tora kikore korish 😓'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', 'Scotch opomaanito holo.'],
#   ['Subhasish Basak', 'Seriously'],
#   ['Subhasish Basak', 'Seriously'],
#   ['Subhasish Basak', 'Seri'],
#   ['Subhasish Basak', 'Same kotha ta ami aritra k bolechilam...'],
#   ['Subhasish Basak', 'Exactly the same words'],
#   ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#   ['Subhasish Basak', 'Tomay pronam'],
#   ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#   1],
#  [['Trisha Dey', '🤣🤣🤣'],
#   ['Trisha Dey', 'Arey ki birokto laagche'],
#   ['Trisha Dey', 'R stock tulteo parbona'],
#   ['Subhasish Basak', 'Ki jataah'],
#   ['Subhasish Basak', 'Thug lyf hoye gelo😢'],
#   3],
#  [['Trisha Dey', '😭'],
#   ['Subhasish Basak',
#    'Aaj kal khub busy monne hocche\U0001f9d0...online dekha jay na aapna k'],
#   ['Subhasish Basak', 'Ki korre busy thaka jay...amader oo bol ektu'],
#   1],
#  [['Trisha Dey', 'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!'],
#   ['Trisha Dey', 'Tor assignment kotdur?'],
#   ['Subhasish Basak', 'Assignment kotha theke chole elo abar😒'],
#   ['Subhasish Basak', 'Assignment jali ..'],
#   2],
#  [['Trisha Dey', '🤣🤣'],
#   ['Subhasish Basak',
#    'Amar toh raat eeo ghum aaseena😥...ki obostha... corona rr bazar ee insomnia hoye gelo mone hoy'],
#   1],
#  [['Trisha Dey', 'Tai naaki?'],
#   ['Trisha Dey', 'E to amaro same obostha'],
#   ['Subhasish Basak', 'Cmi tey thakte khub kom ghumatam'],
#   2],
#  [['Trisha Dey', 'Ami just bari theke berote chai'],
#   ['Subhasish Basak', 'Tar ee effect hoyto'],
#   ['Subhasish Basak', 'Sobai chai'],
#   1],
#  [['Trisha Dey',
#    'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.'],
#   ['Trisha Dey', 'Amar ghumiye ghumiye matha dhore jacche'],
#   ['Trisha Dey', '😓'],
#   ['Subhasish Basak', 'Ekhon kothaye tora ??'],
#   ['Subhasish Basak', 'Mamar bari tei ?'],
#   3],
#  [['Trisha Dey', 'Na na. Barite.'],
#   ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#   ['Subhasish Basak', 'Kno mamar bari keno jabi ??'],
#   ['Subhasish Basak', 'K acche ??'],
#   ['Subhasish Basak', 'Or'],
#   ['Subhasish Basak', 'Ki acche??'],
#   ['Subhasish Basak', '🤔'],
#   2],
#  [['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#   ['Trisha Dey', 'Ami pagol hoye jaabo'],
#   ['Trisha Dey', '😭'],
#   ['Subhasish Basak', '😆'],
#   ['Subhasish Basak', 'Eto chap nis na'],
#   ['Subhasish Basak', 'Aaste aaste sob habituated hoye jabo amra'],
#   ['Subhasish Basak', 'Eta ekhono onk din ee cholbe ja monne hoy'],
#   3],
#  [['Trisha Dey',
#    'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.'],
#   ['Trisha Dey', 'Ami thaakte parchina r barite'],
#   ['Subhasish Basak', 'Bari ta just hotel naki\U0001f92d'],
#   ['Subhasish Basak', "Papa's hotel"],
#   2],
#  [['Trisha Dey', 'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭'],
#   ['Trisha Dey', 'Almost 🤣🤣🤣'],
#   ['Subhasish Basak', 'Babare...tui oo booze er jonno pagol hoye jacchis'],
#   ['Subhasish Basak', 'Booze kintu control ee khete hobe...naholei case'],
#   ['Subhasish Basak', 'Besi booze khawa bhalo na😌'],
#   2],
#  [['Trisha Dey', 'Jaani. 😓'],
#   ['Trisha Dey', 'But birokto laagche'],
#   ['Subhasish Basak', 'Tym paas kor'],
#   2],
#  [['Trisha Dey', 'Ekta nip o thaakle roj ek drop kore khetam 🤣'],
#   ['Subhasish Basak', 'Any hobbies ?? Drawing movies etc!??'],
#   ['Subhasish Basak', 'Comics acche toh'],
#   1],
#  [['Trisha Dey',
#    'I do sketch like Titir. But ajkal oitao korte lyadh laagche'],
#   ['Subhasish Basak', 'Hmm'],
#   ['Subhasish Basak', 'Cooking ???'],
#   1],
#  [['Trisha Dey',
#    'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭'],
#   ['Trisha Dey', 'Sudhu chicken banate paari. 😅'],
#   ['Subhasish Basak', 'Arre dhur🙈'],
#   ['Subhasish Basak', 'Chicken banano toh 60ml peg bananor thekeo soja'],
#   2],
#  [['Trisha Dey', 'Ekta sketch dekhbi?'],
#   ['Subhasish Basak', 'Lasagna ..pasta...esob bana'],
#   ['Subhasish Basak', 'Yes pls...😁'],
#   1],
#  [['Trisha Dey', 'Eire. Otou shoja na!!!😶😶😶'],
#   ['Trisha Dey', 'Pasta banate pari'],
#   ['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak',
#    'When I say that...I mean not a single drop should fall out of the peg measure😌'],
#   3],
#  [['Trisha Dey', 'Lasagna ta konodin try korini jodio'],
#   ['Subhasish Basak', '😮😮😮😮😮'],
#   ['Subhasish Basak', 'Seriously'],
#   ['Subhasish Basak', 'U did that'],
#   1],
#  [['Trisha Dey', 'Wait korchilam je kokhon eta bolbi 🤣🤣🤣'],
#   ['Trisha Dey', 'Yep 😝'],
#   ['Subhasish Basak', '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂'],
#   ['Subhasish Basak', 'Why why'],
#   ['Subhasish Basak', 'Keno'],
#   2],
#  [['Trisha Dey', 'Eki? Keno, keno?'],
#   ['Subhasish Basak', 'Why wasting ur talent'],
#   ['Subhasish Basak', 'Eta over professional'],
#   ['Subhasish Basak', 'Seriously'],
#   1],
#  [['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#   ['Subhasish Basak', 'Bolchi...'],
#   ['Subhasish Basak', 'Esob bolis na'],
#   ['Subhasish Basak', 'Just .. printed monne hocche'],
#   ['Subhasish Basak', 'Great job👏🏻👏🏻'],
#   1],
#  [['Trisha Dey',
#    "Ek shomoy khub interest chilo art and animation niye kaaj korar. Tarpor bujhlam je oishob to shob shomoy korte parbo. And I don't want to work for someone else when it's something I love. I sketch for myself."],
#   ['Trisha Dey', 'Thanks! 😃'],
#   ['Subhasish Basak', 'Passion it is'],
#   2],
#  [['Trisha Dey', 'Akdom!'],
#   ['Subhasish Basak',
#    'Ami onk friends der dekhechi.... drawing korte....but eta off the track chilo.... seriously'],
#   ['Subhasish Basak', 'Puro printed comics monne hocche'],
#   ['Subhasish Basak', 'Tym waste koris na... concentrate on drawing'],
#   1],
#  [['Trisha Dey',
#    'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.'],
#   ['Subhasish Basak', 'Pen??'],
#   ['Subhasish Basak', 'Tar maane without any mistakes'],
#   ['Subhasish Basak', 'Eto level berei choleche'],
#   1],
#  [['Trisha Dey',
#    'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!'],
#   ['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Eta dekhe ekta gaan mone pore gelo..'],
#   ['Subhasish Basak',
#    'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970'],
#   2],
#  [['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#   ['Subhasish Basak', 'Young ta dekhina...normal TBBT'],
#   ['Subhasish Basak', 'Tao kobe last dekhechi monne ney'],
#   ['Subhasish Basak', 'Lecture maane toh 1.5 hrs'],
#   ['Subhasish Basak', 'Eto puro ready made fast art😄'],
#   1],
#  [['Trisha Dey', 'More or less'],
#   ['Trisha Dey', 'Amader 4 hours er o lecture thaake'],
#   ['Trisha Dey', '😭😭'],
#   ['Subhasish Basak', 'Ekjon ee professor ??'],
#   3],
#  [['Trisha Dey', 'Abar ekjon professor ekdin 6 hours er o niyechilo.'],
#   ['Trisha Dey', 'Na. Dujon.'],
#   ['Trisha Dey', 'Eita ekjon professor.'],
#   ['Subhasish Basak', 'Salute to their devotion'],
#   ['Subhasish Basak', 'Erai paarbe Corona rr solution ber korte🤣'],
#   3],
#  [['Trisha Dey', 'Amra pagol hoye jai'],
#   ['Trisha Dey', '😭'],
#   ['Trisha Dey', 'R enar under ei amar dissertation paper 🤣'],
#   ['Trisha Dey', 'Emni khubi bhalo porae. Kintu 6 hours ta newa jaena.'],
#   ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#   4],
#  [['Trisha Dey',
#    'Abar amader bole je tomra majhe chaile giye cigarette coffee kheye esho.'],
#   ['Subhasish Basak', 'Class ei allow kore dik..😅'],
#   1],
#  [['Trisha Dey',
#    'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.'],
#   ['Subhasish Basak', 'Tahole claass koris keno etokkhon dhore'],
#   ['Subhasish Basak', 'Bunk mar chill kor'],
#   1],
#  [['Trisha Dey',
#    "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona."],
#   ['Trisha Dey', 'Baaki class gulo jokhon jokhon icche korena, korina.'],
#   ['Subhasish Basak',
#    'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...'],
#   ['Subhasish Basak', 'Kheye deye kaaj nei'],
#   ['Subhasish Basak', 'Kaatano oo jay na😒'],
#   2],
#  [['Trisha Dey', 'Keno?'],
#   ['Trisha Dey', 'CMI er lokjon?'],
#   ['Subhasish Basak', 'Na na ...oder sathe kal k kotha bolchilam'],
#   ['Subhasish Basak', 'Kal k trina k bollam toke daaktey'],
#   ['Subhasish Basak', 'Byass'],
#   2],
#  [['Trisha Dey', 'Na maane ototao chinishna moto lokjon?'],
#   ['Trisha Dey', 'Ami ghumocchilam tokhon XD'],
#   ['Subhasish Basak',
#    'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒'],
#   2],
#  [['Trisha Dey', 'Arey ektu kotha bolei ne.'],
#   ['Subhasish Basak', 'Raat 8 pm ee ghumacchis ??'],
#   1],
#  [['Trisha Dey', 'Dujoner e time pass hoe jaabe'],
#   ['Trisha Dey',
#    'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪'],
#   ['Subhasish Basak',
#    'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣'],
#   ['Subhasish Basak', '\U0001f971\U0001f971😴'],
#   2],
#  [['Trisha Dey', 'Na na. Atou baaje hobena 🤣'],
#   ['Subhasish Basak',
#    'Dkh...jokhon cmi tey chilam...tokhon tokee bolchilam j 2 months por kolkatay giea amra party korbo'],
#   ['Subhasish Basak', 'Rr ekhon kolkatay acchi'],
#   ['Subhasish Basak', 'Kichu korte parchi na'],
#   1],
#  [['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Ki obostha'],
#   ['Subhasish Basak', 'Let me guess'],
#   ['Subhasish Basak', 'Tiger caves er beach ta ??'],
#   1],
#  [['Trisha Dey', 'Kostor sesh nei 2020 te 😪😪'],
#   ['Trisha Dey', 'Yes!'],
#   ['Subhasish Basak', 'Shei drive ta ami bhulbo na konodin'],
#   2],
#  [['Trisha Dey', 'Puro trip e amar ei beach ta shob theke bhalo legechilo'],
#   ['Subhasish Basak', 'It was indeed'],
#   ['Subhasish Basak', 'Sob theke worst ki chilo ???'],
#   1],
#  [['Trisha Dey', 'Second would be marina beach.'],
#   ['Trisha Dey', 'Third Mahabalipuram'],
#   ['Trisha Dey', 'Kovallam 🤣'],
#   ['Subhasish Basak', 'Seriously'],
#   3],
#  [['Trisha Dey',
#    'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.'],
#   ['Subhasish Basak', 'Hya.  ...jodio kichu chilo na'],
#   ['Subhasish Basak', 'Rr baki ??'],
#   1],
#  [['Trisha Dey', 'R kon beach e gechilam?'],
#   ['Subhasish Basak', 'Not only beach'],
#   ['Subhasish Basak', 'Baki rr oo toh chilo onk kichu'],
#   ['Subhasish Basak', 'Trip ta tey'],
#   1],
#  [['Trisha Dey',
#    'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#   ['Trisha Dey',
#    "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#   ['Subhasish Basak', 'I can totally relate to this'],
#   ['Subhasish Basak', "That's life my friend"],
#   ['Subhasish Basak', 'Dkh...duto option thake....'],
#   ['Subhasish Basak',
#    '1. Forget everything move on  2. Cherish your memories and create new memories'],
#   2],
#  [['Trisha Dey',
#    'True. R ki kora jaabe. Aj ekhane achi kal okhane thaakbo. Eita niye kicchu korar nei. Aim is to never stop planning out more trips!'],
#   ['Subhasish Basak',
#    'Ami toh paarle lyf er each and every moment ta capture kore rakhtey chai... memories recapitulation is the best thing for me'],
#   1],
#  [['Trisha Dey', 'Do you go back to them? Mane chobi gulo abar dekhish?'],
#   ['Subhasish Basak', 'Google photos ka naam suna hay ??'],
#   ['Subhasish Basak', '😌'],
#   ['Subhasish Basak',
#    'Ota amar most valuable asset....puro lyf acche ota tey amar'],
#   1],
#  [['Trisha Dey', 'Yep. Akdom!'],
#   ['Trisha Dey', 'Ami atodin use e kortam na.'],
#   ['Trisha Dey',
#    'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#   ['Subhasish Basak', 'Kore fel'],
#   ['Subhasish Basak', '10 years pore dekhbi'],
#   ['Subhasish Basak',
#    'Chennai gieachilis...kichu pagol lok jon er sathe party korte'],
#   ['Subhasish Basak', '🤣🤣'],
#   3],
#  [['Trisha Dey',
#    "Pagol to shobai. Sudhu different circumstances and variety'r 😌"],
#   ['Subhasish Basak', 'Yep'],
#   ['Subhasish Basak', '😓'],
#   1],
#  [['Trisha Dey', '🤣'],
#   ['Trisha Dey', 'Ki korchish akhon?'],
#   ['Subhasish Basak', 'Talking to a friend'],
#   2],
#  [['Trisha Dey', 'Accha'],
#   ['Trisha Dey', 'Kotha bole ne'],
#   ['Subhasish Basak', 'High hote iccha korche'],
#   ['Subhasish Basak', 'Any suggestions'],
#   2],
#  [['Trisha Dey', 'Eire'],
#   ['Trisha Dey', 'Emni emni kikore high hobi?'],
#   ['Subhasish Basak', "That's why asking for an expert opinion"],
#   ['Subhasish Basak', 'Who else it could be'],
#   ['Subhasish Basak', 'Other than u'],
#   2],
#  [['Trisha Dey', 'I am sure posto diye kichu na kichu ber kora jaabe 🤣🤣'],
#   ['Subhasish Basak', 'I want to fly in the sky like a bird 😘😗'],
#   1],
#  [['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#   ['Subhasish Basak', "That's only imagination"],
#   ['Subhasish Basak', 'I want it in reality'],
#   ['Subhasish Basak', 'Just imagine... flying in the sky'],
#   ['Subhasish Basak', "Wouldn't it be fun"],
#   1],
#  [['Trisha Dey',
#    'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#   ['Subhasish Basak', 'Go wherever u want'],
#   ['Subhasish Basak', 'Naaaaa'],
#   ['Subhasish Basak', 'Plz bol'],
#   ['Subhasish Basak', 'Plz'],
#   ['Subhasish Basak', 'Pz'],
#   ['Subhasish Basak', 'Plz'],
#   ['Subhasish Basak', 'Plz'],
#   ['Subhasish Basak', 'Plz'],
#   ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻'],
#   1],
#  [['Trisha Dey', 'Amar porer jonme pakhi hoar khub icche'],
#   ['Subhasish Basak', 'Ami ekhon ee pakhi hobo'],
#   1],
#  [['Trisha Dey', 'Barite modh ache?'],
#   ['Subhasish Basak', 'Eagle 😎'],
#   ['Subhasish Basak', 'Jd acche'],
#   ['Subhasish Basak', 'Half khali'],
#   1],
#  [['Trisha Dey', 'Boro game hoye jaabe to tahole?'],
#   ['Subhasish Basak', 'Tui asol kothaa bol na'],
#   1],
#  [['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#   ['Subhasish Basak', 'Ektai bottle acche'],
#   ['Subhasish Basak', 'Tui bol na'],
#   ['Subhasish Basak', 'Ki korte hobe'],
#   ['Subhasish Basak', 'Aagun jalabo?'],
#   1],
#  [['Trisha Dey', 'Beer ache barite?'],
#   ['Trisha Dey', 'Hyaat 🤣'],
#   ['Subhasish Basak', 'Bari eta re...bar noy🙈'],
#   ['Subhasish Basak', 'Sudhu ekta jd acche...byass'],
#   ['Subhasish Basak', 'Bol ebar'],
#   2],
#  [['Trisha Dey', 'Jaani. Ektu apprehensive hocchilam 🤣'],
#   ['Subhasish Basak', '🤣🤣rr kost dis na'],
#   1],
#  [['Trisha Dey',
#    'Taratari high hote gele duto peg 2 min e maar. Mere du tablespoon chini kheye ne.'],
#   ['Trisha Dey', '🤣🤣'],
#   ['Subhasish Basak', 'Chini ??'],
#   2],
#  [['Trisha Dey', 'Tarpor dekh kotokhon uurish'],
#   ['Subhasish Basak', 'Chini???'],
#   1],
#  [['Trisha Dey', '🤣🤣'],
#   ['Trisha Dey', 'Modh kheye mishti khele faatiye nesha dae'],
#   ['Subhasish Basak', '2 peg khele toh abar jol meshate hobe jd tey'],
#   2],
#  [['Trisha Dey', 'Why do you think they add so much sugar in shots?'],
#   ['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'Okay'],
#   ['Subhasish Basak', 'Tui jokhon bole dieachis...aaj k korbo'],
#   2],
#  [['Trisha Dey', 'Tahole ektai peg maar'],
#   ['Trisha Dey', 'But 30 30 kore maar'],
#   ['Subhasish Basak', 'Na ...ekta te amar toh kichu hobe na'],
#   2],
#  [['Trisha Dey', 'Eishob korishna re! Aunty uncle dhorle maar khabina?'],
#   ['Subhasish Basak', 'Ghumiea porbe ektu pore...'],
#   1],
#  [['Trisha Dey', 'Tao. Bujhbena?'],
#   ['Subhasish Basak', 'Tokhon ami jege uthbo🤓'],
#   1],
#  [['Trisha Dey', '🤣🤣🤣'],
#   ['Trisha Dey', 'Eishob korishna re'],
#   ['Subhasish Basak',
#    'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche'],
#   ['Subhasish Basak', 'Kintu kinrr kora jabe'],
#   ['Subhasish Basak', 'Booze sobar opor ee'],
#   2],
#  [['Trisha Dey', 'Moteo na 😒'],
#   ['Subhasish Basak', '???????????????????'],
#   ['Subhasish Basak', "U don't ask that"],
#   ['Subhasish Basak', '*say that'],
#   1],
#  [['Trisha Dey', 'Booze er opor maa babar maar!!!! 😒'],
#   ['Subhasish Basak', '🙈🙈🙈'],
#   1],
#  [['Trisha Dey', 'Dhere boyeshe maar khete bhalo lagbe tor?'],
#   ['Subhasish Basak', 'Maarbe naa ...etuku jani...but bishal jharbe😖'],
#   1],
#  [['Trisha Dey', 'Tahole korishna'],
#   ['Subhasish Basak', 'But tui chini chara onno kichu bol na'],
#   1],
#  [['Trisha Dey',
#    "I've been caught by my parents drunk. Ami jaani ki obostha hoy dhora porle 🤦🏽\u200d♀"],
#   ['Subhasish Basak', 'Sudhu Chini rr jonno eto ta risk nebo🤷🏻\u200d♂️'],
#   1],
#  [['Trisha Dey', 'Barite mishti ache?'],
#   ['Subhasish Basak', 'Soan papri....laddu'],
#   1],
#  [['Trisha Dey', 'Laddu will work.'],
#   ['Trisha Dey', 'Duto laddu kheye nish'],
#   ['Subhasish Basak', '🤣🤣🤣🤣'],
#   ['Subhasish Basak', 'Ki din eseche...'],
#   2],
#  [['Trisha Dey', 'Also, khali pete thaakle bhalo.'],
#   ['Trisha Dey', "Kintu I'm guessing tui dinner kore felechish"],
#   ['Subhasish Basak',
#    'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣'],
#   ['Subhasish Basak', 'Hya...dinner complete'],
#   2],
#  [['Trisha Dey', 'Tor kache to tao kichu ache. Amar konk stock e nei. 🤣'],
#   ['Subhasish Basak', 'Ki kore bujhli?'],
#   1],
#  [['Trisha Dey', 'Then ektu raat er dike kha!'],
#   ['Trisha Dey', 'I can guess 😌'],
#   ['Subhasish Basak', 'Bari tey fix tym 9pm'],
#   ['Subhasish Basak', 'Khetey hole khao....nahole abar kal k 😅😂'],
#   2],
#  [['Trisha Dey', 'Tai????? 🤣🤣🤣🤣'],
#   ['Subhasish Basak', 'Toder dinner done ??'],
#   1],
#  [['Trisha Dey', 'Tor kono bhai ba bon ache?'],
#   ['Subhasish Basak', 'Cousins acche'],
#   ['Subhasish Basak', '7 jon total'],
#   1],
#  [['Trisha Dey', 'Nope. Trina ghumocche! Also, eita amader shondhebela 😌'],
#   ['Trisha Dey', "We don't have dinner before 11 p.m."],
#   ['Trisha Dey', 'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!'],
#   ['Subhasish Basak', 'Amar saamne cupboard er moddhei acche'],
#   ['Subhasish Basak', 'Guard laagbe na😅'],
#   3],
#  [['Trisha Dey', 'No. 7?'], ['Subhasish Basak', 'Ami 3rd'], 1],
#  [['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#   ['Subhasish Basak', '🤣🤣🤣'],
#   ['Subhasish Basak', 'Wait dara check korchi'],
#   ['Subhasish Basak', 'Eta ekjon baba k gift korechilo....porei acche....'],
#   ['Subhasish Basak', 'Duty free maal'],
#   1],
#  [['Trisha Dey', 'Uncle khaena?'],
#   ['Subhasish Basak',
#    'Uncle ek somoy amar thekeo bishal passionate chilo booze niea....'],
#   ['Subhasish Basak', 'Cupboard ekta compartment ta k bar baniea chilo....'],
#   1],
#  [['Trisha Dey', 'Tahole tor chaap ki??'],
#   ['Subhasish Basak', 'Ekhon seta r obostha dekhley amar ee kharap laage😓'],
#   1],
#  [['Trisha Dey', 'Keno?'],
#   ['Subhasish Basak',
#    'Biscuits Horlicks rr khali Scotch glass gulo rakha thake'],
#   ['Subhasish Basak', '🤣🤣'],
#   1],
#  [['Trisha Dey', 'Eire 🤣'],
#   ['Subhasish Basak', 'Dara ami jd ta check korchi'],
#   1],
#  [['Trisha Dey', 'Kor'],
#   ['Subhasish Basak', 'Arrey'],
#   ['Subhasish Basak', 'Ki luck amar'],
#   ['Subhasish Basak', 'Ki pelam dkh'],
#   1],
#  [['Trisha Dey', 'Dekha'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', '🤤🤤😍😍'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', 'Eita ki??'],
#   ['Subhasish Basak', 'Goa theke kinechilo baba......ekhon monne porlo...'],
#   ['Subhasish Basak', 'Local daru'],
#   1],
#  [['Trisha Dey', 'Eire 🤣'],
#   ['Subhasish Basak', 'Eta khele toh ami aaj rocket'],
#   1],
#  [['Trisha Dey', 'But oita sealed pack'],
#   ['Trisha Dey', 'Kikore khabi?'],
#   ['Subhasish Basak', 'Kintu poblm ektai...'],
#   ['Subhasish Basak', 'Exactly'],
#   ['Subhasish Basak', 'Ki coincidence'],
#   ['Subhasish Basak', 'Etai bolte jacchilam'],
#   ['Subhasish Basak', '🙈🙈'],
#   2],
#  [['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#   ['Trisha Dey', 'Kaju fenni ta baad de.'],
#   ['Subhasish Basak', 'Duto punch kore dbo??'],
#   2],
#  [['Trisha Dey', 'Kikore korbi?'],
#   ['Trisha Dey', 'Sealed to'],
#   ['Subhasish Basak', 'Tahole toh bishmaal puro'],
#   2],
#  [['Trisha Dey', 'Korle rocket er moto uthbi 🤣'],
#   ['Trisha Dey', 'Yes'],
#   ['Subhasish Basak', 'Hya...seal ta opn korlam...jol misiea dilam'],
#   2],
#  [['Trisha Dey', 'Local daaru is bangla 🤣'],
#   ['Subhasish Basak', 'Alcohol ee jol meshlae chap nei toh'],
#   1],
#  [['Trisha Dey', 'Uncle ki boka 😒😒'],
#   ['Subhasish Basak', 'Feni ta Goan daru'],
#   ['Subhasish Basak',
#    'Uncle er bondhu bandhob bari tey na ele uncle khabe na....'],
#   ['Subhasish Basak', 'Tao rare'],
#   1],
#  [['Trisha Dey',
#    'Country liquor more or less shob jaegar eki khete hoy. Puro bish er moto. Jar jonno ami konodin khabona decide korechi.'],
#   ['Subhasish Basak', 'Rr ekhon toh beri tey keo aasbei na'],
#   1],
#  [['Trisha Dey', 'But jedin dhorte parbe sedin ki hobe bhaab'],
#   ['Subhasish Basak', 'Kheyechis kono din??'],
#   ['Subhasish Basak', 'Ooh...oto k bhabe'],
#   ['Subhasish Basak', 'Tui bachiea dis ama k sedin🙏🏻'],
#   1],
#  [['Trisha Dey', '😶😶'],
#   ['Trisha Dey', 'Na'],
#   ['Subhasish Basak', 'Feni+jd+laddu+chini'],
#   2],
#  [['Trisha Dey', 'Eita impossible. Nijekeo bachate parini 🤣🤣'],
#   ['Subhasish Basak', 'Ufff\U0001f92f'],
#   1],
#  [['Trisha Dey', 'Chinni r laagbena.'],
#   ['Trisha Dey', 'More jaabi re.'],
#   ['Subhasish Basak', 'Raw khete hobe otai chap...smell berobe naki ??'],
#   2],
#  [['Trisha Dey', 'Amader shonge r party korte parbina konodin.'],
#   ['Subhasish Basak', 'Bangla te toh smell hoy'],
#   1],
#  [['Trisha Dey', 'Bhaab'],
#   ['Subhasish Basak', 'Na na'],
#   ['Subhasish Basak', 'Eta hobe na konodin'],
#   1],
#  [['Trisha Dey', 'Raw khashna.'],
#   ['Trisha Dey', 'Jol mishiyei kha'],
#   ['Subhasish Basak', 'Arre uncle oo bojhe booze ki jinis😌'],
#   2],
#  [['Trisha Dey', 'Tao 🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'Tahole ekhon ee shuru kori naki??'],
#   ['Subhasish Basak', '😝'],
#   1],
#  [['Trisha Dey', 'Na na'],
#   ['Trisha Dey', 'Akdom na'],
#   ['Subhasish Basak', 'Ami tor arr w8 korte parchi na'],
#   2],
#  [['Trisha Dey', 'Pore!'], ['Subhasish Basak', '🤤🤤'], 1],
#  [['Trisha Dey', 'R ektu wait kore ja'],
#   ['Subhasish Basak', 'Koto w8 korabi'],
#   ['Subhasish Basak', '10 ta baaje'],
#   1],
#  [['Trisha Dey',
#    'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣'],
#   ['Subhasish Basak', 'Jd ta ek dhok maarbo...trpor feni ta ek dhok'],
#   ['Subhasish Basak', 'Na na'],
#   ['Subhasish Basak', 'Pagol naki'],
#   1],
#  [['Trisha Dey', 'Tui 11tae khash!'],
#   ['Subhasish Basak', 'Ok bolis na...'],
#   ['Subhasish Basak', 'Na na bolbe abar'],
#   1],
#  [['Trisha Dey', 'Ami bolbona. Tui bolbi.'],
#   ['Trisha Dey', '😶'],
#   ['Subhasish Basak', 'Hurr'],
#   2],
#  [['Trisha Dey', '😒😒'],
#   ['Trisha Dey', "We'll see"],
#   ['Subhasish Basak', 'Arrey...tui sudhu dekhtey thak...'],
#   ['Subhasish Basak', 'Amar game'],
#   ['Subhasish Basak', 'Aaj k kaju feni rr party hobe'],
#   2],
#  [['Trisha Dey', '11tar agey warm up suru hobena'],
#   ['Trisha Dey', 'Deal?'],
#   ['Subhasish Basak', 'Ami idea peye gechi'],
#   ['Subhasish Basak', 'Bottle tai gayeb kore debo'],
#   2],
#  [['Trisha Dey',
#    'E kirom party? Eka eka? Bhaab Aritra, Subhayan r Trina koto kosto paabe'],
#   ['Subhasish Basak', 'Bujhtei paarbe na🤣🤣'],
#   1],
#  [['Trisha Dey', '😒😒'],
#   ['Trisha Dey', 'Akdom na.'],
#   ['Subhasish Basak', '😓 emotional blackmail😖😖'],
#   ['Subhasish Basak', 'Ki naa???'],
#   ['Subhasish Basak', 'Eita toh bhalo idea ??'],
#   2],
#  [['Trisha Dey', 'Emotional blackmail na! Oder shotti kharap lagbe!'],
#   ['Trisha Dey', 'Akdom na!'],
#   ['Subhasish Basak', 'Tahole ki ami pakhi hotte parbo na'],
#   ['Subhasish Basak', 'Keno...??'],
#   ['Subhasish Basak', 'Full proof'],
#   2],
#  [['Trisha Dey', 'Bottle gayeb korle tui du teen din e bottle sesh kore dibi'],
#   ['Subhasish Basak',
#    'Baba bhuleo geche j Orom kichu ekta chilo...just like amio bhule gechilam'],
#   ['Subhasish Basak', 'Hya ...ota toh rr oo moja😁😁🤤'],
#   1],
#  [['Trisha Dey',
#    'Hoa uchit noe. Bhaab oder ekdin video call e rekhe pakhi hobi. That way orao anondo paabe'],
#   ['Trisha Dey',
#    'Toke idea shob diye rakhlam, implementation onno ekdin hok!'],
#   ['Subhasish Basak',
#    'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe'],
#   2],
#  [['Trisha Dey', 'Tarpor to abar booze booze korbi! 🤦🏽\u200d♀'],
#   ['Trisha Dey', 'Arey shobai ghumiye porbe to!'],
#   ['Trisha Dey', 'Kal kha! Kalke video call e thaakbo shobai!'],
#   ['Subhasish Basak', 'Arre tui chap nicchis keno...chill'],
#   3],
#  [['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#   ['Subhasish Basak', 'Kichu hobe na'],
#   ['Subhasish Basak', 'Chap nis na'],
#   ['Subhasish Basak', 'Chilll'],
#   ['Subhasish Basak', 'Chill'],
#   1],
#  [['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#   ['Subhasish Basak', 'Se toh hobei'],
#   ['Subhasish Basak', 'Taintoh bolchi'],
#   ['Subhasish Basak', 'Video call korbo ami'],
#   ['Subhasish Basak', 'Ok'],
#   1],
#  [['Trisha Dey', 'Baakira jege thaakbe?'],
#   ['Subhasish Basak', 'Sobai jege thakbe'],
#   ['Subhasish Basak', '😁😁😁😁😁'],
#   ['Subhasish Basak', 'Wah wah'],
#   ['Subhasish Basak', 'Aaj may udega🤤'],
#   1],
#  [['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#   ['Trisha Dey',
#    'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#   ['Subhasish Basak', 'Chill'],
#   ['Subhasish Basak', 'Chill'],
#   ['Subhasish Basak', 'Just w8 & watch'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', "It's going to drop soon😆"],
#   2],
#  [['Trisha Dey', 'Besh'],
#   ['Trisha Dey', 'Game suru hocche akhon?'],
#   ['Subhasish Basak', 'Still waiting for ur permission😓'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Khulbo???'],
#   ['Subhasish Basak', 'Plz??'],
#   2],
#  [['Trisha Dey', '🤣'],
#   ['Trisha Dey', 'Na'],
#   ['Trisha Dey', 'In another 15 mins'],
#   ['Subhasish Basak', 'Keno?????????????????'],
#   ['Subhasish Basak', 'Keno ???'],
#   ['Subhasish Basak', 'Agge bol keno????????'],
#   ['Subhasish Basak', 'Why'],
#   ['Subhasish Basak', '????'],
#   3],
#  [['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#   ['Trisha Dey', '😒'],
#   ['Subhasish Basak', 'Subho kaaj ee deri keno???'],
#   ['Subhasish Basak', 'Done ami wait korchi till 10:30'],
#   ['Subhasish Basak', 'Trpor kintu ek dhok ee direct eto ta namabo'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', '🤤🤤🤤🤤'],
#   2],
#  [['Trisha Dey', 'Chele pagol hoye geche'],
#   ['Subhasish Basak', 'Bhai maaro mujhe maaro'],
#   1],
#  [['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#   ['Subhasish Basak', 'Dhak dhak...hocche amar'],
#   ['Subhasish Basak', 'Wai ekhon keno???'],
#   ['Subhasish Basak', 'Ei toh bolli 10:30'],
#   ['Subhasish Basak', 'Wai'],
#   1],
#  [['Trisha Dey', '🤣🤣'],
#   ['Trisha Dey', 'Bole rakh re'],
#   ['Subhasish Basak', 'Let me enjoy the moment'],
#   2],
#  [['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#   ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#   ['Subhasish Basak', 'Mood aasbe emon ekta gaan bol'],
#   ['Subhasish Basak', 'Ooh peyechi'],
#   ['Subhasish Basak', 'Tor favourite song'],
#   ['Subhasish Basak', 'Ritviz'],
#   2],
#  [['Trisha Dey', 'Dim the lights 😌'],
#   ['Trisha Dey', 'Arey!!!'],
#   ['Trisha Dey', 'Amar favourite party song'],
#   ['Subhasish Basak', "It's already dimmed"],
#   3],
#  [['Trisha Dey', 'Let me guess. Liggi?'],
#   ['Trisha Dey', 'Naki udd gaye?'],
#   ['Subhasish Basak', 'Na na bol konta chalabo'],
#   2],
#  [['Trisha Dey', 'Eita I guess'],
#   ['Trisha Dey', 'Udd gaaye 🤣🤣'],
#   ['Subhasish Basak', 'Ami toh bhablam...chalo chalei'],
#   2],
#  [['Trisha Dey', 'Chala!'],
#   ['Subhasish Basak', 'Konta chalabo?? Ritviz naki dim the lights'],
#   1],
#  [['Trisha Dey', 'Uurte chash tai udd gaye bollam'],
#   ['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'Ritviz toh sune sune heziea geche'],
#   ['Subhasish Basak', 'Dim the lights ee chalai'],
#   2],
#  [['Trisha Dey', 'Eita kon gaan?'],
#   ['Subhasish Basak', 'Ei toh bolli'],
#   ['Subhasish Basak', '???'],
#   ['Subhasish Basak', 'Ota ki gaan chilo na??'],
#   1],
#  [['Trisha Dey', 'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣'],
#   ['Subhasish Basak', 'Seriously???'],
#   ['Subhasish Basak', '🙈🙈🙈'],
#   1],
#  [['Trisha Dey', 'Eire. Tor to na kheyei obostha kharap'],
#   ['Trisha Dey', '🤣🤣'],
#   ['Subhasish Basak', 'Amio prothom ee tai bhablam......'],
#   ['Subhasish Basak', 'Seriously'],
#   ['Subhasish Basak', 'Porre tui bolli eta'],
#   2],
#  [['Trisha Dey', '🤣🤣'],
#   ['Subhasish Basak', 'Tai ami bhablam..ota seriously kono gaan'],
#   1],
#  [['Trisha Dey', 'Ritviz er gaan gulo amar favourite party songs I meant!'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Ei toh...dim the lights'],
#   1],
#  [['Trisha Dey', 'Eita ami jaantam e na 🤣'],
#   ['Subhasish Basak', 'Ki ????????'],
#   ['Subhasish Basak', 'Hey bhogoban🙈'],
#   1],
#  [['Trisha Dey', 'Ei gaan ta exist kore jaantam na'],
#   ['Trisha Dey', 'Ki coincidence er khela hocche bhai!!!'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   2],
#  [['Trisha Dey', 'Chena gaan chala!'],
#   ['Subhasish Basak', 'Mood chole elo re'],
#   ['Subhasish Basak', 'Puro full mood'],
#   1],
#  [['Trisha Dey', 'Elo?'], ['Subhasish Basak', 'Etai chaichilam'], 1],
#  [['Trisha Dey', 'R 4 mins'],
#   ['Subhasish Basak', 'Khaini ekhono monne acche'],
#   1],
#  [['Trisha Dey', '😌'], ['Subhasish Basak', 'Feelings tai toh ashol'], 1],
#  [['Trisha Dey', 'Akdom!'], ['Subhasish Basak', 'Moments guloi toh ashol'], 1],
#  [['Trisha Dey', '3 mins'],
#   ['Subhasish Basak', 'Booze toh just puro process ta k fast koree...rr ki'],
#   ['Subhasish Basak', 'My eyes on the clock'],
#   1],
#  [['Trisha Dey', '2 mins'],
#   ['Subhasish Basak', '\U0001f9d0'],
#   ['Subhasish Basak', '😖😖😖😖'],
#   ['Subhasish Basak', '😩😩😩😫😫'],
#   ['Subhasish Basak', 'Tule nao'],
#   ['Subhasish Basak', 'Ama k tule nao'],
#   1],
#  [['Trisha Dey', '1 min'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Party mood on'],
#   1],
#  [['Trisha Dey', '♥'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', 'START!'],
#   ['Subhasish Basak', 'Timestamp 10:29'],
#   ['Subhasish Basak', "Let's start"],
#   1],
#  [['Trisha Dey', '👏🏽'],
#   ['Trisha Dey', '😎'],
#   ['Trisha Dey', 'Kheli?'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Ki kopal amar'],
#   ['Subhasish Basak', 'Seal siddhi khule gelo'],
#   3],
#  [['Trisha Dey', 'Keno?'], ['Subhasish Basak', '😂😂😂😂'], 1],
#  [['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Byass rr chap nei....abar lagiea debo🤣🤣🤣🤣'],
#   1],
#  [['Trisha Dey', 'Emni ektu taste kore dekh agey'],
#   ['Subhasish Basak', 'Bishal smell'],
#   ['Subhasish Basak', '\U0001f92e\U0001f92e'],
#   ['Subhasish Basak', 'Khaini ekhono'],
#   1],
#  [['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'Bish puro'],
#   ['Subhasish Basak', 'Bish'],
#   ['Subhasish Basak', 'Beche thakbo toh'],
#   1],
#  [['Trisha Dey', 'Tahole khashna!!!'],
#   ['Subhasish Basak', 'Jai hok...bolechi jokhon ...khetey toh hobei'],
#   1],
#  [['Trisha Dey', 'Whiskey ta kha'],
#   ['Subhasish Basak', 'Nna na a'],
#   ['Subhasish Basak', 'Na na'],
#   1],
#  [['Trisha Dey', 'Akdom e na'], ['Subhasish Basak', 'Aaj k etai khabo'], 1],
#  [['Trisha Dey', '😒'],
#   ['Trisha Dey', 'Naa'],
#   ['Trisha Dey', 'Olpo kha'],
#   ['Subhasish Basak', '\U0001f92e\U0001f92e🤢'],
#   ['Subhasish Basak', 'Ki jali'],
#   ['Subhasish Basak', 'Jali rr jali'],
#   3],
#  [['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', 'Neshar dik theke positive naki negative?'],
#   ['Subhasish Basak', 'Puro jali\U0001f92e\U0001f92e'],
#   1],
#  [['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'Mukher bhetor ta jole gelo\U0001f92e'],
#   1],
#  [['Trisha Dey', 'R khashna. Rakh ota. JD kha.'],
#   ['Subhasish Basak', 'Hmm.'],
#   1],
#  [['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Trisha Dey', 'Mishti ta kha'],
#   ['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'Thank u so much'],
#   ['Subhasish Basak', 'Monne koranor jonno'],
#   3],
#  [['Trisha Dey', 'For what?'],
#   ['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'Monne hocche....petrol kheye nieachi😖'],
#   2],
#  [['Trisha Dey', 'Jol kha'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', '😶😶😶'],
#   ['Trisha Dey', 'R kichu khashna ajke'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Done and dusted'],
#   ['Subhasish Basak',
#    '5 mins por rr ek dhok khabo...asha korchi kaaj hoye jabe'],
#   2],
#  [['Trisha Dey', 'Shera dokan er laddu to 😌'],
#   ['Trisha Dey', 'Hoye jawar kotha. Tar por aro ekta khash laddu'],
#   ['Subhasish Basak', 'Duto khelam kintu'],
#   2],
#  [['Trisha Dey', 'Tahole r khashna'],
#   ['Subhasish Basak',
#    'Hobe toh botel....60moto kheyechi...tao abar...desi daru'],
#   ['Subhasish Basak', '😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁'],
#   ['Subhasish Basak', 'Ki moja'],
#   1],
#  [['Trisha Dey', 'Koto boro bottle ta??'],
#   ['Subhasish Basak', 'Ki moja'],
#   ['Subhasish Basak', 'Kichu measure lekha nei'],
#   ['Subhasish Basak', 'Kintu bishmall puro'],
#   ['Subhasish Basak', 'Ki bolbo'],
#   1],
#  [['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Issh'],
#   ['Subhasish Basak', 'Arrey lovely'],
#   ['Subhasish Basak', '😍'],
#   1],
#  [['Trisha Dey', 'Koto boro bottle ta? Dekhe mone hocche pite.'],
#   ['Subhasish Basak', 'Hote parre'],
#   ['Subhasish Basak', 'Ac chalai...gorom gorom laagche kintu halka halka'],
#   1],
#  [['Trisha Dey', 'Eitoh. Ebar ashol game 😌'],
#   ['Subhasish Basak', '60 neat desi daru'],
#   ['Subhasish Basak', '😁😁😁'],
#   ['Subhasish Basak', '😁😁😁'],
#   ['Subhasish Basak', '😁😁😁'],
#   ['Subhasish Basak', '😁😁😁'],
#   ['Subhasish Basak', 'Ki moja'],
#   ['Subhasish Basak', 'Thank u so much'],
#   ['Subhasish Basak', 'Idea tar jonno...'],
#   ['Subhasish Basak', 'Jd khele kichui hoto na....bekar'],
#   ['Subhasish Basak', 'Ei sob quarantine er din e desi daru chai'],
#   1],
#  [['Trisha Dey', '🤣🤣'],
#   ['Trisha Dey', 'Idea ta tor e chilo!'],
#   ['Trisha Dey', 'Amar idea to JD er chilo'],
#   ['Subhasish Basak', 'Mukher taste ta kemon change change hoye gelo....'],
#   ['Subhasish Basak', 'Jd khujtey giea ee toh....asol maal ta pelam'],
#   3],
#  [['Trisha Dey', 'Modh e to eishob hoyna 😶😶'],
#   ['Subhasish Basak', 'Hidden gem\U0001f92d'],
#   1],
#  [['Trisha Dey', 'Ekta chotto jinish korbi?'],
#   ['Subhasish Basak', 'Na na...kemon burnt taste'],
#   ['Subhasish Basak', 'Sob korbo'],
#   ['Subhasish Basak', 'Bol sudhu tui'],
#   ['Subhasish Basak', 'Bol'],
#   ['Subhasish Basak', 'Bol'],
#   ['Subhasish Basak', 'Bole fel'],
#   ['Subhasish Basak', 'Hoye jak'],
#   ['Subhasish Basak', 'Aaj k'],
#   ['Subhasish Basak', 'Bolei fel'],
#   ['Subhasish Basak', 'Hok'],
#   ['Subhasish Basak', 'Hok'],
#   ['Subhasish Basak', 'Aaj k hok'],
#   1],
#  [['Trisha Dey',
#    'Neck er exercise e jerom matha ta ghorae ektu du teen rouch ghuriye shoja rakh. Tarpor dekh kirom laage 🤣  But shabdhane, khaat e matha abar thuke felishna.'],
#   ['Subhasish Basak', '😍😍😍😍😍😍😍😍😍😍😍😍😝😝😝😝😝😝😝😝😝😝😝😍😍😍😍'],
#   1],
#  [['Trisha Dey', '*round'],
#   ['Subhasish Basak', 'Ki idea re'],
#   ['Subhasish Basak', 'Sabas'],
#   1],
#  [['Trisha Dey', '🤣🤣'],
#   ['Subhasish Basak', 'Sabas'],
#   ['Subhasish Basak', 'Ekhhuni korchi'],
#   1],
#  [['Trisha Dey', 'Careful'],
#   ['Trisha Dey', 'Matha thukishna kothao'],
#   ['Subhasish Basak', 'Ooooooooooooooooooooooo'],
#   ['Subhasish Basak', 'Ki dili'],
#   2],
#  [['Trisha Dey', '🤣🤣'], ['Subhasish Basak', 'Pagol hoye jabo amo'], 1],
#  [['Trisha Dey', 'Eigulo cheap tricks'],
#   ['Subhasish Basak', 'Puro bishmaal'],
#   ['Subhasish Basak', 'Rr oo bol'],
#   1],
#  [['Trisha Dey', 'Modh kom thaakle'],
#   ['Trisha Dey', 'Mishti ta r ekta cheap trick'],
#   ['Subhasish Basak', 'Ami Bonobo Kerala chalacchi'],
#   2],
#  [['Trisha Dey', '🤣🤣🤣'],
#   ['Trisha Dey',
#    "R ekta is smoking. But I wouldn't suggest that to any non-smoker"],
#   ['Subhasish Basak', 'Mood'],
#   2],
#  [['Trisha Dey', 'Kemon laagche?'],
#   ['Subhasish Basak', '😍'],
#   ['Subhasish Basak', 'Neck trick ta darun chilo'],
#   ['Subhasish Basak', 'Just sera'],
#   ['Subhasish Basak', '😘😘😘'],
#   ['Subhasish Basak', 'Pagol puro'],
#   1],
#  [['Trisha Dey', 'Eita shob shomoy kaaj kore'],
#   ['Trisha Dey', '😎😎'],
#   ['Subhasish Basak', '🤤🤤🤤'],
#   ['Subhasish Basak', 'Iss'],
#   2],
#  [['Trisha Dey', 'But r modh khashna.'], ['Subhasish Basak', 'Isshhhhhhh'], 1],
#  [['Trisha Dey', 'Ei shundor high ta thaak'],
#   ['Subhasish Basak', 'R ekbar'],
#   ['Subhasish Basak', 'Nahole puro ta mati hoye jabe'],
#   1],
#  [['Trisha Dey', 'Abar kal khash!'],
#   ['Subhasish Basak', 'Ekhon just...peak hocche'],
#   ['Subhasish Basak', 'Halka aasche'],
#   ['Subhasish Basak', 'Halka'],
#   1],
#  [['Trisha Dey', 'Tahole r olpo khabi'],
#   ['Subhasish Basak', 'Just halka'],
#   ['Subhasish Basak', 'Ami gems khacchi\U0001f92d\U0001f92d'],
#   1],
#  [['Trisha Dey', 'Pagla hoye jaabi tui 🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Na na smell ta katatey hobe'],
#   ['Subhasish Basak', 'Rr chocolate to process ta k enhance oo korbe'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   1],
#  [['Trisha Dey', 'Eita ki chilo!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣'],
#   ['Subhasish Basak', 'Gems khacchi'],
#   ['Subhasish Basak', 'Cadbury gems'],
#   ['Subhasish Basak', 'Kire'],
#   1],
#  [['Trisha Dey', 'Chocolate dopamine barae! Happy high!'],
#   ['Subhasish Basak', 'Gems khasni konodin'],
#   ['Subhasish Basak', '😁😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁'],
#   ['Subhasish Basak', '😁😁😁😁😁'],
#   1],
#  [['Trisha Dey',
#    'Arey maane jei stunt ta korli, dekhe khub moja laaglo. Atogulo gems akshonge kheye nili'],
#   ['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'Gems rrr oo achhe'],
#   ['Subhasish Basak', '2nd peg tar por khabo abar'],
#   2],
#  [['Trisha Dey', 'R laagbena'],
#   ['Trisha Dey', 'Ebar second peg ta mere bottle ta rekhe de'],
#   ['Subhasish Basak', 'Ami sober thakte thakte ekta kotha bol'],
#   2],
#  [['Trisha Dey', 'Bol'], ['Subhasish Basak', 'Ami toh rr ekta peg maarbo'], 1],
#  [['Trisha Dey', 'Yes'],
#   ['Trisha Dey', 'Not more than that'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Ok??'],
#   2],
#  [['Trisha Dey', 'Okay. But tar theke beshi na'],
#   ['Subhasish Basak', 'Ok ok'],
#   ['Subhasish Basak', 'Shon ebar'],
#   ['Subhasish Basak', 'Ebar ami eta tey jodi jol misiea di'],
#   ['Subhasish Basak', 'Tahole jinis ta nosto hoye jabe na toh???'],
#   ['Subhasish Basak', 'Becoz ami half bottle ta rakhte parbo na'],
#   1],
#  [['Trisha Dey',
#    'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.'],
#   ['Subhasish Basak', 'PLZZ plz'],
#   ['Subhasish Basak', 'Bol'],
#   ['Subhasish Basak', 'Ama k shei moto plan korte hobe...'],
#   ['Subhasish Basak', 'Nahole aaj kei sesh kore bottle ta fele debo'],
#   1],
#  [['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Trisha Dey', 'Akdom na.'],
#   ['Trisha Dey', 'Bottle ta bondho kore nijer bag e rekhe de apatoto.'],
#   ['Trisha Dey', 'Ami kalke jerom bhabe bolbo, rekhe dibi bottle ta.'],
#   ['Subhasish Basak', 'Bag ta dhuye dieache maa...bag nei amar ekhon'],
#   4],
#  [['Trisha Dey', 'Any locker that you have?'],
#   ['Subhasish Basak', 'Bottle ta jekhanee chilo okhanei rakhte hobe'],
#   ['Subhasish Basak', 'Jol mesano jay kinna bol'],
#   1],
#  [['Trisha Dey', 'Accha'],
#   ['Trisha Dey', 'Dara'],
#   ['Subhasish Basak', 'Ami eta next 2 -3 te sitting ee sesh kore debo'],
#   2],
#  [['Trisha Dey', 'Ajke r khabina'],
#   ['Subhasish Basak', 'In that case porer sitting gulo ektu diluted hobe'],
#   ['Subhasish Basak', 'Na keno'],
#   ['Subhasish Basak', 'Bollam toh ek peg'],
#   1],
#  [['Trisha Dey', 'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.'],
#   ['Trisha Dey', 'Filtered water meshash'],
#   ['Subhasish Basak', 'Locker ee k rakhe...chabi ber korte gelei dhora porbo'],
#   ['Subhasish Basak', 'Ekhon abar filter chalatey hobe????'],
#   ['Subhasish Basak', '😫'],
#   ['Subhasish Basak', 'Emni jol  ??'],
#   2],
#  [['Trisha Dey',
#    'Tahole porer sitting guloe diluted khash. Ajke r ek peg kheye rekhe de.'],
#   ['Trisha Dey', 'Bottle er jol o to filter er?'],
#   ['Subhasish Basak', 'Oh hya...same ee toh...tahole ki chap'],
#   2],
#  [['Trisha Dey', 'Jol er bottle theke jol dhele de'],
#   ['Subhasish Basak', 'Ok tahole ota sorted'],
#   ['Subhasish Basak', 'Notun problem.'],
#   ['Subhasish Basak', 'Smell ta ki korbo???'],
#   1],
#  [['Trisha Dey',
#    "Don't fill it to the brim though. Jerom modh er level chilo orom level obdhi jol diye rakh"],
#   ['Subhasish Basak', 'Rr ek peg khele bishal smell berobo😓'],
#   1],
#  [['Trisha Dey', 'Gaa diye gondho berocche?'],
#   ['Trisha Dey', 'Deo'],
#   ['Trisha Dey', 'Perfume'],
#   ['Subhasish Basak', 'Seta ami jani😌'],
#   3],
#  [['Trisha Dey', 'Puro AC er vent er shamne maar r nijer gaaye.'],
#   ['Subhasish Basak',
#    'Mukh theke smell aasche....jali smell...petrol er moto😥'],
#   ['Subhasish Basak', '😮😮😮'],
#   ['Subhasish Basak', 'Ki idea'],
#   ['Subhasish Basak', '👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻'],
#   ['Subhasish Basak', '👏🏻👏🏻👏🏻👏🏻👏🏻'],
#   1],
#  [['Trisha Dey', 'Chips ache barite? Lays?'],
#   ['Subhasish Basak', 'Haldirams bhujia'],
#   ['Subhasish Basak', 'Acche'],
#   1],
#  [['Trisha Dey', 'R ekta option'],
#   ['Trisha Dey', 'Mukhe ektu toothpaste r jol niye kulluchi kore fele de.'],
#   ['Subhasish Basak', 'Ooh....rr oo bhalo jinis acche 😍'],
#   2],
#  [['Trisha Dey', 'Nahole orbit jaatiyo barite kichu thaakle kheye ne'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', 'Ba listerine'], ['Subhasish Basak', '😁😁😁'], 1],
#  [['Trisha Dey', 'Arey! Chakna 😌'],
#   ['Subhasish Basak', 'Uff'],
#   ['Subhasish Basak', 'Ki mood😍😍😍'],
#   1],
#  [['Trisha Dey', '😌😌'],
#   ['Trisha Dey', 'Eigulo amader university tricks.'],
#   ['Subhasish Basak', 'Jemon jemon???'],
#   2],
#  [['Trisha Dey', 'We get exactly one hour to get high and then get that down'],
#   ['Trisha Dey', 'Toke ajke jotogulo trick bollam'],
#   ['Subhasish Basak', '🤣🤣🤣'],
#   ['Subhasish Basak',
#    '1.Neck trick 2. Laddu 3. Chocolate 4. Ritviz 5. Chakhna'],
#   2],
#  [['Trisha Dey',
#    'Loke modh kheye nesha hole, komanor jonno lebu khae. Oita akdom bhul approach. Jhaal kichu khelei the work is done.'],
#   ['Subhasish Basak', 'Ebaba...papad ta toh jhal'],
#   1],
#  [['Trisha Dey', 'Eita jene rakh. Life lesson.'],
#   ['Subhasish Basak', 'Ami khacchi keno😥'],
#   1],
#  [['Trisha Dey', 'Beshi khashna then'],
#   ['Subhasish Basak', 'Fele dieachi😒'],
#   1],
#  [['Trisha Dey', '🤣🤣🤣'],
#   ['Trisha Dey', 'Eki! Fele dili keno?'],
#   ['Trisha Dey', '🤦🏽\u200d♀'],
#   ['Subhasish Basak', 'R khabo ma'],
#   ['Subhasish Basak', '*na'],
#   3],
#  [['Trisha Dey', 'Oituku jhaal e kichu hobena!'],
#   ['Subhasish Basak',
#    'Halka j jinis ta esechilo....abar kintu shey cholle jacche😥'],
#   ['Subhasish Basak', 'Taake aatkabo ki kore ??'],
#   1],
#  [['Trisha Dey', 'Peg ta maar'],
#   ['Trisha Dey', 'Mere repeat the tricks'],
#   ['Trisha Dey', 'Neck trick 😌'],
#   ['Subhasish Basak', 'Eto joldi...tahole toh party sesh 🙈'],
#   ['Subhasish Basak', 'Ota ami last er jonno bachiea rakhtey chai'],
#   ['Subhasish Basak', 'Right'],
#   3],
#  [['Trisha Dey', 'Se to sesh hobei!'],
#   ['Subhasish Basak', 'With sage'],
#   ['Subhasish Basak', 'Naa 😭😭'],
#   1],
#  [['Trisha Dey', 'Yep 😌'],
#   ['Trisha Dey', 'Party suru hole to sesh hobei?'],
#   ['Subhasish Basak', 'Arre dhur'],
#   2],
#  [['Trisha Dey', 'Ki holo?'],
#   ['Subhasish Basak', 'Neck trick ta rr kaaj korche na'],
#   ['Subhasish Basak', '😭'],
#   ['Subhasish Basak', 'Eta teo resistance chole elo naki🙈'],
#   1],
#  [['Trisha Dey', 'Korbena to! High hote hobe.'],
#   ['Subhasish Basak', 'Naaaqaaaa'],
#   ['Subhasish Basak', 'Naaaqaqq'],
#   ['Subhasish Basak', 'Nananaanann'],
#   ['Subhasish Basak', 'Nana'],
#   ['Subhasish Basak', 'Naan'],
#   1],
#  [['Trisha Dey', 'Tahole abar ektu baade party suru korish 🤣'],
#   ['Subhasish Basak', 'Jeet sunchi'],
#   1],
#  [['Trisha Dey', 'Shon'],
#   ['Subhasish Basak', 'Rr chobi dekchi...'],
#   ['Subhasish Basak', 'Jodi kichu hoy😓'],
#   1],
#  [['Trisha Dey', 'Kisher chobi?'],
#   ['Trisha Dey', 'Ete hobena kichu! Ulte bad trip kheye jaabi!'],
#   ['Trisha Dey', 'Thik achish to?'],
#   ['Subhasish Basak', 'Chill'],
#   ['Subhasish Basak', 'Chap nei'],
#   ['Subhasish Basak', 'Neme geche puro ta...abar khela start korte hobe'],
#   ['Subhasish Basak', 'Khela hobe aaj k...'],
#   ['Subhasish Basak', 'Ekta jinis bujhlam'],
#   ['Subhasish Basak', 'Bishal jol teshta pacche...'],
#   ['Subhasish Basak', 'Dehydration hobe marattok'],
#   3],
#  [['Trisha Dey', 'Jol kha'],
#   ['Subhasish Basak', 'Rr oo ek bottle jol laagbe raat e'],
#   1],
#  [['Trisha Dey', 'Dehydration is what causes the hangover'],
#   ['Subhasish Basak', 'Last 30 min ee 1l jol khelam'],
#   ['Subhasish Basak', 'Smell chole geche'],
#   ['Subhasish Basak', 'Mood tao'],
#   1],
#  [['Trisha Dey', 'Abar hobe mood'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Chalalam...'],
#   ['Subhasish Basak', 'Asha kori mood aasbe'],
#   1],
#  [['Trisha Dey', 'Dekh ashe ki na'],
#   ['Subhasish Basak', 'Kokhon maarbo bol next peg ta ???'],
#   ['Subhasish Basak', 'Optimised ekta time bol'],
#   1],
#  [['Trisha Dey', '12ta'],
#   ['Trisha Dey', 'Dot'],
#   ['Subhasish Basak', '😮😮'],
#   ['Subhasish Basak', 'Iccha nei...but monne hocche otai best hobe'],
#   2],
#  [['Trisha Dey', 'Tahole khashna'],
#   ['Subhasish Basak', 'Sotti...salute to ur experience and suggestions'],
#   1],
#  [['Trisha Dey', 'Jor kore khashna'],
#   ['Subhasish Basak', 'Wait korar iccha nei😒'],
#   1],
#  [['Trisha Dey', '🤣'],
#   ['Trisha Dey', '11:45. Deal?'],
#   ['Subhasish Basak', 'Khawar iccha thakbena....ki bolis'],
#   ['Subhasish Basak', 'Na na 12...'],
#   ['Subhasish Basak', "Don't negotiate"],
#   ['Subhasish Basak', 'Ami nijeke control korchi'],
#   ['Subhasish Basak', 'Help kor'],
#   2],
#  [['Trisha Dey', 'Eitoh. Good good. 😌'],
#   ['Subhasish Basak', 'Tui toh control bhenge dicchis'],
#   1],
#  [['Trisha Dey', '12tar agey sudhu jol khaabi'],
#   ['Subhasish Basak', 'But ekta notul problem fell korchi'],
#   ['Subhasish Basak', 'Ok...sure ....ekdom'],
#   1],
#  [['Trisha Dey', 'Amae control korate bolle ja routine debo, maante parbina.'],
#   ['Trisha Dey', 'Ki??'],
#   ['Subhasish Basak', 'Na na..ota porre. Ek din hobbe ..aaj na🙏🏻'],
#   ['Subhasish Basak', 'Bole fel....'],
#   ['Subhasish Basak', 'Tui toh guess korte paris'],
#   ['Subhasish Basak', "Let's c"],
#   2],
#  [['Trisha Dey', 'Matha betha korche? Ba khub gorom laagche?'],
#   ['Subhasish Basak', 'Halka feel korchi'],
#   ['Subhasish Basak', 'Na na....gorom er problem solved'],
#   1],
#  [['Trisha Dey', 'Naki bomi pacche?'],
#   ['Subhasish Basak', 'Na na....ami ki kiddo naki😒'],
#   1],
#  [['Trisha Dey', 'Tui kiddo e 🤣🤣'],
#   ['Subhasish Basak', 'Ektu holeo experience acche'],
#   ['Subhasish Basak', 'Naaaaaaaaaaaaa'],
#   ['Subhasish Basak', 'Trina kiddo'],
#   ['Subhasish Basak', 'Ami na'],
#   1],
#  [['Trisha Dey', 'Tui mon theke kiddo!'],
#   ['Subhasish Basak', 'Seta alada byapar'],
#   ['Subhasish Basak', 'But ami booze kiddo na'],
#   ['Subhasish Basak', 'Ami booze pro'],
#   1],
#  [['Trisha Dey', 'Besh! Problem ki hocche bol'],
#   ['Subhasish Basak', 'Agge gaan bol'],
#   ['Subhasish Basak', 'Peye gechi'],
#   ['Subhasish Basak', 'In lamho k daman mey'],
#   ['Subhasish Basak', 'Bol tui bol'],
#   ['Subhasish Basak', 'Dekhi guessing power'],
#   1],
#  [['Trisha Dey', 'R guess er baire chole jacche. Boleifel'],
#   ['Subhasish Basak', 'Buring🔥 halka'],
#   ['Subhasish Basak', 'Mild'],
#   ['Subhasish Basak', 'But acche'],
#   1],
#  [['Trisha Dey', 'Oh'], ['Subhasish Basak', 'Persistence'], 1],
#  [['Trisha Dey', 'Heartburn hobei.'],
#   ['Subhasish Basak', 'Heart ee onk niche.... intestine er kache'],
#   1],
#  [['Trisha Dey', 'Ghumonor agey ekta antacid kheye ghumiye porish.'],
#   ['Subhasish Basak', 'Heart is fit'],
#   1],
#  [['Trisha Dey', 'Acid r gas hocche.'],
#   ['Subhasish Basak', 'Orebaba'],
#   ['Subhasish Basak', 'Eita ki game'],
#   1],
#  [['Trisha Dey', 'Eita game er rules'],
#   ['Subhasish Basak',
#    'Antacid khujtey gele ekhon abar bawal hobe...ota amar room ee nei🙈'],
#   ['Subhasish Basak', 'Jigges korbe...ki hoyeche...keno kiser jonno'],
# ...
#   1],
#  [['Trisha Dey', 'R mood esheo ki labh hoto? Khete to partish na :/'],
#   ['Subhasish Basak', '😖😖😖'],
#   ['Subhasish Basak', 'Mood is very precious ❤️'],
#   ['Subhasish Basak', 'Sob somoy thake na...'],
#   ['Subhasish Basak',
#    'In other words life ee sob theke important jinis ee holo *mood*😌'],
#   1],
#  [['Trisha Dey', 'Eita thik'],
#   ['Trisha Dey', 'Mood kharap thaakle shob kharap laage'],
#   ['Subhasish Basak', 'Moody bolle ekta company acche naa ?🤔'],
#   2],
#  [['Trisha Dey', 'Ache ache 🤣'],
#   ['Subhasish Basak', '\U0001f9da🏻\u200d♂️'],
#   1],
#  [['Trisha Dey', 'Tinker bell!'],
#   ['Subhasish Basak', 'Seta abar ki jinis??'],
#   1],
#  [['Trisha Dey', 'Petar Pan bole golpo tar ekta character'],
#   ['Trisha Dey', '*peter'],
#   ['Subhasish Basak', 'Oi dara'],
#   2],
#  [['Trisha Dey', 'Boshi?'],
#   ['Subhasish Basak', '🤦🏻\u200d♂️'],
#   ['Subhasish Basak', 'Accha...'],
#   1],
#  [['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'Have a goodnight (in advance)'],
#   ['Subhasish Basak', '😌'],
#   1],
#  [['Trisha Dey', 'Advance? 🤔'],
#   ['Trisha Dey', 'Tui akhon ghumote jaabina?'],
#   ['Trisha Dey', 'Tor movie dekhar time to sesh. 10-2 a.m.'],
#   ['Subhasish Basak',
#    'Hya...tui toh bolbi..j ami porre ghumabo....tai tor jonno..in advance'],
#   ['Subhasish Basak', 'Hay...ami chollam'],
#   3],
#  [['Trisha Dey', 'Amio. Ghum peye geche'], ['Subhasish Basak', '😵'], 1],
#  [['Trisha Dey', 'Goodnight (in advance)! 😌'],
#   ['Subhasish Basak', 'Yeh chamatkar hua kaise ??'],
#   1],
#  [['Trisha Dey', 'Eita jaanina. Mone hoy bekar bole aro ghum pacche ajkal'],
#   ['Subhasish Basak', '😂😂'],
#   ['Subhasish Basak', 'Have a goodnight 😴'],
#   1],
#  [['Trisha Dey', '\U0001f971😴'],
#   ['Trisha Dey', 'Good afternoon, sir 😎'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   2],
#  [['Trisha Dey', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'onk din friends dekha hoy na'],
#   ['Subhasish Basak', 'watch friends😂'],
#   1],
#  [['Trisha Dey', 'Dekh dekh! Akhoni to shomoy!'],
#   ['Subhasish Basak', 'ami Money heist ta sesh korlam....uff chorom chilo'],
#   ['Subhasish Basak', 'dekhis ota...darun laagbe'],
#   1],
#  [['Trisha Dey', 'Bella ciao 😌'],
#   ['Trisha Dey', 'Dekhbo!'],
#   ['Trisha Dey', 'https://youtu.be/ePz5ztDnMa4'],
#   ['Subhasish Basak', '🤣🤣🤣hebby chilo eta'],
#   3],
#  [['Trisha Dey', '😌'],
#   ['Subhasish Basak', 'Ei lok ta sob somoy ee high thake 😂'],
#   1],
#  [['Trisha Dey', 'Darun lage ei channel ta amar'],
#   ['Subhasish Basak', 'Accha ei lok tar liver kharap hoy na kno ??🤔'],
#   1],
#  [['Trisha Dey', 'Karon o banae. Khaena oto hoyto 😌'],
#   ['Subhasish Basak', 'Bhogoban naki....😂 Eto control'],
#   ['Subhasish Basak', 'Aaj k class chilo...5:30 theke..bhulei gechilm...'],
#   ['Subhasish Basak', '🙈'],
#   1],
#  [['Trisha Dey', 'Trina to korche mone hoy'],
#   ['Trisha Dey', 'Join kore ne akhon'],
#   ['Trisha Dey', 'Amar class cancel hoye gelo'],
#   ['Trisha Dey', '🤦🏽\u200d♀️'],
#   ['Subhasish Basak', 'Ami join korlam...'],
#   ['Subhasish Basak', 'Keno bristi porche bolle😅😂'],
#   4],
#  [['Trisha Dey', 'Brishti porche? 😶'],
#   ['Trisha Dey', 'Ami room e boshe bujhteo parini'],
#   ['Subhasish Basak', 'Porchilo olpo olpo'],
#   ['Subhasish Basak', 'Kal ker moto noy'],
#   2],
#  [['Trisha Dey', 'Kalke to brishti porar por gorom bere gelo'],
#   ['Subhasish Basak', 'Sukno gorom☹️😒'],
#   ['Subhasish Basak', 'Dry heat☹️😒'],
#   1],
#  [['Trisha Dey', 'Dry heat koi?'],
#   ['Trisha Dey', 'Prochondo humid'],
#   ['Subhasish Basak', 'ei dry shei dry noy'],
#   2],
#  [['Trisha Dey', 'Tahole ei dry kon dry?'],
#   ['Subhasish Basak', 'Boozantine'],
#   ['Subhasish Basak', 'er dryness'],
#   ['Subhasish Basak', '\U0001f92d😂😂'],
#   1],
#  [['Trisha Dey', 'Bujhlam 🤣🤣🤣'],
#   ['Trisha Dey', 'Noboborsho to kalker por hobe!'],
#   ['Trisha Dey', 'শুভ নববর্ষ। ❤'],
#   ['Subhasish Basak',
#    'আপনার বাড়ির গুরুজন দের প্রতি আমার প্রনাম এবং আপনি ও আপনার ছোটবোন এর প্রতি আন্তরিক ভালোবাসা ও শুভেচ্ছা রইল। 😌🙏🏻'],
#   3],
#  [['Trisha Dey', 'Arey! 🤣🤣'],
#   ['Subhasish Basak', '😌😌'],
#   ['Subhasish Basak', 'Eta ki chilo??'],
#   1],
#  [['Trisha Dey', 'Arey guliye felechilam'],
#   ['Trisha Dey', 'I thought today is 13th'],
#   ['Subhasish Basak', 'Roj roj 5am ghumate gele ei hoy'],
#   2],
#  [['Trisha Dey', 'Arey ghum ashena. Ki korbo??'],
#   ['Subhasish Basak', 'Ghum asena ..'],
#   ['Subhasish Basak', 'Esob symptoms toh bhalo noy\U0001f92d'],
#   1],
#  [['Trisha Dey', 'Keno keno?'],
#   ['Subhasish Basak', 'I have to investigate the reasons..'],
#   ['Subhasish Basak', 'Why u have to spend sleepless nights'],
#   ['Subhasish Basak', '😌'],
#   1],
#  [['Trisha Dey', 'Kobe theke suru korbi investigation, detective Basak? 😌'],
#   ['Subhasish Basak', 'Okay..'],
#   ['Subhasish Basak', 'Let me see'],
#   1],
#  [['Trisha Dey', '🤔'],
#   ['Subhasish Basak',
#    'Based on my quick research I have found 2 probable reasons'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   1],
#  [['Trisha Dey', '🤣'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'Which one do u prefer ??'],
#   1],
#  [['Trisha Dey', "Now I'm confused 😌🤣"],
#   ['Trisha Dey',
#    "I'd prefer this but unfortunately I know that reason 1 is the only correct option I guess 😪🤣"],
#   ['Subhasish Basak', 'Eto tym lege gelo🤣'],
#   ['Subhasish Basak', 'Then case closed'],
#   ['Subhasish Basak', 'Amar fees ta pathiea deben...ekta blue label😌'],
#   2],
#  [['Trisha Dey', '🤣🤣🤣'],
#   ['Trisha Dey', 'Peye jaben blue label 😌'],
#   ['Trisha Dey', 'Kintu akhon noe'],
#   ['Trisha Dey', '😌'],
#   ['Trisha Dey', 'Call e chilam ekta!'],
#   ['Subhasish Basak', 'Aaj k Subho din ee Subho kaaj ee nemechi'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   5],
#  [['Trisha Dey', 'Tui guitar bajash?!?!'],
#   ['Trisha Dey', 'Jantam na to! 🤔'],
#   ['Subhasish Basak', 'Karaoke gaibo😎🤣'],
#   2],
#  [['Trisha Dey', 'Ke guitar bajae tor barite?'],
#   ['Subhasish Basak', 'Big brother'],
#   1],
#  [['Trisha Dey', 'Nice nice!'],
#   ['Trisha Dey', 'You must be busy with your family now. Pore kotha bolish.'],
#   ['Subhasish Basak', 'Family time onk hoye geche...😝'],
#   2],
#  [['Trisha Dey', 'Karaoke hoye gelo already?!'],
#   ['Subhasish Basak', 'Hya ..gola boshe geche'],
#   ['Subhasish Basak', '🤐'],
#   1],
#  [['Trisha Dey', 'Ebaba 😨'],
#   ['Subhasish Basak', '🤧'],
#   ['Subhasish Basak', 'Aaj k setup ta holo...kal theke recording korbo😁'],
#   1],
#  [['Trisha Dey', 'Accha accha'],
#   ['Trisha Dey', 'Ajke kon movie dekha hocche?'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   2],
#  [['Trisha Dey', '🤦🏽\u200d♀️🤦🏽\u200d♀️'],
#   ['Subhasish Basak', 'Evergreen movi'],
#   1],
#  [['Trisha Dey', '😝😝'],
#   ['Trisha Dey', 'Kolkatae ebar theke liquor er home delivery hobe'],
#   ['Trisha Dey', 'The off-shops will be delivering. 😌'],
#   ['Subhasish Basak', 'Ami toh sunlam..pincon  dada ekhon 500/ bottle😅'],
#   ['Subhasish Basak',
#    'Shei hiseb ee RC ekhon black label er daam e sell hocche'],
#   3],
#  [['Trisha Dey', '😨😨'],
#   ['Trisha Dey', 'Eishob kothae shunli?'],
#   ['Subhasish Basak', 'Amader dokan eer ekhon bolchilo baba k...'],
#   ['Subhasish Basak', 'Ogulor daam 85 ...ekhon naki 500 tey black hocche'],
#   2],
#  [['Trisha Dey', '😶😶😶😶'],
#   ['Trisha Dey', 'Er theke to alcohol khawa chere dewai bhalo'],
#   ['Subhasish Basak', 'jara addicted tara ki korbe !!'],
#   ['Subhasish Basak', 'sobai ki rr promise korte paare😌'],
#   2],
#  [['Trisha Dey', 'Tader kopale dukkho ache'], ['Subhasish Basak', '😆'], 1],
#  [['Trisha Dey',
#    'Paare. Kotojon promise kore seta rakhte paare is the question 😌'],
#   ['Subhasish Basak', 'thik acche..thik acche'],
#   ['Subhasish Basak',
#    "ami kintu 5 days without booze acchi...I'm keeping my promise"],
#   1],
#  [['Trisha Dey', '7 days hoar kotha to 🤔'],
#   ['Subhasish Basak', 'Oh really😍'],
#   ['Subhasish Basak', '9th ee resolution nieachilm'],
#   1],
#  [['Trisha Dey', 'Yep'],
#   ['Trisha Dey', 'Tarpor kheyechish naki?'],
#   ['Trisha Dey', '😯'],
#   ['Subhasish Basak', 'noooooo'],
#   ['Subhasish Basak', "ekdom na...I'm strict on my rules"],
#   3],
#  [['Trisha Dey', 'Good boy! 😝'],
#   ['Subhasish Basak',
#    'ami aaj ker din ta k ekhono count korini...k jaane ki hoye jay😝'],
#   ['Subhasish Basak', '🤣🤣'],
#   1],
#  [['Trisha Dey', 'Promise kore bhenge dibi? Okay. 😌'],
#   ['Subhasish Basak', "I'll not let ur hopes down"],
#   ['Subhasish Basak',
#    'kothin kaaj .... promise korar agge bhabini erokom oo hote paare'],
#   ['Subhasish Basak',
#    'j jinis ta baron kora thake...baar baar otar kothai mone pore'],
#   1],
#  [['Trisha Dey',
#    "Yaarki maarchilam. I have complete faith in you. I know you won't break your promise. 😌"],
#   ['Subhasish Basak', 'ei sob er chokkor ee Irish coffee er plan tao gelo😒'],
#   1],
#  [['Trisha Dey', 'Agey lockdown to sesh hok! Irish house o hobe 😌'],
#   ['Subhasish Basak', 'otao ki banatey parbo na??\U0001f97a'],
#   1],
#  [['Trisha Dey', 'Oh irish coffee!'],
#   ['Trisha Dey', 'Banate parbi kintu khete parbina.'],
#   ['Subhasish Basak', 'eeki???????'],
#   2],
#  [['Trisha Dey', 'Er theke ekta month wait kore ne.'],
#   ['Trisha Dey', 'Tarpor  banash'],
#   ['Subhasish Basak', 'esob ki kotha?'],
#   2],
#  [['Trisha Dey', 'No booze kor a month 😶'],
#   ['Subhasish Basak', 'lock down uthe gele rr k banabe'],
#   1],
#  [['Trisha Dey', 'That was the promise!'],
#   ['Trisha Dey', 'Lockdown akhono cholbe 2 months'],
#   ['Subhasish Basak', 'ami ki tahole cough syrup oo khabo na??'],
#   2],
#  [['Trisha Dey',
#    'Bhab lockdown er por shob bondhuder shonge banate parbi irish coffee 😌'],
#   ['Trisha Dey', 'Nope 😝'],
#   ['Subhasish Basak', '🤦🏻\u200d♂️🤦🏻\u200d♂️'],
#   2],
#  [['Trisha Dey',
#    'Toke bolechilam na, amae control korte bolle ami ja regime debo, r kono upay thaakbena tor 🤣'],
#   ['Trisha Dey',
#    'Dekh, jerom 23rd April e one month hoye jabe since I last had a smoke.'],
#   ['Trisha Dey', 'R booze to already ek maash hoye geche khaini.'],
#   ['Subhasish Basak',
#    'smoking is not good !! Ota plzz give up....Its a request🙏🏻'],
#   3],
#  [['Trisha Dey',
#    'March e exactly 3 din kheyechilam. Du din toder shonge r ek din Kolkatae fire. 14th March.'],
#   ['Trisha Dey', 'Done.'],
#   ['Subhasish Basak', 'eto joldi hya bole dili??'],
#   ['Subhasish Basak', 'jak bhalo kotha'],
#   2],
#  [['Trisha Dey',
#    'Amar kache akhono cig pore ache kintu ami khabona. Kono bondhu ke diye debo ba fele debo after the lockdown'],
#   ['Subhasish Basak', 'kao k dite hobe naa....'],
#   ['Subhasish Basak', 'fele dey'],
#   1],
#  [['Trisha Dey',
#    "Ha. I do smoke but I'm not addicted to it. I usually like smoking when boozing. Tokhon khub craving hoe. Kintu chesta to korte hobe charar."],
#   ['Trisha Dey', 'Accha fele debo'],
#   ['Subhasish Basak', 'smoking + boozing.....koto sokh🤤\U0001f92d'],
#   ['Subhasish Basak', '+ driving'],
#   ['Subhasish Basak', '= jail-ing'],
#   2],
#  [['Trisha Dey',
#    'I never drink and drive because neither do I support it, nor do I know how to drive 🤣'],
#   ['Subhasish Basak',
#    'ami toh bolbo life ee sob ee ekbar try kora uchit...at least once'],
#   ['Subhasish Basak', 'nahole rr ki lyf enjoy korli !!'],
#   1],
#  [['Trisha Dey', "Nope nope. I don't believe in this."],
#   ['Trisha Dey',
#    'Life kotota enjoy korlam depends on the time that I spend doing things that I like and spending quality time with my loved ones! Ha majhe majhe ektu paglami bhalo kintu tabole shob try kora jaena!'],
#   ['Subhasish Basak', 'eto puro Trina rr moto kotha bolchis...same words😅'],
#   ['Subhasish Basak', 'but Trina k toh convince kore nilei oo raji hoye jeto'],
#   ['Subhasish Basak', 'does the same applies for u ?😜'],
#   2],
#  [['Trisha Dey', 'Nope nope 🤣'],
#   ['Trisha Dey', 'The same does not apply for me'],
#   ['Trisha Dey', "I'm very difficult to convince once I know what I want."],
#   ['Subhasish Basak', 'challange accepted...!!!'],
#   ['Subhasish Basak', "I'll convince u...someday ....somplace...on something"],
#   ['Subhasish Basak', 'let me see how difficult it is'],
#   ['Subhasish Basak', '😎'],
#   3],
#  [['Trisha Dey', 'Challenge?! Okay. Besh. Dekha jabe 😌'],
#   ['Trisha Dey', '😍'],
#   ['Subhasish Basak', 'Boozantinne😒😢'],
#   2],
#  [['Trisha Dey', 'After one month'], ['Subhasish Basak', '20 days🤔'], 1],
#  [['Trisha Dey', 'Yep'],
#   ['Trisha Dey', '20 days'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   2],
#  [['Trisha Dey', 'Kisher line?'],
#   ['Subhasish Basak', 'Eta 5 min porre'],
#   ['Subhasish Basak', 'Kiser abar😅😌'],
#   1],
#  [['Trisha Dey', 'Police tara koreche? 🤦🏽\u200d♀️'],
#   ['Subhasish Basak', 'Hya🤣🤣'],
#   1],
#  [['Trisha Dey', 'Oh. Liquor shops'],
#   ['Subhasish Basak', 'Papi mon er jala'],
#   1],
#  [['Trisha Dey', 'Ki obostha 🤦🏽\u200d♀️🤦🏽\u200d♀️🤦🏽\u200d♀️'],
#   ['Trisha Dey',
#    'Trinar kach theke shunlam toder monday theke exams suru hobe in the form of assignments. All the best! 👍🏽'],
#   ['Subhasish Basak', 'ki ???😱😱'],
#   ['Subhasish Basak', 'Hurrr...Monday theke abar kiser exam'],
#   ['Subhasish Basak', 'Maybe she has...amar kono exam ee nei😅'],
#   2],
#  [['Trisha Dey', 'Maane?'],
#   ['Trisha Dey', '😶'],
#   ['Subhasish Basak', 'ekta acche tao abar 25th ee..onk deri'],
#   ['Subhasish Basak', 'but ota xm noy...ekta assignment just'],
#   ['Subhasish Basak', 'byass'],
#   2],
#  [['Trisha Dey', 'Tahole to bhaloo'],
#   ['Trisha Dey', '*bhaloi'],
#   ['Subhasish Basak', 'ami ekdom minimal courses nieachi...just to pass😁😁'],
#   ['Subhasish Basak', 'aur batao...'],
#   ['Subhasish Basak', 'kya chal raha hay ?'],
#   2],
#  [['Trisha Dey', 'Only classes and assignments 😪'],
#   ['Subhasish Basak', 'ohh ho...'],
#   ['Subhasish Basak', 'noting new'],
#   1],
#  [['Trisha Dey', 'Nope. Nothing new'],
#   ['Trisha Dey', 'Tor?'],
#   ['Subhasish Basak',
#    'ami  bhablam kichu notun suggestions, experiment er idea dibi..ami try korbo'],
#   2],
#  [['Trisha Dey', 'Idea ditei pari'],
#   ['Trisha Dey', 'Kintu try korar shomoy nei'],
#   ['Subhasish Basak', 'please..'],
#   2],
#  [['Trisha Dey', 'Dara'],
#   ['Subhasish Basak', 'idea toh bol'],
#   ['Subhasish Basak', 'baapre...itna busy🙄'],
#   1],
#  [['Trisha Dey', 'Crème brûlée bana.'],
#   ['Subhasish Basak', '😱'],
#   ['Subhasish Basak', 'naam ta sune toh mood chole elo'],
#   1],
#  [['Trisha Dey', 'Amar prochondo ghum bere geche. Mane khub ghumocchi'],
#   ['Trisha Dey', 'In fact eita tui e pathiyechilish amae I guess'],
#   ['Subhasish Basak', 'ami kobe pathalam??'],
#   ['Subhasish Basak', 'accha oi dessert ta!!'],
#   2],
#  [['Trisha Dey', 'Ha'],
#   ['Trisha Dey', "You'll need ice cream, sugar and an egg yolk."],
#   ['Subhasish Basak', 'ice cream kothaye pabo😢'],
#   ['Subhasish Basak', 'emni Amul creme acche...ota diea kora jete pare'],
#   2],
#  [['Trisha Dey', 'Ummm oita diye hobe ki na janina'],
#   ['Subhasish Basak',
#    'arre ami j video ta pathieachilam...ota tey khub easy recipe dehieachilo..ota dekhi'],
#   1],
#  [['Trisha Dey', 'Oitai bollam to 😶'],
#   ['Trisha Dey', '3 ingredient recipe eitai chilo'],
#   ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#   2],
#  [['Trisha Dey', 'Joke ta bujhlam na to 🤔'],
#   ['Subhasish Basak', "It's not a joke"],
#   ['Subhasish Basak',
#    'The guy also learnt this recipe from his friend named Rie'],
#   1],
#  [['Trisha Dey', 'Rie naam hoy re 🤣'],
#   ['Trisha Dey', "Wait I'll show you who Rie is!"],
#   ['Subhasish Basak', "That's another coincidence😂😂"],
#   2],
#  [['Trisha Dey', 'Amar daak naam to Rai! Not Rie! 🤣'],
#   ['Subhasish Basak', 'Pronounciation ta toh same'],
#   ['Subhasish Basak', 'রাই।'],
#   ['Subhasish Basak', 'Tai toh.??'],
#   1],
#  [['Trisha Dey', 'Na na. Rie er pronunciation is  banglar ree.'],
#   ['Trisha Dey', 'Eita amar naam er pronunciation.'],
#   ['Trisha Dey', "Na wait. It's ree-a"],
#   ['Subhasish Basak', '😒'],
#   3],
#  [['Trisha Dey', 'The pronunciation of Rie'],
#   ['Subhasish Basak', 'Ami oto kichu jani na'],
#   1],
#  [['Trisha Dey', 'https://youtu.be/dP6V5ldIym0'],
#   ['Trisha Dey', 'Eita is Rie 🤣'],
#   ['Subhasish Basak', 'Rai == Rie'],
#   2],
#  [['Trisha Dey', 'Besh 🤣🤣'],
#   ['Subhasish Basak', 'Is that the friend he was referring ??'],
#   1],
#  [['Trisha Dey', 'Yes'],
#   ['Trisha Dey', 'Dujonei tasty er producers'],
#   ['Subhasish Basak', '😳😵'],
#   2],
#  [['Trisha Dey', 'Yes!'], ['Subhasish Basak', 'Okay...eta notun jaanlam'], 1],
#  ...]

# %%
# code for generating all possible incoming-outgoing pairs within each block

final = []

for block in blocks:
    block_expanded = []
    incoming_num = block[-1]
    outgoing_num = len(block) -1 - incoming_num
    
    incoming_block = block[:incoming_num]
    outgoing_block = block[incoming_num:-1]
    
    for i in incoming_block:
        for j in outgoing_block:
            final.append(i)
            final.append(j)

# %%
final
# Out:
# [['Trisha Dey', 'Permission granted XD'],
#  ['Subhasish Basak', 'Sobe toh shuru korlam'],
#  ['Trisha Dey', 'Permission granted XD'],
#  ['Subhasish Basak', '5 April deadline jodio...onk tym acche'],
#  ['Trisha Dey', 'Assignment kotdur?'],
#  ['Subhasish Basak', 'Sobe toh shuru korlam'],
#  ['Trisha Dey', 'Assignment kotdur?'],
#  ['Subhasish Basak', '5 April deadline jodio...onk tym acche'],
#  ['Trisha Dey',
#   'Amar laptop e beshi kaaj korle matha dhore jae. Tora kikore korish 😓'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Seri'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Same kotha ta ami aritra k bolechilam...'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Exactly the same words'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', 'Tomay pronam'],
#  ['Trisha Dey', 'Scotch opomaanito holo.'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻🙏🏻'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Subhasish Basak', 'Ki jataah'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Subhasish Basak', 'Thug lyf hoye gelo😢'],
#  ['Trisha Dey', 'Arey ki birokto laagche'],
#  ['Subhasish Basak', 'Ki jataah'],
#  ['Trisha Dey', 'Arey ki birokto laagche'],
#  ['Subhasish Basak', 'Thug lyf hoye gelo😢'],
#  ['Trisha Dey', 'R stock tulteo parbona'],
#  ['Subhasish Basak', 'Ki jataah'],
#  ['Trisha Dey', 'R stock tulteo parbona'],
#  ['Subhasish Basak', 'Thug lyf hoye gelo😢'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak',
#   'Aaj kal khub busy monne hocche\U0001f9d0...online dekha jay na aapna k'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', 'Ki korre busy thaka jay...amader oo bol ektu'],
#  ['Trisha Dey', 'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!'],
#  ['Subhasish Basak', 'Assignment kotha theke chole elo abar😒'],
#  ['Trisha Dey', 'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!'],
#  ['Subhasish Basak', 'Assignment jali ..'],
#  ['Trisha Dey', 'Tor assignment kotdur?'],
#  ['Subhasish Basak', 'Assignment kotha theke chole elo abar😒'],
#  ['Trisha Dey', 'Tor assignment kotdur?'],
#  ['Subhasish Basak', 'Assignment jali ..'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak',
#   'Amar toh raat eeo ghum aaseena😥...ki obostha... corona rr bazar ee insomnia hoye gelo mone hoy'],
#  ['Trisha Dey', 'Tai naaki?'],
#  ['Subhasish Basak', 'Cmi tey thakte khub kom ghumatam'],
#  ['Trisha Dey', 'E to amaro same obostha'],
#  ['Subhasish Basak', 'Cmi tey thakte khub kom ghumatam'],
#  ['Trisha Dey', 'Ami just bari theke berote chai'],
#  ['Subhasish Basak', 'Tar ee effect hoyto'],
#  ['Trisha Dey', 'Ami just bari theke berote chai'],
#  ['Subhasish Basak', 'Sobai chai'],
#  ['Trisha Dey',
#   'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.'],
#  ['Subhasish Basak', 'Ekhon kothaye tora ??'],
#  ['Trisha Dey',
#   'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.'],
#  ['Subhasish Basak', 'Mamar bari tei ?'],
#  ['Trisha Dey', 'Amar ghumiye ghumiye matha dhore jacche'],
#  ['Subhasish Basak', 'Ekhon kothaye tora ??'],
#  ['Trisha Dey', 'Amar ghumiye ghumiye matha dhore jacche'],
#  ['Subhasish Basak', 'Mamar bari tei ?'],
#  ['Trisha Dey', '😓'],
#  ['Subhasish Basak', 'Ekhon kothaye tora ??'],
#  ['Trisha Dey', '😓'],
#  ['Subhasish Basak', 'Mamar bari tei ?'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Subhasish Basak', 'Kno mamar bari keno jabi ??'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Subhasish Basak', 'K acche ??'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Subhasish Basak', 'Or'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Subhasish Basak', 'Ki acche??'],
#  ['Trisha Dey', 'Na na. Barite.'],
#  ['Subhasish Basak', '🤔'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', 'Kno mamar bari keno jabi ??'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', 'K acche ??'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', 'Or'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', 'Ki acche??'],
#  ['Trisha Dey', 'Mamarbari jete dicchena 😭'],
#  ['Subhasish Basak', '🤔'],
#  ['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#  ['Subhasish Basak', '😆'],
#  ['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#  ['Subhasish Basak', 'Eto chap nis na'],
#  ['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#  ['Subhasish Basak', 'Aaste aaste sob habituated hoye jabo amra'],
#  ['Trisha Dey', 'Kichuina. Just bari theke berote chai!!'],
#  ['Subhasish Basak', 'Eta ekhono onk din ee cholbe ja monne hoy'],
#  ['Trisha Dey', 'Ami pagol hoye jaabo'],
#  ['Subhasish Basak', '😆'],
#  ['Trisha Dey', 'Ami pagol hoye jaabo'],
#  ['Subhasish Basak', 'Eto chap nis na'],
#  ['Trisha Dey', 'Ami pagol hoye jaabo'],
#  ['Subhasish Basak', 'Aaste aaste sob habituated hoye jabo amra'],
#  ['Trisha Dey', 'Ami pagol hoye jaabo'],
#  ['Subhasish Basak', 'Eta ekhono onk din ee cholbe ja monne hoy'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', '😆'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', 'Eto chap nis na'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', 'Aaste aaste sob habituated hoye jabo amra'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', 'Eta ekhono onk din ee cholbe ja monne hoy'],
#  ['Trisha Dey',
#   'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.'],
#  ['Subhasish Basak', 'Bari ta just hotel naki\U0001f92d'],
#  ['Trisha Dey',
#   'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.'],
#  ['Subhasish Basak', "Papa's hotel"],
#  ['Trisha Dey', 'Ami thaakte parchina r barite'],
#  ['Subhasish Basak', 'Bari ta just hotel naki\U0001f92d'],
#  ['Trisha Dey', 'Ami thaakte parchina r barite'],
#  ['Subhasish Basak', "Papa's hotel"],
#  ['Trisha Dey', 'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭'],
#  ['Subhasish Basak', 'Babare...tui oo booze er jonno pagol hoye jacchis'],
#  ['Trisha Dey', 'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭'],
#  ['Subhasish Basak', 'Booze kintu control ee khete hobe...naholei case'],
#  ['Trisha Dey', 'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭'],
#  ['Subhasish Basak', 'Besi booze khawa bhalo na😌'],
#  ['Trisha Dey', 'Almost 🤣🤣🤣'],
#  ['Subhasish Basak', 'Babare...tui oo booze er jonno pagol hoye jacchis'],
#  ['Trisha Dey', 'Almost 🤣🤣🤣'],
#  ['Subhasish Basak', 'Booze kintu control ee khete hobe...naholei case'],
#  ['Trisha Dey', 'Almost 🤣🤣🤣'],
#  ['Subhasish Basak', 'Besi booze khawa bhalo na😌'],
#  ['Trisha Dey', 'Jaani. 😓'],
#  ['Subhasish Basak', 'Tym paas kor'],
#  ['Trisha Dey', 'But birokto laagche'],
#  ['Subhasish Basak', 'Tym paas kor'],
#  ['Trisha Dey', 'Ekta nip o thaakle roj ek drop kore khetam 🤣'],
#  ['Subhasish Basak', 'Any hobbies ?? Drawing movies etc!??'],
#  ['Trisha Dey', 'Ekta nip o thaakle roj ek drop kore khetam 🤣'],
#  ['Subhasish Basak', 'Comics acche toh'],
#  ['Trisha Dey', 'I do sketch like Titir. But ajkal oitao korte lyadh laagche'],
#  ['Subhasish Basak', 'Hmm'],
#  ['Trisha Dey', 'I do sketch like Titir. But ajkal oitao korte lyadh laagche'],
#  ['Subhasish Basak', 'Cooking ???'],
#  ['Trisha Dey',
#   'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭'],
#  ['Subhasish Basak', 'Arre dhur🙈'],
#  ['Trisha Dey',
#   'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭'],
#  ['Subhasish Basak', 'Chicken banano toh 60ml peg bananor thekeo soja'],
#  ['Trisha Dey', 'Sudhu chicken banate paari. 😅'],
#  ['Subhasish Basak', 'Arre dhur🙈'],
#  ['Trisha Dey', 'Sudhu chicken banate paari. 😅'],
#  ['Subhasish Basak', 'Chicken banano toh 60ml peg bananor thekeo soja'],
#  ['Trisha Dey', 'Ekta sketch dekhbi?'],
#  ['Subhasish Basak', 'Lasagna ..pasta...esob bana'],
#  ['Trisha Dey', 'Ekta sketch dekhbi?'],
#  ['Subhasish Basak', 'Yes pls...😁'],
#  ['Trisha Dey', 'Eire. Otou shoja na!!!😶😶😶'],
#  ['Subhasish Basak',
#   'When I say that...I mean not a single drop should fall out of the peg measure😌'],
#  ['Trisha Dey', 'Pasta banate pari'],
#  ['Subhasish Basak',
#   'When I say that...I mean not a single drop should fall out of the peg measure😌'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak',
#   'When I say that...I mean not a single drop should fall out of the peg measure😌'],
#  ['Trisha Dey', 'Lasagna ta konodin try korini jodio'],
#  ['Subhasish Basak', '😮😮😮😮😮'],
#  ['Trisha Dey', 'Lasagna ta konodin try korini jodio'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Lasagna ta konodin try korini jodio'],
#  ['Subhasish Basak', 'U did that'],
#  ['Trisha Dey', 'Wait korchilam je kokhon eta bolbi 🤣🤣🤣'],
#  ['Subhasish Basak', '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂'],
#  ['Trisha Dey', 'Wait korchilam je kokhon eta bolbi 🤣🤣🤣'],
#  ['Subhasish Basak', 'Why why'],
#  ['Trisha Dey', 'Wait korchilam je kokhon eta bolbi 🤣🤣🤣'],
#  ['Subhasish Basak', 'Keno'],
#  ['Trisha Dey', 'Yep 😝'],
#  ['Subhasish Basak', '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂'],
#  ['Trisha Dey', 'Yep 😝'],
#  ['Subhasish Basak', 'Why why'],
#  ['Trisha Dey', 'Yep 😝'],
#  ['Subhasish Basak', 'Keno'],
#  ['Trisha Dey', 'Eki? Keno, keno?'],
#  ['Subhasish Basak', 'Why wasting ur talent'],
#  ['Trisha Dey', 'Eki? Keno, keno?'],
#  ['Subhasish Basak', 'Eta over professional'],
#  ['Trisha Dey', 'Eki? Keno, keno?'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#  ['Subhasish Basak', 'Bolchi...'],
#  ['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#  ['Subhasish Basak', 'Esob bolis na'],
#  ['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#  ['Subhasish Basak', 'Just .. printed monne hocche'],
#  ['Trisha Dey', 'R talent gangar jole bheshe geche!'],
#  ['Subhasish Basak', 'Great job👏🏻👏🏻'],
#  ['Trisha Dey',
#   "Ek shomoy khub interest chilo art and animation niye kaaj korar. Tarpor bujhlam je oishob to shob shomoy korte parbo. And I don't want to work for someone else when it's something I love. I sketch for myself."],
#  ['Subhasish Basak', 'Passion it is'],
#  ['Trisha Dey', 'Thanks! 😃'],
#  ['Subhasish Basak', 'Passion it is'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak',
#   'Ami onk friends der dekhechi.... drawing korte....but eta off the track chilo.... seriously'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak', 'Puro printed comics monne hocche'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak', 'Tym waste koris na... concentrate on drawing'],
#  ['Trisha Dey',
#   'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.'],
#  ['Subhasish Basak', 'Pen??'],
#  ['Trisha Dey',
#   'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.'],
#  ['Subhasish Basak', 'Tar maane without any mistakes'],
#  ['Trisha Dey',
#   'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.'],
#  ['Subhasish Basak', 'Eto level berei choleche'],
#  ['Trisha Dey',
#   'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!'],
#  ['Subhasish Basak', 'Eta dekhe ekta gaan mone pore gelo..'],
#  ['Trisha Dey',
#   'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!'],
#  ['Subhasish Basak',
#   'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Eta dekhe ekta gaan mone pore gelo..'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak',
#   'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970'],
#  ['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#  ['Subhasish Basak', 'Young ta dekhina...normal TBBT'],
#  ['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#  ['Subhasish Basak', 'Tao kobe last dekhechi monne ney'],
#  ['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#  ['Subhasish Basak', 'Lecture maane toh 1.5 hrs'],
#  ['Trisha Dey', 'Tuio dekhish? Young Sheldon?'],
#  ['Subhasish Basak', 'Eto puro ready made fast art😄'],
#  ['Trisha Dey', 'More or less'],
#  ['Subhasish Basak', 'Ekjon ee professor ??'],
#  ['Trisha Dey', 'Amader 4 hours er o lecture thaake'],
#  ['Subhasish Basak', 'Ekjon ee professor ??'],
#  ['Trisha Dey', '😭😭'],
#  ['Subhasish Basak', 'Ekjon ee professor ??'],
#  ['Trisha Dey', 'Abar ekjon professor ekdin 6 hours er o niyechilo.'],
#  ['Subhasish Basak', 'Salute to their devotion'],
#  ['Trisha Dey', 'Abar ekjon professor ekdin 6 hours er o niyechilo.'],
#  ['Subhasish Basak', 'Erai paarbe Corona rr solution ber korte🤣'],
#  ['Trisha Dey', 'Na. Dujon.'],
#  ['Subhasish Basak', 'Salute to their devotion'],
#  ['Trisha Dey', 'Na. Dujon.'],
#  ['Subhasish Basak', 'Erai paarbe Corona rr solution ber korte🤣'],
#  ['Trisha Dey', 'Eita ekjon professor.'],
#  ['Subhasish Basak', 'Salute to their devotion'],
#  ['Trisha Dey', 'Eita ekjon professor.'],
#  ['Subhasish Basak', 'Erai paarbe Corona rr solution ber korte🤣'],
#  ['Trisha Dey', 'Amra pagol hoye jai'],
#  ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#  ['Trisha Dey', '😭'],
#  ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#  ['Trisha Dey', 'R enar under ei amar dissertation paper 🤣'],
#  ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#  ['Trisha Dey', 'Emni khubi bhalo porae. Kintu 6 hours ta newa jaena.'],
#  ['Subhasish Basak', 'Accha toder class ee attendence thake naki ??'],
#  ['Trisha Dey',
#   'Abar amader bole je tomra majhe chaile giye cigarette coffee kheye esho.'],
#  ['Subhasish Basak', 'Class ei allow kore dik..😅'],
#  ['Trisha Dey',
#   'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.'],
#  ['Subhasish Basak', 'Tahole claass koris keno etokkhon dhore'],
#  ['Trisha Dey',
#   'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.'],
#  ['Subhasish Basak', 'Bunk mar chill kor'],
#  ['Trisha Dey',
#   "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona."],
#  ['Subhasish Basak',
#   'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...'],
#  ['Trisha Dey',
#   "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona."],
#  ['Subhasish Basak', 'Kheye deye kaaj nei'],
#  ['Trisha Dey',
#   "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona."],
#  ['Subhasish Basak', 'Kaatano oo jay na😒'],
#  ['Trisha Dey', 'Baaki class gulo jokhon jokhon icche korena, korina.'],
#  ['Subhasish Basak',
#   'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...'],
#  ['Trisha Dey', 'Baaki class gulo jokhon jokhon icche korena, korina.'],
#  ['Subhasish Basak', 'Kheye deye kaaj nei'],
#  ['Trisha Dey', 'Baaki class gulo jokhon jokhon icche korena, korina.'],
#  ['Subhasish Basak', 'Kaatano oo jay na😒'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak', 'Na na ...oder sathe kal k kotha bolchilam'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak', 'Kal k trina k bollam toke daaktey'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak', 'Byass'],
#  ['Trisha Dey', 'CMI er lokjon?'],
#  ['Subhasish Basak', 'Na na ...oder sathe kal k kotha bolchilam'],
#  ['Trisha Dey', 'CMI er lokjon?'],
#  ['Subhasish Basak', 'Kal k trina k bollam toke daaktey'],
#  ['Trisha Dey', 'CMI er lokjon?'],
#  ['Subhasish Basak', 'Byass'],
#  ['Trisha Dey', 'Na maane ototao chinishna moto lokjon?'],
#  ['Subhasish Basak',
#   'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒'],
#  ['Trisha Dey', 'Ami ghumocchilam tokhon XD'],
#  ['Subhasish Basak',
#   'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒'],
#  ['Trisha Dey', 'Arey ektu kotha bolei ne.'],
#  ['Subhasish Basak', 'Raat 8 pm ee ghumacchis ??'],
#  ['Trisha Dey', 'Dujoner e time pass hoe jaabe'],
#  ['Subhasish Basak',
#   'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣'],
#  ['Trisha Dey', 'Dujoner e time pass hoe jaabe'],
#  ['Subhasish Basak', '\U0001f971\U0001f971😴'],
#  ['Trisha Dey',
#   'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪'],
#  ['Subhasish Basak',
#   'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣'],
#  ['Trisha Dey',
#   'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪'],
#  ['Subhasish Basak', '\U0001f971\U0001f971😴'],
#  ['Trisha Dey', 'Na na. Atou baaje hobena 🤣'],
#  ['Subhasish Basak',
#   'Dkh...jokhon cmi tey chilam...tokhon tokee bolchilam j 2 months por kolkatay giea amra party korbo'],
#  ['Trisha Dey', 'Na na. Atou baaje hobena 🤣'],
#  ['Subhasish Basak', 'Rr ekhon kolkatay acchi'],
#  ['Trisha Dey', 'Na na. Atou baaje hobena 🤣'],
#  ['Subhasish Basak', 'Kichu korte parchi na'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Ki obostha'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Let me guess'],
#  ['Trisha Dey', 'I wish I could send an imgae for this!'],
#  ['Subhasish Basak', 'Tiger caves er beach ta ??'],
#  ['Trisha Dey', 'Kostor sesh nei 2020 te 😪😪'],
#  ['Subhasish Basak', 'Shei drive ta ami bhulbo na konodin'],
#  ['Trisha Dey', 'Yes!'],
#  ['Subhasish Basak', 'Shei drive ta ami bhulbo na konodin'],
#  ['Trisha Dey', 'Puro trip e amar ei beach ta shob theke bhalo legechilo'],
#  ['Subhasish Basak', 'It was indeed'],
#  ['Trisha Dey', 'Puro trip e amar ei beach ta shob theke bhalo legechilo'],
#  ['Subhasish Basak', 'Sob theke worst ki chilo ???'],
#  ['Trisha Dey', 'Second would be marina beach.'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Third Mahabalipuram'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Kovallam 🤣'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey',
#   'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.'],
#  ['Subhasish Basak', 'Hya.  ...jodio kichu chilo na'],
#  ['Trisha Dey',
#   'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.'],
#  ['Subhasish Basak', 'Rr baki ??'],
#  ['Trisha Dey', 'R kon beach e gechilam?'],
#  ['Subhasish Basak', 'Not only beach'],
#  ['Trisha Dey', 'R kon beach e gechilam?'],
#  ['Subhasish Basak', 'Baki rr oo toh chilo onk kichu'],
#  ['Trisha Dey', 'R kon beach e gechilam?'],
#  ['Subhasish Basak', 'Trip ta tey'],
#  ['Trisha Dey',
#   'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#  ['Subhasish Basak', 'I can totally relate to this'],
#  ['Trisha Dey',
#   'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#  ['Subhasish Basak', "That's life my friend"],
#  ['Trisha Dey',
#   'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#  ['Subhasish Basak', 'Dkh...duto option thake....'],
#  ['Trisha Dey',
#   'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!'],
#  ['Subhasish Basak',
#   '1. Forget everything move on  2. Cherish your memories and create new memories'],
#  ['Trisha Dey',
#   "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#  ['Subhasish Basak', 'I can totally relate to this'],
#  ['Trisha Dey',
#   "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#  ['Subhasish Basak', "That's life my friend"],
#  ['Trisha Dey',
#   "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#  ['Subhasish Basak', 'Dkh...duto option thake....'],
#  ['Trisha Dey',
#   "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra."],
#  ['Subhasish Basak',
#   '1. Forget everything move on  2. Cherish your memories and create new memories'],
#  ['Trisha Dey',
#   'True. R ki kora jaabe. Aj ekhane achi kal okhane thaakbo. Eita niye kicchu korar nei. Aim is to never stop planning out more trips!'],
#  ['Subhasish Basak',
#   'Ami toh paarle lyf er each and every moment ta capture kore rakhtey chai... memories recapitulation is the best thing for me'],
#  ['Trisha Dey', 'Do you go back to them? Mane chobi gulo abar dekhish?'],
#  ['Subhasish Basak', 'Google photos ka naam suna hay ??'],
#  ['Trisha Dey', 'Do you go back to them? Mane chobi gulo abar dekhish?'],
#  ['Subhasish Basak', '😌'],
#  ['Trisha Dey', 'Do you go back to them? Mane chobi gulo abar dekhish?'],
#  ['Subhasish Basak',
#   'Ota amar most valuable asset....puro lyf acche ota tey amar'],
#  ['Trisha Dey', 'Yep. Akdom!'],
#  ['Subhasish Basak', 'Kore fel'],
#  ['Trisha Dey', 'Yep. Akdom!'],
#  ['Subhasish Basak', '10 years pore dekhbi'],
#  ['Trisha Dey', 'Yep. Akdom!'],
#  ['Subhasish Basak',
#   'Chennai gieachilis...kichu pagol lok jon er sathe party korte'],
#  ['Trisha Dey', 'Yep. Akdom!'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey', 'Ami atodin use e kortam na.'],
#  ['Subhasish Basak', 'Kore fel'],
#  ['Trisha Dey', 'Ami atodin use e kortam na.'],
#  ['Subhasish Basak', '10 years pore dekhbi'],
#  ['Trisha Dey', 'Ami atodin use e kortam na.'],
#  ['Subhasish Basak',
#   'Chennai gieachilis...kichu pagol lok jon er sathe party korte'],
#  ['Trisha Dey', 'Ami atodin use e kortam na.'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey',
#   'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#  ['Subhasish Basak', 'Kore fel'],
#  ['Trisha Dey',
#   'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#  ['Subhasish Basak', '10 years pore dekhbi'],
#  ['Trisha Dey',
#   'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#  ['Subhasish Basak',
#   'Chennai gieachilis...kichu pagol lok jon er sathe party korte'],
#  ['Trisha Dey',
#   'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey',
#   "Pagol to shobai. Sudhu different circumstances and variety'r 😌"],
#  ['Subhasish Basak', 'Yep'],
#  ['Trisha Dey',
#   "Pagol to shobai. Sudhu different circumstances and variety'r 😌"],
#  ['Subhasish Basak', '😓'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Talking to a friend'],
#  ['Trisha Dey', 'Ki korchish akhon?'],
#  ['Subhasish Basak', 'Talking to a friend'],
#  ['Trisha Dey', 'Accha'],
#  ['Subhasish Basak', 'High hote iccha korche'],
#  ['Trisha Dey', 'Accha'],
#  ['Subhasish Basak', 'Any suggestions'],
#  ['Trisha Dey', 'Kotha bole ne'],
#  ['Subhasish Basak', 'High hote iccha korche'],
#  ['Trisha Dey', 'Kotha bole ne'],
#  ['Subhasish Basak', 'Any suggestions'],
#  ['Trisha Dey', 'Eire'],
#  ['Subhasish Basak', "That's why asking for an expert opinion"],
#  ['Trisha Dey', 'Eire'],
#  ['Subhasish Basak', 'Who else it could be'],
#  ['Trisha Dey', 'Eire'],
#  ['Subhasish Basak', 'Other than u'],
#  ['Trisha Dey', 'Emni emni kikore high hobi?'],
#  ['Subhasish Basak', "That's why asking for an expert opinion"],
#  ['Trisha Dey', 'Emni emni kikore high hobi?'],
#  ['Subhasish Basak', 'Who else it could be'],
#  ['Trisha Dey', 'Emni emni kikore high hobi?'],
#  ['Subhasish Basak', 'Other than u'],
#  ['Trisha Dey', 'I am sure posto diye kichu na kichu ber kora jaabe 🤣🤣'],
#  ['Subhasish Basak', 'I want to fly in the sky like a bird 😘😗'],
#  ['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#  ['Subhasish Basak', "That's only imagination"],
#  ['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#  ['Subhasish Basak', 'I want it in reality'],
#  ['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#  ['Subhasish Basak', 'Just imagine... flying in the sky'],
#  ['Trisha Dey', "Why do I feel like you're already high? 🤣"],
#  ['Subhasish Basak', "Wouldn't it be fun"],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Go wherever u want'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Naaaaa'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Plz bol'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Plz'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Pz'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Plz'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Plz'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', 'Plz'],
#  ['Trisha Dey',
#   'Dekh, all other ways of getting high is dangerous tai bolbouna toke.'],
#  ['Subhasish Basak', '🙏🏻🙏🏻🙏🏻'],
#  ['Trisha Dey', 'Amar porer jonme pakhi hoar khub icche'],
#  ['Subhasish Basak', 'Ami ekhon ee pakhi hobo'],
#  ['Trisha Dey', 'Barite modh ache?'],
#  ['Subhasish Basak', 'Eagle 😎'],
#  ['Trisha Dey', 'Barite modh ache?'],
#  ['Subhasish Basak', 'Jd acche'],
#  ['Trisha Dey', 'Barite modh ache?'],
#  ['Subhasish Basak', 'Half khali'],
#  ['Trisha Dey', 'Boro game hoye jaabe to tahole?'],
#  ['Subhasish Basak', 'Tui asol kothaa bol na'],
#  ['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#  ['Subhasish Basak', 'Ektai bottle acche'],
#  ['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#  ['Subhasish Basak', 'Tui bol na'],
#  ['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#  ['Subhasish Basak', 'Ki korte hobe'],
#  ['Trisha Dey', 'Er theke kom daam er kichu ache?'],
#  ['Subhasish Basak', 'Aagun jalabo?'],
#  ['Trisha Dey', 'Beer ache barite?'],
#  ['Subhasish Basak', 'Bari eta re...bar noy🙈'],
#  ['Trisha Dey', 'Beer ache barite?'],
#  ['Subhasish Basak', 'Sudhu ekta jd acche...byass'],
#  ['Trisha Dey', 'Beer ache barite?'],
#  ['Subhasish Basak', 'Bol ebar'],
#  ['Trisha Dey', 'Hyaat 🤣'],
#  ['Subhasish Basak', 'Bari eta re...bar noy🙈'],
#  ['Trisha Dey', 'Hyaat 🤣'],
#  ['Subhasish Basak', 'Sudhu ekta jd acche...byass'],
#  ['Trisha Dey', 'Hyaat 🤣'],
#  ['Subhasish Basak', 'Bol ebar'],
#  ['Trisha Dey', 'Jaani. Ektu apprehensive hocchilam 🤣'],
#  ['Subhasish Basak', '🤣🤣rr kost dis na'],
#  ['Trisha Dey',
#   'Taratari high hote gele duto peg 2 min e maar. Mere du tablespoon chini kheye ne.'],
#  ['Subhasish Basak', 'Chini ??'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Chini ??'],
#  ['Trisha Dey', 'Tarpor dekh kotokhon uurish'],
#  ['Subhasish Basak', 'Chini???'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', '2 peg khele toh abar jol meshate hobe jd tey'],
#  ['Trisha Dey', 'Modh kheye mishti khele faatiye nesha dae'],
#  ['Subhasish Basak', '2 peg khele toh abar jol meshate hobe jd tey'],
#  ['Trisha Dey', 'Why do you think they add so much sugar in shots?'],
#  ['Subhasish Basak', 'Okay'],
#  ['Trisha Dey', 'Why do you think they add so much sugar in shots?'],
#  ['Subhasish Basak', 'Tui jokhon bole dieachis...aaj k korbo'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Okay'],
#  ['Trisha Dey', '🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Tui jokhon bole dieachis...aaj k korbo'],
#  ['Trisha Dey', 'Tahole ektai peg maar'],
#  ['Subhasish Basak', 'Na ...ekta te amar toh kichu hobe na'],
#  ['Trisha Dey', 'But 30 30 kore maar'],
#  ['Subhasish Basak', 'Na ...ekta te amar toh kichu hobe na'],
#  ['Trisha Dey', 'Eishob korishna re! Aunty uncle dhorle maar khabina?'],
#  ['Subhasish Basak', 'Ghumiea porbe ektu pore...'],
#  ['Trisha Dey', 'Tao. Bujhbena?'],
#  ['Subhasish Basak', 'Tokhon ami jege uthbo🤓'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Subhasish Basak',
#   'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Subhasish Basak', 'Kintu kinrr kora jabe'],
#  ['Trisha Dey', '🤣🤣🤣'],
#  ['Subhasish Basak', 'Booze sobar opor ee'],
#  ['Trisha Dey', 'Eishob korishna re'],
#  ['Subhasish Basak',
#   'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche'],
#  ['Trisha Dey', 'Eishob korishna re'],
#  ['Subhasish Basak', 'Kintu kinrr kora jabe'],
#  ['Trisha Dey', 'Eishob korishna re'],
#  ['Subhasish Basak', 'Booze sobar opor ee'],
#  ['Trisha Dey', 'Moteo na 😒'],
#  ['Subhasish Basak', '???????????????????'],
#  ['Trisha Dey', 'Moteo na 😒'],
#  ['Subhasish Basak', "U don't ask that"],
#  ['Trisha Dey', 'Moteo na 😒'],
#  ['Subhasish Basak', '*say that'],
#  ['Trisha Dey', 'Booze er opor maa babar maar!!!! 😒'],
#  ['Subhasish Basak', '🙈🙈🙈'],
#  ['Trisha Dey', 'Dhere boyeshe maar khete bhalo lagbe tor?'],
#  ['Subhasish Basak', 'Maarbe naa ...etuku jani...but bishal jharbe😖'],
#  ['Trisha Dey', 'Tahole korishna'],
#  ['Subhasish Basak', 'But tui chini chara onno kichu bol na'],
#  ['Trisha Dey',
#   "I've been caught by my parents drunk. Ami jaani ki obostha hoy dhora porle 🤦🏽\u200d♀"],
#  ['Subhasish Basak', 'Sudhu Chini rr jonno eto ta risk nebo🤷🏻\u200d♂️'],
#  ['Trisha Dey', 'Barite mishti ache?'],
#  ['Subhasish Basak', 'Soan papri....laddu'],
#  ['Trisha Dey', 'Laddu will work.'],
#  ['Subhasish Basak', '🤣🤣🤣🤣'],
#  ['Trisha Dey', 'Laddu will work.'],
#  ['Subhasish Basak', 'Ki din eseche...'],
#  ['Trisha Dey', 'Duto laddu kheye nish'],
#  ['Subhasish Basak', '🤣🤣🤣🤣'],
#  ['Trisha Dey', 'Duto laddu kheye nish'],
#  ['Subhasish Basak', 'Ki din eseche...'],
#  ['Trisha Dey', 'Also, khali pete thaakle bhalo.'],
#  ['Subhasish Basak',
#   'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣'],
#  ['Trisha Dey', 'Also, khali pete thaakle bhalo.'],
#  ['Subhasish Basak', 'Hya...dinner complete'],
#  ['Trisha Dey', "Kintu I'm guessing tui dinner kore felechish"],
#  ['Subhasish Basak',
#   'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣'],
#  ['Trisha Dey', "Kintu I'm guessing tui dinner kore felechish"],
#  ['Subhasish Basak', 'Hya...dinner complete'],
#  ['Trisha Dey', 'Tor kache to tao kichu ache. Amar konk stock e nei. 🤣'],
#  ['Subhasish Basak', 'Ki kore bujhli?'],
#  ['Trisha Dey', 'Then ektu raat er dike kha!'],
#  ['Subhasish Basak', 'Bari tey fix tym 9pm'],
#  ['Trisha Dey', 'Then ektu raat er dike kha!'],
#  ['Subhasish Basak', 'Khetey hole khao....nahole abar kal k 😅😂'],
#  ['Trisha Dey', 'I can guess 😌'],
#  ['Subhasish Basak', 'Bari tey fix tym 9pm'],
#  ['Trisha Dey', 'I can guess 😌'],
#  ['Subhasish Basak', 'Khetey hole khao....nahole abar kal k 😅😂'],
#  ['Trisha Dey', 'Tai????? 🤣🤣🤣🤣'],
#  ['Subhasish Basak', 'Toder dinner done ??'],
#  ['Trisha Dey', 'Tor kono bhai ba bon ache?'],
#  ['Subhasish Basak', 'Cousins acche'],
#  ['Trisha Dey', 'Tor kono bhai ba bon ache?'],
#  ['Subhasish Basak', '7 jon total'],
#  ['Trisha Dey', 'Nope. Trina ghumocche! Also, eita amader shondhebela 😌'],
#  ['Subhasish Basak', 'Amar saamne cupboard er moddhei acche'],
#  ['Trisha Dey', 'Nope. Trina ghumocche! Also, eita amader shondhebela 😌'],
#  ['Subhasish Basak', 'Guard laagbe na😅'],
#  ['Trisha Dey', "We don't have dinner before 11 p.m."],
#  ['Subhasish Basak', 'Amar saamne cupboard er moddhei acche'],
#  ['Trisha Dey', "We don't have dinner before 11 p.m."],
#  ['Subhasish Basak', 'Guard laagbe na😅'],
#  ['Trisha Dey', 'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!'],
#  ['Subhasish Basak', 'Amar saamne cupboard er moddhei acche'],
#  ['Trisha Dey', 'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!'],
#  ['Subhasish Basak', 'Guard laagbe na😅'],
#  ['Trisha Dey', 'No. 7?'],
#  ['Subhasish Basak', 'Ami 3rd'],
#  ['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#  ['Subhasish Basak', '🤣🤣🤣'],
#  ['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#  ['Subhasish Basak', 'Wait dara check korchi'],
#  ['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#  ['Subhasish Basak', 'Eta ekjon baba k gift korechilo....porei acche....'],
#  ['Trisha Dey', 'Arey dhur JD er number jigesh korlam 🤣🤣'],
#  ['Subhasish Basak', 'Duty free maal'],
#  ['Trisha Dey', 'Uncle khaena?'],
#  ['Subhasish Basak',
#   'Uncle ek somoy amar thekeo bishal passionate chilo booze niea....'],
#  ['Trisha Dey', 'Uncle khaena?'],
#  ['Subhasish Basak', 'Cupboard ekta compartment ta k bar baniea chilo....'],
#  ['Trisha Dey', 'Tahole tor chaap ki??'],
#  ['Subhasish Basak', 'Ekhon seta r obostha dekhley amar ee kharap laage😓'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak',
#   'Biscuits Horlicks rr khali Scotch glass gulo rakha thake'],
#  ['Trisha Dey', 'Keno?'],
#  ['Subhasish Basak', '🤣🤣'],
#  ['Trisha Dey', 'Eire 🤣'],
#  ['Subhasish Basak', 'Dara ami jd ta check korchi'],
#  ['Trisha Dey', 'Kor'],
#  ['Subhasish Basak', 'Arrey'],
#  ['Trisha Dey', 'Kor'],
#  ['Subhasish Basak', 'Ki luck amar'],
#  ['Trisha Dey', 'Kor'],
#  ['Subhasish Basak', 'Ki pelam dkh'],
#  ['Trisha Dey', 'Dekha'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Dekha'],
#  ['Subhasish Basak', '🤤🤤😍😍'],
#  ['Trisha Dey', 'Dekha'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Eita ki??'],
#  ['Subhasish Basak', 'Goa theke kinechilo baba......ekhon monne porlo...'],
#  ['Trisha Dey', 'Eita ki??'],
#  ['Subhasish Basak', 'Local daru'],
#  ['Trisha Dey', 'Eire 🤣'],
#  ['Subhasish Basak', 'Eta khele toh ami aaj rocket'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Subhasish Basak', 'Kintu poblm ektai...'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Subhasish Basak', 'Exactly'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Subhasish Basak', 'Ki coincidence'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Subhasish Basak', 'Etai bolte jacchilam'],
#  ['Trisha Dey', 'But oita sealed pack'],
#  ['Subhasish Basak', '🙈🙈'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', 'Kintu poblm ektai...'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', 'Exactly'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', 'Ki coincidence'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', 'Etai bolte jacchilam'],
#  ['Trisha Dey', 'Kikore khabi?'],
#  ['Subhasish Basak', '🙈🙈'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Duto punch kore dbo??'],
#  ['Trisha Dey', 'Kaju fenni ta baad de.'],
#  ['Subhasish Basak', 'Duto punch kore dbo??'],
#  ['Trisha Dey', 'Kikore korbi?'],
#  ['Subhasish Basak', 'Tahole toh bishmaal puro'],
#  ['Trisha Dey', 'Sealed to'],
#  ['Subhasish Basak', 'Tahole toh bishmaal puro'],
#  ['Trisha Dey', 'Korle rocket er moto uthbi 🤣'],
#  ['Subhasish Basak', 'Hya...seal ta opn korlam...jol misiea dilam'],
#  ['Trisha Dey', 'Yes'],
#  ['Subhasish Basak', 'Hya...seal ta opn korlam...jol misiea dilam'],
#  ['Trisha Dey', 'Local daaru is bangla 🤣'],
#  ['Subhasish Basak', 'Alcohol ee jol meshlae chap nei toh'],
#  ['Trisha Dey', 'Uncle ki boka 😒😒'],
#  ['Subhasish Basak', 'Feni ta Goan daru'],
#  ['Trisha Dey', 'Uncle ki boka 😒😒'],
#  ['Subhasish Basak',
#   'Uncle er bondhu bandhob bari tey na ele uncle khabe na....'],
#  ['Trisha Dey', 'Uncle ki boka 😒😒'],
#  ['Subhasish Basak', 'Tao rare'],
#  ['Trisha Dey',
#   'Country liquor more or less shob jaegar eki khete hoy. Puro bish er moto. Jar jonno ami konodin khabona decide korechi.'],
#  ['Subhasish Basak', 'Rr ekhon toh beri tey keo aasbei na'],
#  ['Trisha Dey', 'But jedin dhorte parbe sedin ki hobe bhaab'],
#  ['Subhasish Basak', 'Kheyechis kono din??'],
#  ['Trisha Dey', 'But jedin dhorte parbe sedin ki hobe bhaab'],
#  ['Subhasish Basak', 'Ooh...oto k bhabe'],
#  ['Trisha Dey', 'But jedin dhorte parbe sedin ki hobe bhaab'],
#  ['Subhasish Basak', 'Tui bachiea dis ama k sedin🙏🏻'],
#  ['Trisha Dey', '😶😶'],
#  ['Subhasish Basak', 'Feni+jd+laddu+chini'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Feni+jd+laddu+chini'],
#  ['Trisha Dey', 'Eita impossible. Nijekeo bachate parini 🤣🤣'],
#  ['Subhasish Basak', 'Ufff\U0001f92f'],
#  ['Trisha Dey', 'Chinni r laagbena.'],
#  ['Subhasish Basak', 'Raw khete hobe otai chap...smell berobe naki ??'],
#  ['Trisha Dey', 'More jaabi re.'],
#  ['Subhasish Basak', 'Raw khete hobe otai chap...smell berobe naki ??'],
#  ['Trisha Dey', 'Amader shonge r party korte parbina konodin.'],
#  ['Subhasish Basak', 'Bangla te toh smell hoy'],
#  ['Trisha Dey', 'Bhaab'],
#  ['Subhasish Basak', 'Na na'],
#  ['Trisha Dey', 'Bhaab'],
#  ['Subhasish Basak', 'Eta hobe na konodin'],
#  ['Trisha Dey', 'Raw khashna.'],
#  ['Subhasish Basak', 'Arre uncle oo bojhe booze ki jinis😌'],
#  ['Trisha Dey', 'Jol mishiyei kha'],
#  ['Subhasish Basak', 'Arre uncle oo bojhe booze ki jinis😌'],
#  ['Trisha Dey', 'Tao 🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Tahole ekhon ee shuru kori naki??'],
#  ['Trisha Dey', 'Tao 🤦🏽\u200d♀'],
#  ['Subhasish Basak', '😝'],
#  ['Trisha Dey', 'Na na'],
#  ['Subhasish Basak', 'Ami tor arr w8 korte parchi na'],
#  ['Trisha Dey', 'Akdom na'],
#  ['Subhasish Basak', 'Ami tor arr w8 korte parchi na'],
#  ['Trisha Dey', 'Pore!'],
#  ['Subhasish Basak', '🤤🤤'],
#  ['Trisha Dey', 'R ektu wait kore ja'],
#  ['Subhasish Basak', 'Koto w8 korabi'],
#  ['Trisha Dey', 'R ektu wait kore ja'],
#  ['Subhasish Basak', '10 ta baaje'],
#  ['Trisha Dey',
#   'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣'],
#  ['Subhasish Basak', 'Jd ta ek dhok maarbo...trpor feni ta ek dhok'],
#  ['Trisha Dey',
#   'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣'],
#  ['Subhasish Basak', 'Na na'],
#  ['Trisha Dey',
#   'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣'],
#  ['Subhasish Basak', 'Pagol naki'],
#  ['Trisha Dey', 'Tui 11tae khash!'],
#  ['Subhasish Basak', 'Ok bolis na...'],
#  ['Trisha Dey', 'Tui 11tae khash!'],
#  ['Subhasish Basak', 'Na na bolbe abar'],
#  ['Trisha Dey', 'Ami bolbona. Tui bolbi.'],
#  ['Subhasish Basak', 'Hurr'],
#  ['Trisha Dey', '😶'],
#  ['Subhasish Basak', 'Hurr'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', 'Arrey...tui sudhu dekhtey thak...'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', 'Amar game'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', 'Aaj k kaju feni rr party hobe'],
#  ['Trisha Dey', "We'll see"],
#  ['Subhasish Basak', 'Arrey...tui sudhu dekhtey thak...'],
#  ['Trisha Dey', "We'll see"],
#  ['Subhasish Basak', 'Amar game'],
#  ['Trisha Dey', "We'll see"],
#  ['Subhasish Basak', 'Aaj k kaju feni rr party hobe'],
#  ['Trisha Dey', '11tar agey warm up suru hobena'],
#  ['Subhasish Basak', 'Ami idea peye gechi'],
#  ['Trisha Dey', '11tar agey warm up suru hobena'],
#  ['Subhasish Basak', 'Bottle tai gayeb kore debo'],
#  ['Trisha Dey', 'Deal?'],
#  ['Subhasish Basak', 'Ami idea peye gechi'],
#  ['Trisha Dey', 'Deal?'],
#  ['Subhasish Basak', 'Bottle tai gayeb kore debo'],
#  ['Trisha Dey',
#   'E kirom party? Eka eka? Bhaab Aritra, Subhayan r Trina koto kosto paabe'],
#  ['Subhasish Basak', 'Bujhtei paarbe na🤣🤣'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', '😓 emotional blackmail😖😖'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', 'Ki naa???'],
#  ['Trisha Dey', '😒😒'],
#  ['Subhasish Basak', 'Eita toh bhalo idea ??'],
#  ['Trisha Dey', 'Akdom na.'],
#  ['Subhasish Basak', '😓 emotional blackmail😖😖'],
#  ['Trisha Dey', 'Akdom na.'],
#  ['Subhasish Basak', 'Ki naa???'],
#  ['Trisha Dey', 'Akdom na.'],
#  ['Subhasish Basak', 'Eita toh bhalo idea ??'],
#  ['Trisha Dey', 'Emotional blackmail na! Oder shotti kharap lagbe!'],
#  ['Subhasish Basak', 'Tahole ki ami pakhi hotte parbo na'],
#  ['Trisha Dey', 'Emotional blackmail na! Oder shotti kharap lagbe!'],
#  ['Subhasish Basak', 'Keno...??'],
#  ['Trisha Dey', 'Emotional blackmail na! Oder shotti kharap lagbe!'],
#  ['Subhasish Basak', 'Full proof'],
#  ['Trisha Dey', 'Akdom na!'],
#  ['Subhasish Basak', 'Tahole ki ami pakhi hotte parbo na'],
#  ['Trisha Dey', 'Akdom na!'],
#  ['Subhasish Basak', 'Keno...??'],
#  ['Trisha Dey', 'Akdom na!'],
#  ['Subhasish Basak', 'Full proof'],
#  ['Trisha Dey', 'Bottle gayeb korle tui du teen din e bottle sesh kore dibi'],
#  ['Subhasish Basak',
#   'Baba bhuleo geche j Orom kichu ekta chilo...just like amio bhule gechilam'],
#  ['Trisha Dey', 'Bottle gayeb korle tui du teen din e bottle sesh kore dibi'],
#  ['Subhasish Basak', 'Hya ...ota toh rr oo moja😁😁🤤'],
#  ['Trisha Dey',
#   'Hoa uchit noe. Bhaab oder ekdin video call e rekhe pakhi hobi. That way orao anondo paabe'],
#  ['Subhasish Basak',
#   'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe'],
#  ['Trisha Dey', 'Toke idea shob diye rakhlam, implementation onno ekdin hok!'],
#  ['Subhasish Basak',
#   'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe'],
#  ['Trisha Dey', 'Tarpor to abar booze booze korbi! 🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Arre tui chap nicchis keno...chill'],
#  ['Trisha Dey', 'Arey shobai ghumiye porbe to!'],
#  ['Subhasish Basak', 'Arre tui chap nicchis keno...chill'],
#  ['Trisha Dey', 'Kal kha! Kalke video call e thaakbo shobai!'],
#  ['Subhasish Basak', 'Arre tui chap nicchis keno...chill'],
#  ['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#  ['Subhasish Basak', 'Kichu hobe na'],
#  ['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#  ['Subhasish Basak', 'Chap nis na'],
#  ['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#  ['Subhasish Basak', 'Chilll'],
#  ['Trisha Dey', 'Aritra, Subhayan, tui, Trina r ami.'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#  ['Subhasish Basak', 'Se toh hobei'],
#  ['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#  ['Subhasish Basak', 'Taintoh bolchi'],
#  ['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#  ['Subhasish Basak', 'Video call korbo ami'],
#  ['Trisha Dey', 'Hoar jonno na! Shobai video call e thaakle moja hobe!'],
#  ['Subhasish Basak', 'Ok'],
#  ['Trisha Dey', 'Baakira jege thaakbe?'],
#  ['Subhasish Basak', 'Sobai jege thakbe'],
#  ['Trisha Dey', 'Baakira jege thaakbe?'],
#  ['Subhasish Basak', '😁😁😁😁😁'],
#  ['Trisha Dey', 'Baakira jege thaakbe?'],
#  ['Subhasish Basak', 'Wah wah'],
#  ['Trisha Dey', 'Baakira jege thaakbe?'],
#  ['Subhasish Basak', 'Aaj may udega🤤'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'Just w8 & watch'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', '🤦🏽\u200d♀🤦🏽\u200d♀'],
#  ['Subhasish Basak', "It's going to drop soon😆"],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', 'Chill'],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', 'Just w8 & watch'],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey',
#   'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣'],
#  ['Subhasish Basak', "It's going to drop soon😆"],
#  ['Trisha Dey', 'Besh'],
#  ['Subhasish Basak', 'Still waiting for ur permission😓'],
#  ['Trisha Dey', 'Besh'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Besh'],
#  ['Subhasish Basak', 'Khulbo???'],
#  ['Trisha Dey', 'Besh'],
#  ['Subhasish Basak', 'Plz??'],
#  ['Trisha Dey', 'Game suru hocche akhon?'],
#  ['Subhasish Basak', 'Still waiting for ur permission😓'],
#  ['Trisha Dey', 'Game suru hocche akhon?'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Game suru hocche akhon?'],
#  ['Subhasish Basak', 'Khulbo???'],
#  ['Trisha Dey', 'Game suru hocche akhon?'],
#  ['Subhasish Basak', 'Plz??'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Keno?????????????????'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Keno ???'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Agge bol keno????????'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Why'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', '????'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Keno?????????????????'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Keno ???'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Agge bol keno????????'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', 'Why'],
#  ['Trisha Dey', 'Na'],
#  ['Subhasish Basak', '????'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', 'Keno?????????????????'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', 'Keno ???'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', 'Agge bol keno????????'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', 'Why'],
#  ['Trisha Dey', 'In another 15 mins'],
#  ['Subhasish Basak', '????'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Subhasish Basak', 'Subho kaaj ee deri keno???'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Subhasish Basak', 'Done ami wait korchi till 10:30'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Subhasish Basak', 'Trpor kintu ek dhok ee direct eto ta namabo'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', '11ta bolechilam! 10:30 te korte dicchi'],
#  ['Subhasish Basak', '🤤🤤🤤🤤'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', 'Subho kaaj ee deri keno???'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', 'Done ami wait korchi till 10:30'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', 'Trpor kintu ek dhok ee direct eto ta namabo'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', '😒'],
#  ['Subhasish Basak', '🤤🤤🤤🤤'],
#  ['Trisha Dey', 'Chele pagol hoye geche'],
#  ['Subhasish Basak', 'Bhai maaro mujhe maaro'],
#  ['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#  ['Subhasish Basak', 'Dhak dhak...hocche amar'],
#  ['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#  ['Subhasish Basak', 'Wai ekhon keno???'],
#  ['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#  ['Subhasish Basak', 'Ei toh bolli 10:30'],
#  ['Trisha Dey', 'Aritra Subhayan r Trina ke video call e ashte bol'],
#  ['Subhasish Basak', 'Wai'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Let me enjoy the moment'],
#  ['Trisha Dey', 'Bole rakh re'],
#  ['Subhasish Basak', 'Let me enjoy the moment'],
#  ['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#  ['Subhasish Basak', 'Mood aasbe emon ekta gaan bol'],
#  ['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#  ['Subhasish Basak', 'Ooh peyechi'],
#  ['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#  ['Subhasish Basak', 'Tor favourite song'],
#  ['Trisha Dey', 'Nahole tui nijer phone theke video tule patha'],
#  ['Subhasish Basak', 'Ritviz'],
#  ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#  ['Subhasish Basak', 'Mood aasbe emon ekta gaan bol'],
#  ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#  ['Subhasish Basak', 'Ooh peyechi'],
#  ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#  ['Subhasish Basak', 'Tor favourite song'],
#  ['Trisha Dey', 'Video tule rakh. Pathabi.'],
#  ['Subhasish Basak', 'Ritviz'],
#  ['Trisha Dey', 'Dim the lights 😌'],
#  ['Subhasish Basak', "It's already dimmed"],
#  ['Trisha Dey', 'Arey!!!'],
#  ['Subhasish Basak', "It's already dimmed"],
#  ['Trisha Dey', 'Amar favourite party song'],
#  ['Subhasish Basak', "It's already dimmed"],
#  ['Trisha Dey', 'Let me guess. Liggi?'],
#  ['Subhasish Basak', 'Na na bol konta chalabo'],
#  ['Trisha Dey', 'Naki udd gaye?'],
#  ['Subhasish Basak', 'Na na bol konta chalabo'],
#  ['Trisha Dey', 'Eita I guess'],
#  ['Subhasish Basak', 'Ami toh bhablam...chalo chalei'],
#  ['Trisha Dey', 'Udd gaaye 🤣🤣'],
#  ['Subhasish Basak', 'Ami toh bhablam...chalo chalei'],
#  ['Trisha Dey', 'Chala!'],
#  ['Subhasish Basak', 'Konta chalabo?? Ritviz naki dim the lights'],
#  ['Trisha Dey', 'Uurte chash tai udd gaye bollam'],
#  ['Subhasish Basak', 'Ritviz toh sune sune heziea geche'],
#  ['Trisha Dey', 'Uurte chash tai udd gaye bollam'],
#  ['Subhasish Basak', 'Dim the lights ee chalai'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Ritviz toh sune sune heziea geche'],
#  ['Trisha Dey', '🤣'],
#  ['Subhasish Basak', 'Dim the lights ee chalai'],
#  ['Trisha Dey', 'Eita kon gaan?'],
#  ['Subhasish Basak', 'Ei toh bolli'],
#  ['Trisha Dey', 'Eita kon gaan?'],
#  ['Subhasish Basak', '???'],
#  ['Trisha Dey', 'Eita kon gaan?'],
#  ['Subhasish Basak', 'Ota ki gaan chilo na??'],
#  ['Trisha Dey', 'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣'],
#  ['Subhasish Basak', 'Seriously???'],
#  ['Trisha Dey', 'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣'],
#  ['Subhasish Basak', '🙈🙈🙈'],
#  ['Trisha Dey', 'Eire. Tor to na kheyei obostha kharap'],
#  ['Subhasish Basak', 'Amio prothom ee tai bhablam......'],
#  ['Trisha Dey', 'Eire. Tor to na kheyei obostha kharap'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', 'Eire. Tor to na kheyei obostha kharap'],
#  ['Subhasish Basak', 'Porre tui bolli eta'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Amio prothom ee tai bhablam......'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Seriously'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Porre tui bolli eta'],
#  ['Trisha Dey', '🤣🤣'],
#  ['Subhasish Basak', 'Tai ami bhablam..ota seriously kono gaan'],
#  ['Trisha Dey', 'Ritviz er gaan gulo amar favourite party songs I meant!'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Ritviz er gaan gulo amar favourite party songs I meant!'],
#  ['Subhasish Basak', 'Ei toh...dim the lights'],
#  ['Trisha Dey', 'Eita ami jaantam e na 🤣'],
#  ['Subhasish Basak', 'Ki ????????'],
#  ['Trisha Dey', 'Eita ami jaantam e na 🤣'],
#  ['Subhasish Basak', 'Hey bhogoban🙈'],
#  ['Trisha Dey', 'Ei gaan ta exist kore jaantam na'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Ki coincidence er khela hocche bhai!!!'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'Chena gaan chala!'],
#  ['Subhasish Basak', 'Mood chole elo re'],
#  ['Trisha Dey', 'Chena gaan chala!'],
#  ['Subhasish Basak', 'Puro full mood'],
#  ['Trisha Dey', 'Elo?'],
#  ['Subhasish Basak', 'Etai chaichilam'],
#  ['Trisha Dey', 'R 4 mins'],
#  ['Subhasish Basak', 'Khaini ekhono monne acche'],
#  ['Trisha Dey', '😌'],
#  ['Subhasish Basak', 'Feelings tai toh ashol'],
#  ['Trisha Dey', 'Akdom!'],
#  ['Subhasish Basak', 'Moments guloi toh ashol'],
#  ['Trisha Dey', '3 mins'],
#  ['Subhasish Basak', 'Booze toh just puro process ta k fast koree...rr ki'],
#  ['Trisha Dey', '3 mins'],
#  ['Subhasish Basak', 'My eyes on the clock'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', '\U0001f9d0'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', '😖😖😖😖'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', '😩😩😩😫😫'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', 'Tule nao'],
#  ['Trisha Dey', '2 mins'],
#  ['Subhasish Basak', 'Ama k tule nao'],
#  ['Trisha Dey', '1 min'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', '1 min'],
#  ['Subhasish Basak', 'Party mood on'],
#  ['Trisha Dey', '♥'],
#  ['Subhasish Basak', 'I wish I could send an imgae for this!'],
#  ['Trisha Dey', 'START!'],
#  ['Subhasish Basak', 'Timestamp 10:29'],
#  ...]

# %%
# code for generating MODIFIED incoming.txt and outgoing.txt

incoming = [x[1] for x in final[::2]]
outgoing = [x[1] for x in final[1:][::2]]

assert len(incoming) == len(outgoing), 'incoming & outgoing lengths differ'

# %%
incoming
# Out:
# ['Permission granted XD',
#  'Permission granted XD',
#  'Assignment kotdur?',
#  'Assignment kotdur?',
#  'Amar laptop e beshi kaaj korle matha dhore jae. Tora kikore korish 😓',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  'Scotch opomaanito holo.',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  'Arey ki birokto laagche',
#  'Arey ki birokto laagche',
#  'R stock tulteo parbona',
#  'R stock tulteo parbona',
#  '😭',
#  '😭',
#  'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!',
#  'Ghumiye ghumiye 🤣🤣 Dine 14 hours ghumocchi!!',
#  'Tor assignment kotdur?',
#  'Tor assignment kotdur?',
#  '🤣🤣',
#  'Tai naaki?',
#  'E to amaro same obostha',
#  'Ami just bari theke berote chai',
#  'Ami just bari theke berote chai',
#  'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.',
#  'Amar university khola thaakle ami dine 3 hours ghumoi. Tar beshi na.',
#  'Amar ghumiye ghumiye matha dhore jacche',
#  'Amar ghumiye ghumiye matha dhore jacche',
#  '😓',
#  '😓',
#  'Na na. Barite.',
#  'Na na. Barite.',
#  'Na na. Barite.',
#  'Na na. Barite.',
#  'Na na. Barite.',
#  'Mamarbari jete dicchena 😭',
#  'Mamarbari jete dicchena 😭',
#  'Mamarbari jete dicchena 😭',
#  'Mamarbari jete dicchena 😭',
#  'Mamarbari jete dicchena 😭',
#  'Kichuina. Just bari theke berote chai!!',
#  'Kichuina. Just bari theke berote chai!!',
#  'Kichuina. Just bari theke berote chai!!',
#  'Kichuina. Just bari theke berote chai!!',
#  'Ami pagol hoye jaabo',
#  'Ami pagol hoye jaabo',
#  'Ami pagol hoye jaabo',
#  'Ami pagol hoye jaabo',
#  '😭',
#  '😭',
#  '😭',
#  '😭',
#  'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.',
#  'Arey amar routine hocche ghum theke uthe 1 hours er moddhe leave for univ. Get back home, have dinner and sleep. Literally.',
#  'Ami thaakte parchina r barite',
#  'Ami thaakte parchina r barite',
#  'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭',
#  'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭',
#  'Ei obostha hobe jaanle ektu booze o stock kore nitam 😭',
#  'Almost 🤣🤣🤣',
#  'Almost 🤣🤣🤣',
#  'Almost 🤣🤣🤣',
#  'Jaani. 😓',
#  'But birokto laagche',
#  'Ekta nip o thaakle roj ek drop kore khetam 🤣',
#  'Ekta nip o thaakle roj ek drop kore khetam 🤣',
#  'I do sketch like Titir. But ajkal oitao korte lyadh laagche',
#  'I do sketch like Titir. But ajkal oitao korte lyadh laagche',
#  'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭',
#  'R movie dekhte parchina. Ato dekhechi. Amar to quarantine e almost two weeks hote chollo 😭',
#  'Sudhu chicken banate paari. 😅',
#  'Sudhu chicken banate paari. 😅',
#  'Ekta sketch dekhbi?',
#  'Ekta sketch dekhbi?',
#  'Eire. Otou shoja na!!!😶😶😶',
#  'Pasta banate pari',
#  'I wish I could send an imgae for this!',
#  'Lasagna ta konodin try korini jodio',
#  'Lasagna ta konodin try korini jodio',
#  'Lasagna ta konodin try korini jodio',
#  'Wait korchilam je kokhon eta bolbi 🤣🤣🤣',
#  'Wait korchilam je kokhon eta bolbi 🤣🤣🤣',
#  'Wait korchilam je kokhon eta bolbi 🤣🤣🤣',
#  'Yep 😝',
#  'Yep 😝',
#  'Yep 😝',
#  'Eki? Keno, keno?',
#  'Eki? Keno, keno?',
#  'Eki? Keno, keno?',
#  'R talent gangar jole bheshe geche!',
#  'R talent gangar jole bheshe geche!',
#  'R talent gangar jole bheshe geche!',
#  'R talent gangar jole bheshe geche!',
#  "Ek shomoy khub interest chilo art and animation niye kaaj korar. Tarpor bujhlam je oishob to shob shomoy korte parbo. And I don't want to work for someone else when it's something I love. I sketch for myself.",
#  'Thanks! 😃',
#  'Akdom!',
#  'Akdom!',
#  'Akdom!',
#  'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.',
#  'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.',
#  'Eita ami du teen din dhore baniyechilam. Purota paati gel pen e kora. Black gel pen. R kicchu na.',
#  'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!',
#  'Mane pencil e ekta faint outline korechilam. Tarpor. Ototao pro noi!',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Tuio dekhish? Young Sheldon?',
#  'Tuio dekhish? Young Sheldon?',
#  'Tuio dekhish? Young Sheldon?',
#  'Tuio dekhish? Young Sheldon?',
#  'More or less',
#  'Amader 4 hours er o lecture thaake',
#  '😭😭',
#  'Abar ekjon professor ekdin 6 hours er o niyechilo.',
#  'Abar ekjon professor ekdin 6 hours er o niyechilo.',
#  'Na. Dujon.',
#  'Na. Dujon.',
#  'Eita ekjon professor.',
#  'Eita ekjon professor.',
#  'Amra pagol hoye jai',
#  '😭',
#  'R enar under ei amar dissertation paper 🤣',
#  'Emni khubi bhalo porae. Kintu 6 hours ta newa jaena.',
#  'Abar amader bole je tomra majhe chaile giye cigarette coffee kheye esho.',
#  'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.',
#  'Nope. Maximum professors naena attendance. Ek dujon jae. Attendance niye chaap nei.',
#  "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona.",
#  "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona.",
#  "Economics of Marx er paper ta kori. It's a very difficult and heavily philosophical paper. Mane professor er porano na shunle boi pore ek line o bujhbona.",
#  'Baaki class gulo jokhon jokhon icche korena, korina.',
#  'Baaki class gulo jokhon jokhon icche korena, korina.',
#  'Baaki class gulo jokhon jokhon icche korena, korina.',
#  'Keno?',
#  'Keno?',
#  'Keno?',
#  'CMI er lokjon?',
#  'CMI er lokjon?',
#  'CMI er lokjon?',
#  'Na maane ototao chinishna moto lokjon?',
#  'Ami ghumocchilam tokhon XD',
#  'Arey ektu kotha bolei ne.',
#  'Dujoner e time pass hoe jaabe',
#  'Dujoner e time pass hoe jaabe',
#  'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪',
#  'Yes. Ami jokhon tokhon ghumoi kaaj na thaakle r khub bored hoye gele 😪',
#  'Na na. Atou baaje hobena 🤣',
#  'Na na. Atou baaje hobena 🤣',
#  'Na na. Atou baaje hobena 🤣',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Kostor sesh nei 2020 te 😪😪',
#  'Yes!',
#  'Puro trip e amar ei beach ta shob theke bhalo legechilo',
#  'Puro trip e amar ei beach ta shob theke bhalo legechilo',
#  'Second would be marina beach.',
#  'Third Mahabalipuram',
#  'Kovallam 🤣',
#  'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.',
#  'Actually Mahabalipuram and Marina is at par. Timing sudhu alada chilo.',
#  'R kon beach e gechilam?',
#  'R kon beach e gechilam?',
#  'R kon beach e gechilam?',
#  'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!',
#  'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!',
#  'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!',
#  'Kovallam tai bhalo lageni. Baki shob jaega bhalo legeche.   Dekh, it all matters on the company. Bondhuder shonge jail eo boshe thaakle tor bhalo laagbe. Eitae ami bishash kori!',
#  "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra.",
#  "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra.",
#  "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra.",
#  "Also, there is one plus point amar khetre. Toder CMI chaarte akhon jei kosto ta hocche, I've already been through this when my seniors left karon amar univ er bondhuder group ta consists of mainly my seniors. Sudhu dujon ba teenjon junior amra.",
#  'True. R ki kora jaabe. Aj ekhane achi kal okhane thaakbo. Eita niye kicchu korar nei. Aim is to never stop planning out more trips!',
#  'Do you go back to them? Mane chobi gulo abar dekhish?',
#  'Do you go back to them? Mane chobi gulo abar dekhish?',
#  'Do you go back to them? Mane chobi gulo abar dekhish?',
#  'Yep. Akdom!',
#  'Yep. Akdom!',
#  'Yep. Akdom!',
#  'Yep. Akdom!',
#  'Ami atodin use e kortam na.',
#  'Ami atodin use e kortam na.',
#  'Ami atodin use e kortam na.',
#  'Ami atodin use e kortam na.',
#  'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.',
#  'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.',
#  'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.',
#  'Bhabchi shob upload kore phone theke delete kore debo. Amar phone e r jaega nei.',
#  "Pagol to shobai. Sudhu different circumstances and variety'r 😌",
#  "Pagol to shobai. Sudhu different circumstances and variety'r 😌",
#  '🤣',
#  'Ki korchish akhon?',
#  'Accha',
#  'Accha',
#  'Kotha bole ne',
#  'Kotha bole ne',
#  'Eire',
#  'Eire',
#  'Eire',
#  'Emni emni kikore high hobi?',
#  'Emni emni kikore high hobi?',
#  'Emni emni kikore high hobi?',
#  'I am sure posto diye kichu na kichu ber kora jaabe 🤣🤣',
#  "Why do I feel like you're already high? 🤣",
#  "Why do I feel like you're already high? 🤣",
#  "Why do I feel like you're already high? 🤣",
#  "Why do I feel like you're already high? 🤣",
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Dekh, all other ways of getting high is dangerous tai bolbouna toke.',
#  'Amar porer jonme pakhi hoar khub icche',
#  'Barite modh ache?',
#  'Barite modh ache?',
#  'Barite modh ache?',
#  'Boro game hoye jaabe to tahole?',
#  'Er theke kom daam er kichu ache?',
#  'Er theke kom daam er kichu ache?',
#  'Er theke kom daam er kichu ache?',
#  'Er theke kom daam er kichu ache?',
#  'Beer ache barite?',
#  'Beer ache barite?',
#  'Beer ache barite?',
#  'Hyaat 🤣',
#  'Hyaat 🤣',
#  'Hyaat 🤣',
#  'Jaani. Ektu apprehensive hocchilam 🤣',
#  'Taratari high hote gele duto peg 2 min e maar. Mere du tablespoon chini kheye ne.',
#  '🤣🤣',
#  'Tarpor dekh kotokhon uurish',
#  '🤣🤣',
#  'Modh kheye mishti khele faatiye nesha dae',
#  'Why do you think they add so much sugar in shots?',
#  'Why do you think they add so much sugar in shots?',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  'Tahole ektai peg maar',
#  'But 30 30 kore maar',
#  'Eishob korishna re! Aunty uncle dhorle maar khabina?',
#  'Tao. Bujhbena?',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  'Eishob korishna re',
#  'Eishob korishna re',
#  'Eishob korishna re',
#  'Moteo na 😒',
#  'Moteo na 😒',
#  'Moteo na 😒',
#  'Booze er opor maa babar maar!!!! 😒',
#  'Dhere boyeshe maar khete bhalo lagbe tor?',
#  'Tahole korishna',
#  "I've been caught by my parents drunk. Ami jaani ki obostha hoy dhora porle 🤦🏽\u200d♀",
#  'Barite mishti ache?',
#  'Laddu will work.',
#  'Laddu will work.',
#  'Duto laddu kheye nish',
#  'Duto laddu kheye nish',
#  'Also, khali pete thaakle bhalo.',
#  'Also, khali pete thaakle bhalo.',
#  "Kintu I'm guessing tui dinner kore felechish",
#  "Kintu I'm guessing tui dinner kore felechish",
#  'Tor kache to tao kichu ache. Amar konk stock e nei. 🤣',
#  'Then ektu raat er dike kha!',
#  'Then ektu raat er dike kha!',
#  'I can guess 😌',
#  'I can guess 😌',
#  'Tai????? 🤣🤣🤣🤣',
#  'Tor kono bhai ba bon ache?',
#  'Tor kono bhai ba bon ache?',
#  'Nope. Trina ghumocche! Also, eita amader shondhebela 😌',
#  'Nope. Trina ghumocche! Also, eita amader shondhebela 😌',
#  "We don't have dinner before 11 p.m.",
#  "We don't have dinner before 11 p.m.",
#  'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!',
#  'Good. Tahole oder moddhe kauke ekjon ke guard dite bol!!',
#  'No. 7?',
#  'Arey dhur JD er number jigesh korlam 🤣🤣',
#  'Arey dhur JD er number jigesh korlam 🤣🤣',
#  'Arey dhur JD er number jigesh korlam 🤣🤣',
#  'Arey dhur JD er number jigesh korlam 🤣🤣',
#  'Uncle khaena?',
#  'Uncle khaena?',
#  'Tahole tor chaap ki??',
#  'Keno?',
#  'Keno?',
#  'Eire 🤣',
#  'Kor',
#  'Kor',
#  'Kor',
#  'Dekha',
#  'Dekha',
#  'Dekha',
#  'Eita ki??',
#  'Eita ki??',
#  'Eire 🤣',
#  'But oita sealed pack',
#  'But oita sealed pack',
#  'But oita sealed pack',
#  'But oita sealed pack',
#  'But oita sealed pack',
#  'Kikore khabi?',
#  'Kikore khabi?',
#  'Kikore khabi?',
#  'Kikore khabi?',
#  'Kikore khabi?',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  'Kaju fenni ta baad de.',
#  'Kikore korbi?',
#  'Sealed to',
#  'Korle rocket er moto uthbi 🤣',
#  'Yes',
#  'Local daaru is bangla 🤣',
#  'Uncle ki boka 😒😒',
#  'Uncle ki boka 😒😒',
#  'Uncle ki boka 😒😒',
#  'Country liquor more or less shob jaegar eki khete hoy. Puro bish er moto. Jar jonno ami konodin khabona decide korechi.',
#  'But jedin dhorte parbe sedin ki hobe bhaab',
#  'But jedin dhorte parbe sedin ki hobe bhaab',
#  'But jedin dhorte parbe sedin ki hobe bhaab',
#  '😶😶',
#  'Na',
#  'Eita impossible. Nijekeo bachate parini 🤣🤣',
#  'Chinni r laagbena.',
#  'More jaabi re.',
#  'Amader shonge r party korte parbina konodin.',
#  'Bhaab',
#  'Bhaab',
#  'Raw khashna.',
#  'Jol mishiyei kha',
#  'Tao 🤦🏽\u200d♀',
#  'Tao 🤦🏽\u200d♀',
#  'Na na',
#  'Akdom na',
#  'Pore!',
#  'R ektu wait kore ja',
#  'R ektu wait kore ja',
#  'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣',
#  'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣',
#  'Trina uthuk. Ok boli shob. Ami eka keno boka khabo? Dujonei khabo 🤣🤣🤣',
#  'Tui 11tae khash!',
#  'Tui 11tae khash!',
#  'Ami bolbona. Tui bolbi.',
#  '😶',
#  '😒😒',
#  '😒😒',
#  '😒😒',
#  "We'll see",
#  "We'll see",
#  "We'll see",
#  '11tar agey warm up suru hobena',
#  '11tar agey warm up suru hobena',
#  'Deal?',
#  'Deal?',
#  'E kirom party? Eka eka? Bhaab Aritra, Subhayan r Trina koto kosto paabe',
#  '😒😒',
#  '😒😒',
#  '😒😒',
#  'Akdom na.',
#  'Akdom na.',
#  'Akdom na.',
#  'Emotional blackmail na! Oder shotti kharap lagbe!',
#  'Emotional blackmail na! Oder shotti kharap lagbe!',
#  'Emotional blackmail na! Oder shotti kharap lagbe!',
#  'Akdom na!',
#  'Akdom na!',
#  'Akdom na!',
#  'Bottle gayeb korle tui du teen din e bottle sesh kore dibi',
#  'Bottle gayeb korle tui du teen din e bottle sesh kore dibi',
#  'Hoa uchit noe. Bhaab oder ekdin video call e rekhe pakhi hobi. That way orao anondo paabe',
#  'Toke idea shob diye rakhlam, implementation onno ekdin hok!',
#  'Tarpor to abar booze booze korbi! 🤦🏽\u200d♀',
#  'Arey shobai ghumiye porbe to!',
#  'Kal kha! Kalke video call e thaakbo shobai!',
#  'Aritra, Subhayan, tui, Trina r ami.',
#  'Aritra, Subhayan, tui, Trina r ami.',
#  'Aritra, Subhayan, tui, Trina r ami.',
#  'Aritra, Subhayan, tui, Trina r ami.',
#  'Hoar jonno na! Shobai video call e thaakle moja hobe!',
#  'Hoar jonno na! Shobai video call e thaakle moja hobe!',
#  'Hoar jonno na! Shobai video call e thaakle moja hobe!',
#  'Hoar jonno na! Shobai video call e thaakle moja hobe!',
#  'Baakira jege thaakbe?',
#  'Baakira jege thaakbe?',
#  'Baakira jege thaakbe?',
#  'Baakira jege thaakbe?',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀',
#  'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣',
#  'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣',
#  'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣',
#  'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣',
#  'Amader barite maa baba onekkhon jege thaake. So ami r Trina most probably khub olpo kotha bolte parbo. But call e thaakbo 🤣',
#  'Besh',
#  'Besh',
#  'Besh',
#  'Besh',
#  'Game suru hocche akhon?',
#  'Game suru hocche akhon?',
#  'Game suru hocche akhon?',
#  'Game suru hocche akhon?',
#  '🤣',
#  '🤣',
#  '🤣',
#  '🤣',
#  '🤣',
#  'Na',
#  'Na',
#  'Na',
#  'Na',
#  'Na',
#  'In another 15 mins',
#  'In another 15 mins',
#  'In another 15 mins',
#  'In another 15 mins',
#  'In another 15 mins',
#  '11ta bolechilam! 10:30 te korte dicchi',
#  '11ta bolechilam! 10:30 te korte dicchi',
#  '11ta bolechilam! 10:30 te korte dicchi',
#  '11ta bolechilam! 10:30 te korte dicchi',
#  '11ta bolechilam! 10:30 te korte dicchi',
#  '😒',
#  '😒',
#  '😒',
#  '😒',
#  '😒',
#  'Chele pagol hoye geche',
#  'Aritra Subhayan r Trina ke video call e ashte bol',
#  'Aritra Subhayan r Trina ke video call e ashte bol',
#  'Aritra Subhayan r Trina ke video call e ashte bol',
#  'Aritra Subhayan r Trina ke video call e ashte bol',
#  '🤣🤣',
#  'Bole rakh re',
#  'Nahole tui nijer phone theke video tule patha',
#  'Nahole tui nijer phone theke video tule patha',
#  'Nahole tui nijer phone theke video tule patha',
#  'Nahole tui nijer phone theke video tule patha',
#  'Video tule rakh. Pathabi.',
#  'Video tule rakh. Pathabi.',
#  'Video tule rakh. Pathabi.',
#  'Video tule rakh. Pathabi.',
#  'Dim the lights 😌',
#  'Arey!!!',
#  'Amar favourite party song',
#  'Let me guess. Liggi?',
#  'Naki udd gaye?',
#  'Eita I guess',
#  'Udd gaaye 🤣🤣',
#  'Chala!',
#  'Uurte chash tai udd gaye bollam',
#  'Uurte chash tai udd gaye bollam',
#  '🤣',
#  '🤣',
#  'Eita kon gaan?',
#  'Eita kon gaan?',
#  'Eita kon gaan?',
#  'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣',
#  'Arey! Bollam ghorar alo gulo ektu dim kor 🤣🤣🤣',
#  'Eire. Tor to na kheyei obostha kharap',
#  'Eire. Tor to na kheyei obostha kharap',
#  'Eire. Tor to na kheyei obostha kharap',
#  '🤣🤣',
#  '🤣🤣',
#  '🤣🤣',
#  '🤣🤣',
#  'Ritviz er gaan gulo amar favourite party songs I meant!',
#  'Ritviz er gaan gulo amar favourite party songs I meant!',
#  'Eita ami jaantam e na 🤣',
#  'Eita ami jaantam e na 🤣',
#  'Ei gaan ta exist kore jaantam na',
#  'Ki coincidence er khela hocche bhai!!!',
#  'Chena gaan chala!',
#  'Chena gaan chala!',
#  'Elo?',
#  'R 4 mins',
#  '😌',
#  'Akdom!',
#  '3 mins',
#  '3 mins',
#  '2 mins',
#  '2 mins',
#  '2 mins',
#  '2 mins',
#  '2 mins',
#  '1 min',
#  '1 min',
#  '♥',
#  'START!',
#  'START!',
#  '👏🏽',
#  '👏🏽',
#  '👏🏽',
#  '😎',
#  '😎',
#  '😎',
#  'Kheli?',
#  'Kheli?',
#  'Kheli?',
#  'Keno?',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  'Emni ektu taste kore dekh agey',
#  'Emni ektu taste kore dekh agey',
#  'Emni ektu taste kore dekh agey',
#  '🤣',
#  '🤣',
#  '🤣',
#  'Tahole khashna!!!',
#  'Whiskey ta kha',
#  'Whiskey ta kha',
#  'Akdom e na',
#  '😒',
#  '😒',
#  '😒',
#  'Naa',
#  'Naa',
#  'Naa',
#  'Olpo kha',
#  'Olpo kha',
#  'Olpo kha',
#  '🤦🏽\u200d♀',
#  'Neshar dik theke positive naki negative?',
#  '🤦🏽\u200d♀',
#  'R khashna. Rakh ota. JD kha.',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  'Mishti ta kha',
#  'Mishti ta kha',
#  '🤣',
#  '🤣',
#  'For what?',
#  '🤦🏽\u200d♀',
#  'Jol kha',
#  '😶😶😶',
#  '😶😶😶',
#  '😶😶😶',
#  'R kichu khashna ajke',
#  'R kichu khashna ajke',
#  'R kichu khashna ajke',
#  'Shera dokan er laddu to 😌',
#  'Hoye jawar kotha. Tar por aro ekta khash laddu',
#  'Tahole r khashna',
#  'Tahole r khashna',
#  'Tahole r khashna',
#  'Tahole r khashna',
#  'Koto boro bottle ta??',
#  'Koto boro bottle ta??',
#  'Koto boro bottle ta??',
#  'Koto boro bottle ta??',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Koto boro bottle ta? Dekhe mone hocche pite.',
#  'Koto boro bottle ta? Dekhe mone hocche pite.',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  'Eitoh. Ebar ashol game 😌',
#  '🤣🤣',
#  '🤣🤣',
#  'Idea ta tor e chilo!',
#  'Idea ta tor e chilo!',
#  'Amar idea to JD er chilo',
#  'Amar idea to JD er chilo',
#  'Modh e to eishob hoyna 😶😶',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Ekta chotto jinish korbi?',
#  'Neck er exercise e jerom matha ta ghorae ektu du teen rouch ghuriye shoja rakh. Tarpor dekh kirom laage 🤣  But shabdhane, khaat e matha abar thuke felishna.',
#  '*round',
#  '*round',
#  '🤣🤣',
#  '🤣🤣',
#  'Careful',
#  'Careful',
#  'Matha thukishna kothao',
#  'Matha thukishna kothao',
#  '🤣🤣',
#  'Eigulo cheap tricks',
#  'Eigulo cheap tricks',
#  'Modh kom thaakle',
#  'Mishti ta r ekta cheap trick',
#  '🤣🤣🤣',
#  "R ekta is smoking. But I wouldn't suggest that to any non-smoker",
#  'Kemon laagche?',
#  'Kemon laagche?',
#  'Kemon laagche?',
#  'Kemon laagche?',
#  'Kemon laagche?',
#  'Eita shob shomoy kaaj kore',
#  'Eita shob shomoy kaaj kore',
#  '😎😎',
#  '😎😎',
#  'But r modh khashna.',
#  'Ei shundor high ta thaak',
#  'Ei shundor high ta thaak',
#  'Abar kal khash!',
#  'Abar kal khash!',
#  'Abar kal khash!',
#  'Tahole r olpo khabi',
#  'Tahole r olpo khabi',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Pagla hoye jaabi tui 🤦🏽\u200d♀',
#  'Eita ki chilo!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#  'Eita ki chilo!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#  'Eita ki chilo!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#  'Chocolate dopamine barae! Happy high!',
#  'Chocolate dopamine barae! Happy high!',
#  'Chocolate dopamine barae! Happy high!',
#  'Chocolate dopamine barae! Happy high!',
#  'Chocolate dopamine barae! Happy high!',
#  'Arey maane jei stunt ta korli, dekhe khub moja laaglo. Atogulo gems akshonge kheye nili',
#  'Arey maane jei stunt ta korli, dekhe khub moja laaglo. Atogulo gems akshonge kheye nili',
#  '🤣',
#  '🤣',
#  'R laagbena',
#  'Ebar second peg ta mere bottle ta rekhe de',
#  'Bol',
#  'Yes',
#  'Yes',
#  'Not more than that',
#  'Not more than that',
#  'Okay. But tar theke beshi na',
#  'Okay. But tar theke beshi na',
#  'Okay. But tar theke beshi na',
#  'Okay. But tar theke beshi na',
#  'Okay. But tar theke beshi na',
#  'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.',
#  'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.',
#  'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.',
#  'Eita no idea bhai. Noshto hoar kotha noe. But fenni jinish ta niye idea nei. Dara dekhe bolchi.',
#  'I wish I could send an imgae for this!',
#  'Akdom na.',
#  'Bottle ta bondho kore nijer bag e rekhe de apatoto.',
#  'Ami kalke jerom bhabe bolbo, rekhe dibi bottle ta.',
#  'Any locker that you have?',
#  'Any locker that you have?',
#  'Accha',
#  'Dara',
#  'Ajke r khabina',
#  'Ajke r khabina',
#  'Ajke r khabina',
#  'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.',
#  'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.',
#  'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.',
#  'Thik ache. Then r ekta peg kha. Diye jol mishiye rekhe de.',
#  'Filtered water meshash',
#  'Filtered water meshash',
#  'Filtered water meshash',
#  'Filtered water meshash',
#  'Tahole porer sitting guloe diluted khash. Ajke r ek peg kheye rekhe de.',
#  'Bottle er jol o to filter er?',
#  'Jol er bottle theke jol dhele de',
#  'Jol er bottle theke jol dhele de',
#  'Jol er bottle theke jol dhele de',
#  "Don't fill it to the brim though. Jerom modh er level chilo orom level obdhi jol diye rakh",
#  'Gaa diye gondho berocche?',
#  'Deo',
#  'Perfume',
#  'Puro AC er vent er shamne maar r nijer gaaye.',
#  'Puro AC er vent er shamne maar r nijer gaaye.',
#  'Puro AC er vent er shamne maar r nijer gaaye.',
#  'Puro AC er vent er shamne maar r nijer gaaye.',
#  'Puro AC er vent er shamne maar r nijer gaaye.',
#  'Chips ache barite? Lays?',
#  'Chips ache barite? Lays?',
#  'R ekta option',
#  'Mukhe ektu toothpaste r jol niye kulluchi kore fele de.',
#  'Nahole orbit jaatiyo barite kichu thaakle kheye ne',
#  'Ba listerine',
#  'Arey! Chakna 😌',
#  'Arey! Chakna 😌',
#  '😌😌',
#  'Eigulo amader university tricks.',
#  'We get exactly one hour to get high and then get that down',
#  'We get exactly one hour to get high and then get that down',
#  'Toke ajke jotogulo trick bollam',
#  'Toke ajke jotogulo trick bollam',
#  'Loke modh kheye nesha hole, komanor jonno lebu khae. Oita akdom bhul approach. Jhaal kichu khelei the work is done.',
#  'Eita jene rakh. Life lesson.',
#  'Beshi khashna then',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  'Eki! Fele dili keno?',
#  'Eki! Fele dili keno?',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  'Oituku jhaal e kichu hobena!',
#  'Oituku jhaal e kichu hobena!',
#  'Peg ta maar',
#  'Peg ta maar',
#  'Peg ta maar',
#  'Mere repeat the tricks',
#  'Mere repeat the tricks',
#  'Mere repeat the tricks',
#  'Neck trick 😌',
#  'Neck trick 😌',
#  'Neck trick 😌',
#  'Se to sesh hobei!',
#  'Se to sesh hobei!',
#  'Yep 😌',
#  'Party suru hole to sesh hobei?',
#  'Ki holo?',
#  'Ki holo?',
#  'Ki holo?',
#  'Korbena to! High hote hobe.',
#  'Korbena to! High hote hobe.',
#  'Korbena to! High hote hobe.',
#  'Korbena to! High hote hobe.',
#  'Korbena to! High hote hobe.',
#  'Tahole abar ektu baade party suru korish 🤣',
#  'Shon',
#  'Shon',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Kisher chobi?',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Ete hobena kichu! Ulte bad trip kheye jaabi!',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Thik achish to?',
#  'Jol kha',
#  'Dehydration is what causes the hangover',
#  'Dehydration is what causes the hangover',
#  'Dehydration is what causes the hangover',
#  'Abar hobe mood',
#  'Abar hobe mood',
#  'Abar hobe mood',
#  'Dekh ashe ki na',
#  'Dekh ashe ki na',
#  '12ta',
#  '12ta',
#  'Dot',
#  'Dot',
#  'Tahole khashna',
#  'Jor kore khashna',
#  '🤣',
#  '🤣',
#  '🤣',
#  '🤣',
#  '🤣',
#  '11:45. Deal?',
#  '11:45. Deal?',
#  '11:45. Deal?',
#  '11:45. Deal?',
#  '11:45. Deal?',
#  'Eitoh. Good good. 😌',
#  '12tar agey sudhu jol khaabi',
#  '12tar agey sudhu jol khaabi',
#  'Amae control korate bolle ja routine debo, maante parbina.',
#  'Amae control korate bolle ja routine debo, maante parbina.',
#  'Amae control korate bolle ja routine debo, maante parbina.',
#  'Amae control korate bolle ja routine debo, maante parbina.',
#  'Ki??',
#  'Ki??',
#  'Ki??',
#  'Ki??',
#  'Matha betha korche? Ba khub gorom laagche?',
#  'Matha betha korche? Ba khub gorom laagche?',
#  'Naki bomi pacche?',
#  'Tui kiddo e 🤣🤣',
#  'Tui kiddo e 🤣🤣',
#  'Tui kiddo e 🤣🤣',
#  'Tui kiddo e 🤣🤣',
#  'Tui mon theke kiddo!',
#  'Tui mon theke kiddo!',
#  'Tui mon theke kiddo!',
#  'Besh! Problem ki hocche bol',
#  'Besh! Problem ki hocche bol',
#  'Besh! Problem ki hocche bol',
#  'Besh! Problem ki hocche bol',
#  'Besh! Problem ki hocche bol',
#  'R guess er baire chole jacche. Boleifel',
#  'R guess er baire chole jacche. Boleifel',
#  'R guess er baire chole jacche. Boleifel',
#  'Oh',
#  'Heartburn hobei.',
#  'Ghumonor agey ekta antacid kheye ghumiye porish.',
#  'Acid r gas hocche.',
#  'Acid r gas hocche.',
#  'Eita game er rules',
#  'Eita game er rules',
#  'Eita game er rules',
#  'Eita game er rules',
#  'Arey! ♥',
#  '😪',
#  'Abar hobe kokhono!',
#  'Yep',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Bhalo gaan!',
#  'Ummm bhaabte de',
#  'Ummm bhaabte de',
#  'O re piya?',
#  'O re piya?',
#  '🤣🤣🤣🤣',
#  '🤣🤣🤣🤣',
#  '🤣🤣🤣🤣',
#  '🤣🤣🤣🤣',
#  'Dekha',
#  'Dekha',
#  'Dekha',
#  'Patha',
#  'Patha',
#  'Patha',
#  'Patha',
#  'Patha',
#  'Patha',
#  'Patha',
#  'Trance chilo puro 😍',
#  'Trance chilo puro 😍',
#  'Trance chilo puro 😍',
#  'Trance chilo puro 😍',
#  'Shotti',
#  'Shotti',
#  '😌😌',
#  '😌😌',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  '🤦🏽\u200d♀',
#  '🤣🤣',
#  '🤣🤣',
#  "12:10 e you'll start",
#  "12:10 e you'll start",
#  '..',
#  '..',
#  '..',
#  '..',
#  '..',
#  '..',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  '🤣🤣🤣',
#  '..',
#  '..',
#  '..',
#  '..',
#  'Ekta shoja ekta ulto',
#  'Ekta shoja ekta ulto',
#  'Ekta shoja ekta ulto',
#  'Ekta shoja ekta ulto',
#  'Co-Pilot boleche bole',
#  'Co-Pilot boleche bole',
#  'Tahole Co-pilot plane e uthbena',
#  'Passenger ra raagbena',
#  'Passenger ra raagbena',
#  'Passenger ra raagbena',
#  '11 mins por plane starts',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'Control. Control.',
#  'Control. Control.',
#  'Control. Control.',
#  'Control. Control.',
#  'Control. Control.',
#  'Control. Control.',
#  'Control. Control.',
#  'R 8 mins',
#  'R 8 mins',
#  'R 8 mins',
#  'R 8 mins',
#  'R 8 mins',
#  'R 8 mins',
#  'Well. 😌😌',
#  'Well. 😌😌',
#  'So tui por por du din modh kheyechish. Abar kal khabi.',
#  'Kal mane 29th',
#  'R 6 mins',
#  'No cheating 😌',
#  'Akdom hoy!!!',
#  'Nope nope',
#  'Nope nope',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'R 5 mins',
#  'R 5 mins',
#  'R 5 mins',
#  'R 5 mins',
#  'R 5 mins',
#  'R 5 mins',
#  'R 5 mins',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  '🤦🏽\u200d♀🤦🏽\u200d♀🤦🏽\u200d♀',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'Ki hocche????',
#  'R 1 min',
#  'R 1 min',
#  '1 min!',
#  '1 min!',
#  '1 min!',
#  'Start!',
#  'Start!',
#  'Start!',
#  'R 10 mins',
#  'R 10 mins',
#  'R 10 mins',
#  'Yes',
#  'Yes',
#  'Yes',
#  '🤣',
#  '🤣',
#  '🤣',
#  '🤣',
#  'Dekhalina next time kotota kheli??',
#  'Dekhalina next time kotota kheli??',
#  'Dekhalina next time kotota kheli??',
#  'Dekhalina next time kotota kheli??',
#  '🤣🤣',
#  'R khashna',
#  'Good boy 😌',
#  'Ki bujhli?',
#  'Ebar try the neck trick after 5 mins',
#  'Good. Keep drinking water. Dehydration hoye jaabe nahole',
#  'Good. Keep drinking water. Dehydration hoye jaabe nahole',
#  'Good. Keep drinking water. Dehydration hoye jaabe nahole',
#  'Ki chole esheche?',
#  'Ki chole esheche?',
#  'Ki chole esheche?',
#  ...]

# %%
outgoing
# Out:
# ['Sobe toh shuru korlam',
#  '5 April deadline jodio...onk tym acche',
#  'Sobe toh shuru korlam',
#  '5 April deadline jodio...onk tym acche',
#  'I wish I could send an imgae for this!',
#  'Seriously',
#  'Seriously',
#  'Seri',
#  'Same kotha ta ami aritra k bolechilam...',
#  'Exactly the same words',
#  '🙏🏻🙏🏻🙏🏻🙏🏻',
#  'Tomay pronam',
#  '🙏🏻🙏🏻🙏🏻🙏🏻',
#  'Ki jataah',
#  'Thug lyf hoye gelo😢',
#  'Ki jataah',
#  'Thug lyf hoye gelo😢',
#  'Ki jataah',
#  'Thug lyf hoye gelo😢',
#  'Aaj kal khub busy monne hocche\U0001f9d0...online dekha jay na aapna k',
#  'Ki korre busy thaka jay...amader oo bol ektu',
#  'Assignment kotha theke chole elo abar😒',
#  'Assignment jali ..',
#  'Assignment kotha theke chole elo abar😒',
#  'Assignment jali ..',
#  'Amar toh raat eeo ghum aaseena😥...ki obostha... corona rr bazar ee insomnia hoye gelo mone hoy',
#  'Cmi tey thakte khub kom ghumatam',
#  'Cmi tey thakte khub kom ghumatam',
#  'Tar ee effect hoyto',
#  'Sobai chai',
#  'Ekhon kothaye tora ??',
#  'Mamar bari tei ?',
#  'Ekhon kothaye tora ??',
#  'Mamar bari tei ?',
#  'Ekhon kothaye tora ??',
#  'Mamar bari tei ?',
#  'Kno mamar bari keno jabi ??',
#  'K acche ??',
#  'Or',
#  'Ki acche??',
#  '🤔',
#  'Kno mamar bari keno jabi ??',
#  'K acche ??',
#  'Or',
#  'Ki acche??',
#  '🤔',
#  '😆',
#  'Eto chap nis na',
#  'Aaste aaste sob habituated hoye jabo amra',
#  'Eta ekhono onk din ee cholbe ja monne hoy',
#  '😆',
#  'Eto chap nis na',
#  'Aaste aaste sob habituated hoye jabo amra',
#  'Eta ekhono onk din ee cholbe ja monne hoy',
#  '😆',
#  'Eto chap nis na',
#  'Aaste aaste sob habituated hoye jabo amra',
#  'Eta ekhono onk din ee cholbe ja monne hoy',
#  'Bari ta just hotel naki\U0001f92d',
#  "Papa's hotel",
#  'Bari ta just hotel naki\U0001f92d',
#  "Papa's hotel",
#  'Babare...tui oo booze er jonno pagol hoye jacchis',
#  'Booze kintu control ee khete hobe...naholei case',
#  'Besi booze khawa bhalo na😌',
#  'Babare...tui oo booze er jonno pagol hoye jacchis',
#  'Booze kintu control ee khete hobe...naholei case',
#  'Besi booze khawa bhalo na😌',
#  'Tym paas kor',
#  'Tym paas kor',
#  'Any hobbies ?? Drawing movies etc!??',
#  'Comics acche toh',
#  'Hmm',
#  'Cooking ???',
#  'Arre dhur🙈',
#  'Chicken banano toh 60ml peg bananor thekeo soja',
#  'Arre dhur🙈',
#  'Chicken banano toh 60ml peg bananor thekeo soja',
#  'Lasagna ..pasta...esob bana',
#  'Yes pls...😁',
#  'When I say that...I mean not a single drop should fall out of the peg measure😌',
#  'When I say that...I mean not a single drop should fall out of the peg measure😌',
#  'When I say that...I mean not a single drop should fall out of the peg measure😌',
#  '😮😮😮😮😮',
#  'Seriously',
#  'U did that',
#  '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂',
#  'Why why',
#  'Keno',
#  '🤦🏻\u200d♂🤦🏻\u200d♂🤦🏻\u200d♂',
#  'Why why',
#  'Keno',
#  'Why wasting ur talent',
#  'Eta over professional',
#  'Seriously',
#  'Bolchi...',
#  'Esob bolis na',
#  'Just .. printed monne hocche',
#  'Great job👏🏻👏🏻',
#  'Passion it is',
#  'Passion it is',
#  'Ami onk friends der dekhechi.... drawing korte....but eta off the track chilo.... seriously',
#  'Puro printed comics monne hocche',
#  'Tym waste koris na... concentrate on drawing',
#  'Pen??',
#  'Tar maane without any mistakes',
#  'Eto level berei choleche',
#  'Eta dekhe ekta gaan mone pore gelo..',
#  'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970',
#  'Eta dekhe ekta gaan mone pore gelo..',
#  'Soft kitty warm kitty little ball of fur.. Happy kitty sleepy kittly purr purr purr\U0001f970',
#  'Young ta dekhina...normal TBBT',
#  'Tao kobe last dekhechi monne ney',
#  'Lecture maane toh 1.5 hrs',
#  'Eto puro ready made fast art😄',
#  'Ekjon ee professor ??',
#  'Ekjon ee professor ??',
#  'Ekjon ee professor ??',
#  'Salute to their devotion',
#  'Erai paarbe Corona rr solution ber korte🤣',
#  'Salute to their devotion',
#  'Erai paarbe Corona rr solution ber korte🤣',
#  'Salute to their devotion',
#  'Erai paarbe Corona rr solution ber korte🤣',
#  'Accha toder class ee attendence thake naki ??',
#  'Accha toder class ee attendence thake naki ??',
#  'Accha toder class ee attendence thake naki ??',
#  'Accha toder class ee attendence thake naki ??',
#  'Class ei allow kore dik..😅',
#  'Tahole claass koris keno etokkhon dhore',
#  'Bunk mar chill kor',
#  'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...',
#  'Kheye deye kaaj nei',
#  'Kaatano oo jay na😒',
#  'Arre dhur ki bhul bhal lok group video call pathacche ..bar bar...',
#  'Kheye deye kaaj nei',
#  'Kaatano oo jay na😒',
#  'Na na ...oder sathe kal k kotha bolchilam',
#  'Kal k trina k bollam toke daaktey',
#  'Byass',
#  'Na na ...oder sathe kal k kotha bolchilam',
#  'Kal k trina k bollam toke daaktey',
#  'Byass',
#  'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒',
#  'Purono bondhu...kothai hoy na...ekhon tym paas korte call korche...k dhobe😒',
#  'Raat 8 pm ee ghumacchis ??',
#  'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣',
#  '\U0001f971\U0001f971😴',
#  'Hya...ja din kal poreche...dudin porre dekhbo ama kei eder call korte hocche🤣',
#  '\U0001f971\U0001f971😴',
#  'Dkh...jokhon cmi tey chilam...tokhon tokee bolchilam j 2 months por kolkatay giea amra party korbo',
#  'Rr ekhon kolkatay acchi',
#  'Kichu korte parchi na',
#  'Ki obostha',
#  'Let me guess',
#  'Tiger caves er beach ta ??',
#  'Shei drive ta ami bhulbo na konodin',
#  'Shei drive ta ami bhulbo na konodin',
#  'It was indeed',
#  'Sob theke worst ki chilo ???',
#  'Seriously',
#  'Seriously',
#  'Seriously',
#  'Hya.  ...jodio kichu chilo na',
#  'Rr baki ??',
#  'Not only beach',
#  'Baki rr oo toh chilo onk kichu',
#  'Trip ta tey',
#  'I can totally relate to this',
#  "That's life my friend",
#  'Dkh...duto option thake....',
#  '1. Forget everything move on  2. Cherish your memories and create new memories',
#  'I can totally relate to this',
#  "That's life my friend",
#  'Dkh...duto option thake....',
#  '1. Forget everything move on  2. Cherish your memories and create new memories',
#  'Ami toh paarle lyf er each and every moment ta capture kore rakhtey chai... memories recapitulation is the best thing for me',
#  'Google photos ka naam suna hay ??',
#  '😌',
#  'Ota amar most valuable asset....puro lyf acche ota tey amar',
#  'Kore fel',
#  '10 years pore dekhbi',
#  'Chennai gieachilis...kichu pagol lok jon er sathe party korte',
#  '🤣🤣',
#  'Kore fel',
#  '10 years pore dekhbi',
#  'Chennai gieachilis...kichu pagol lok jon er sathe party korte',
#  '🤣🤣',
#  'Kore fel',
#  '10 years pore dekhbi',
#  'Chennai gieachilis...kichu pagol lok jon er sathe party korte',
#  '🤣🤣',
#  'Yep',
#  '😓',
#  'Talking to a friend',
#  'Talking to a friend',
#  'High hote iccha korche',
#  'Any suggestions',
#  'High hote iccha korche',
#  'Any suggestions',
#  "That's why asking for an expert opinion",
#  'Who else it could be',
#  'Other than u',
#  "That's why asking for an expert opinion",
#  'Who else it could be',
#  'Other than u',
#  'I want to fly in the sky like a bird 😘😗',
#  "That's only imagination",
#  'I want it in reality',
#  'Just imagine... flying in the sky',
#  "Wouldn't it be fun",
#  'Go wherever u want',
#  'Naaaaa',
#  'Plz bol',
#  'Plz',
#  'Pz',
#  'Plz',
#  'Plz',
#  'Plz',
#  '🙏🏻🙏🏻🙏🏻',
#  'Ami ekhon ee pakhi hobo',
#  'Eagle 😎',
#  'Jd acche',
#  'Half khali',
#  'Tui asol kothaa bol na',
#  'Ektai bottle acche',
#  'Tui bol na',
#  'Ki korte hobe',
#  'Aagun jalabo?',
#  'Bari eta re...bar noy🙈',
#  'Sudhu ekta jd acche...byass',
#  'Bol ebar',
#  'Bari eta re...bar noy🙈',
#  'Sudhu ekta jd acche...byass',
#  'Bol ebar',
#  '🤣🤣rr kost dis na',
#  'Chini ??',
#  'Chini ??',
#  'Chini???',
#  '2 peg khele toh abar jol meshate hobe jd tey',
#  '2 peg khele toh abar jol meshate hobe jd tey',
#  'Okay',
#  'Tui jokhon bole dieachis...aaj k korbo',
#  'Okay',
#  'Tui jokhon bole dieachis...aaj k korbo',
#  'Na ...ekta te amar toh kichu hobe na',
#  'Na ...ekta te amar toh kichu hobe na',
#  'Ghumiea porbe ektu pore...',
#  'Tokhon ami jege uthbo🤓',
#  'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche',
#  'Kintu kinrr kora jabe',
#  'Booze sobar opor ee',
#  'Pasher room theke oto bojha jay na...tao ekta risk factor toh acche',
#  'Kintu kinrr kora jabe',
#  'Booze sobar opor ee',
#  '???????????????????',
#  "U don't ask that",
#  '*say that',
#  '🙈🙈🙈',
#  'Maarbe naa ...etuku jani...but bishal jharbe😖',
#  'But tui chini chara onno kichu bol na',
#  'Sudhu Chini rr jonno eto ta risk nebo🤷🏻\u200d♂️',
#  'Soan papri....laddu',
#  '🤣🤣🤣🤣',
#  'Ki din eseche...',
#  '🤣🤣🤣🤣',
#  'Ki din eseche...',
#  'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣',
#  'Hya...dinner complete',
#  'Cmi te thaktey direct Glenfiddich khetam...ekhon sotti sotti quarantined🙈🤣',
#  'Hya...dinner complete',
#  'Ki kore bujhli?',
#  'Bari tey fix tym 9pm',
#  'Khetey hole khao....nahole abar kal k 😅😂',
#  'Bari tey fix tym 9pm',
#  'Khetey hole khao....nahole abar kal k 😅😂',
#  'Toder dinner done ??',
#  'Cousins acche',
#  '7 jon total',
#  'Amar saamne cupboard er moddhei acche',
#  'Guard laagbe na😅',
#  'Amar saamne cupboard er moddhei acche',
#  'Guard laagbe na😅',
#  'Amar saamne cupboard er moddhei acche',
#  'Guard laagbe na😅',
#  'Ami 3rd',
#  '🤣🤣🤣',
#  'Wait dara check korchi',
#  'Eta ekjon baba k gift korechilo....porei acche....',
#  'Duty free maal',
#  'Uncle ek somoy amar thekeo bishal passionate chilo booze niea....',
#  'Cupboard ekta compartment ta k bar baniea chilo....',
#  'Ekhon seta r obostha dekhley amar ee kharap laage😓',
#  'Biscuits Horlicks rr khali Scotch glass gulo rakha thake',
#  '🤣🤣',
#  'Dara ami jd ta check korchi',
#  'Arrey',
#  'Ki luck amar',
#  'Ki pelam dkh',
#  'I wish I could send an imgae for this!',
#  '🤤🤤😍😍',
#  'I wish I could send an imgae for this!',
#  'Goa theke kinechilo baba......ekhon monne porlo...',
#  'Local daru',
#  'Eta khele toh ami aaj rocket',
#  'Kintu poblm ektai...',
#  'Exactly',
#  'Ki coincidence',
#  'Etai bolte jacchilam',
#  '🙈🙈',
#  'Kintu poblm ektai...',
#  'Exactly',
#  'Ki coincidence',
#  'Etai bolte jacchilam',
#  '🙈🙈',
#  'Duto punch kore dbo??',
#  'Duto punch kore dbo??',
#  'Tahole toh bishmaal puro',
#  'Tahole toh bishmaal puro',
#  'Hya...seal ta opn korlam...jol misiea dilam',
#  'Hya...seal ta opn korlam...jol misiea dilam',
#  'Alcohol ee jol meshlae chap nei toh',
#  'Feni ta Goan daru',
#  'Uncle er bondhu bandhob bari tey na ele uncle khabe na....',
#  'Tao rare',
#  'Rr ekhon toh beri tey keo aasbei na',
#  'Kheyechis kono din??',
#  'Ooh...oto k bhabe',
#  'Tui bachiea dis ama k sedin🙏🏻',
#  'Feni+jd+laddu+chini',
#  'Feni+jd+laddu+chini',
#  'Ufff\U0001f92f',
#  'Raw khete hobe otai chap...smell berobe naki ??',
#  'Raw khete hobe otai chap...smell berobe naki ??',
#  'Bangla te toh smell hoy',
#  'Na na',
#  'Eta hobe na konodin',
#  'Arre uncle oo bojhe booze ki jinis😌',
#  'Arre uncle oo bojhe booze ki jinis😌',
#  'Tahole ekhon ee shuru kori naki??',
#  '😝',
#  'Ami tor arr w8 korte parchi na',
#  'Ami tor arr w8 korte parchi na',
#  '🤤🤤',
#  'Koto w8 korabi',
#  '10 ta baaje',
#  'Jd ta ek dhok maarbo...trpor feni ta ek dhok',
#  'Na na',
#  'Pagol naki',
#  'Ok bolis na...',
#  'Na na bolbe abar',
#  'Hurr',
#  'Hurr',
#  'Arrey...tui sudhu dekhtey thak...',
#  'Amar game',
#  'Aaj k kaju feni rr party hobe',
#  'Arrey...tui sudhu dekhtey thak...',
#  'Amar game',
#  'Aaj k kaju feni rr party hobe',
#  'Ami idea peye gechi',
#  'Bottle tai gayeb kore debo',
#  'Ami idea peye gechi',
#  'Bottle tai gayeb kore debo',
#  'Bujhtei paarbe na🤣🤣',
#  '😓 emotional blackmail😖😖',
#  'Ki naa???',
#  'Eita toh bhalo idea ??',
#  '😓 emotional blackmail😖😖',
#  'Ki naa???',
#  'Eita toh bhalo idea ??',
#  'Tahole ki ami pakhi hotte parbo na',
#  'Keno...??',
#  'Full proof',
#  'Tahole ki ami pakhi hotte parbo na',
#  'Keno...??',
#  'Full proof',
#  'Baba bhuleo geche j Orom kichu ekta chilo...just like amio bhule gechilam',
#  'Hya ...ota toh rr oo moja😁😁🤤',
#  'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe',
#  'Ok...no poblm...ami kheye video call korchi...but aaste aaste kotha bolte hobe',
#  'Arre tui chap nicchis keno...chill',
#  'Arre tui chap nicchis keno...chill',
#  'Arre tui chap nicchis keno...chill',
#  'Kichu hobe na',
#  'Chap nis na',
#  'Chilll',
#  'Chill',
#  'Se toh hobei',
#  'Taintoh bolchi',
#  'Video call korbo ami',
#  'Ok',
#  'Sobai jege thakbe',
#  '😁😁😁😁😁',
#  'Wah wah',
#  'Aaj may udega🤤',
#  'Chill',
#  'Chill',
#  'Just w8 & watch',
#  'I wish I could send an imgae for this!',
#  "It's going to drop soon😆",
#  'Chill',
#  'Chill',
#  'Just w8 & watch',
#  'I wish I could send an imgae for this!',
#  "It's going to drop soon😆",
#  'Still waiting for ur permission😓',
#  'I wish I could send an imgae for this!',
#  'Khulbo???',
#  'Plz??',
#  'Still waiting for ur permission😓',
#  'I wish I could send an imgae for this!',
#  'Khulbo???',
#  'Plz??',
#  'Keno?????????????????',
#  'Keno ???',
#  'Agge bol keno????????',
#  'Why',
#  '????',
#  'Keno?????????????????',
#  'Keno ???',
#  'Agge bol keno????????',
#  'Why',
#  '????',
#  'Keno?????????????????',
#  'Keno ???',
#  'Agge bol keno????????',
#  'Why',
#  '????',
#  'Subho kaaj ee deri keno???',
#  'Done ami wait korchi till 10:30',
#  'Trpor kintu ek dhok ee direct eto ta namabo',
#  'I wish I could send an imgae for this!',
#  '🤤🤤🤤🤤',
#  'Subho kaaj ee deri keno???',
#  'Done ami wait korchi till 10:30',
#  'Trpor kintu ek dhok ee direct eto ta namabo',
#  'I wish I could send an imgae for this!',
#  '🤤🤤🤤🤤',
#  'Bhai maaro mujhe maaro',
#  'Dhak dhak...hocche amar',
#  'Wai ekhon keno???',
#  'Ei toh bolli 10:30',
#  'Wai',
#  'Let me enjoy the moment',
#  'Let me enjoy the moment',
#  'Mood aasbe emon ekta gaan bol',
#  'Ooh peyechi',
#  'Tor favourite song',
#  'Ritviz',
#  'Mood aasbe emon ekta gaan bol',
#  'Ooh peyechi',
#  'Tor favourite song',
#  'Ritviz',
#  "It's already dimmed",
#  "It's already dimmed",
#  "It's already dimmed",
#  'Na na bol konta chalabo',
#  'Na na bol konta chalabo',
#  'Ami toh bhablam...chalo chalei',
#  'Ami toh bhablam...chalo chalei',
#  'Konta chalabo?? Ritviz naki dim the lights',
#  'Ritviz toh sune sune heziea geche',
#  'Dim the lights ee chalai',
#  'Ritviz toh sune sune heziea geche',
#  'Dim the lights ee chalai',
#  'Ei toh bolli',
#  '???',
#  'Ota ki gaan chilo na??',
#  'Seriously???',
#  '🙈🙈🙈',
#  'Amio prothom ee tai bhablam......',
#  'Seriously',
#  'Porre tui bolli eta',
#  'Amio prothom ee tai bhablam......',
#  'Seriously',
#  'Porre tui bolli eta',
#  'Tai ami bhablam..ota seriously kono gaan',
#  'I wish I could send an imgae for this!',
#  'Ei toh...dim the lights',
#  'Ki ????????',
#  'Hey bhogoban🙈',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Mood chole elo re',
#  'Puro full mood',
#  'Etai chaichilam',
#  'Khaini ekhono monne acche',
#  'Feelings tai toh ashol',
#  'Moments guloi toh ashol',
#  'Booze toh just puro process ta k fast koree...rr ki',
#  'My eyes on the clock',
#  '\U0001f9d0',
#  '😖😖😖😖',
#  '😩😩😩😫😫',
#  'Tule nao',
#  'Ama k tule nao',
#  'I wish I could send an imgae for this!',
#  'Party mood on',
#  'I wish I could send an imgae for this!',
#  'Timestamp 10:29',
#  "Let's start",
#  'I wish I could send an imgae for this!',
#  'Ki kopal amar',
#  'Seal siddhi khule gelo',
#  'I wish I could send an imgae for this!',
#  'Ki kopal amar',
#  'Seal siddhi khule gelo',
#  'I wish I could send an imgae for this!',
#  'Ki kopal amar',
#  'Seal siddhi khule gelo',
#  '😂😂😂😂',
#  'I wish I could send an imgae for this!',
#  'Byass rr chap nei....abar lagiea debo🤣🤣🤣🤣',
#  'Bishal smell',
#  '\U0001f92e\U0001f92e',
#  'Khaini ekhono',
#  'Bish puro',
#  'Bish',
#  'Beche thakbo toh',
#  'Jai hok...bolechi jokhon ...khetey toh hobei',
#  'Nna na a',
#  'Na na',
#  'Aaj k etai khabo',
#  '\U0001f92e\U0001f92e🤢',
#  'Ki jali',
#  'Jali rr jali',
#  '\U0001f92e\U0001f92e🤢',
#  'Ki jali',
#  'Jali rr jali',
#  '\U0001f92e\U0001f92e🤢',
#  'Ki jali',
#  'Jali rr jali',
#  'I wish I could send an imgae for this!',
#  'Puro jali\U0001f92e\U0001f92e',
#  'Mukher bhetor ta jole gelo\U0001f92e',
#  'Hmm.',
#  'Thank u so much',
#  'Monne koranor jonno',
#  'Thank u so much',
#  'Monne koranor jonno',
#  'Thank u so much',
#  'Monne koranor jonno',
#  'Monne hocche....petrol kheye nieachi😖',
#  'Monne hocche....petrol kheye nieachi😖',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Done and dusted',
#  '5 mins por rr ek dhok khabo...asha korchi kaaj hoye jabe',
#  'I wish I could send an imgae for this!',
#  'Done and dusted',
#  '5 mins por rr ek dhok khabo...asha korchi kaaj hoye jabe',
#  'Duto khelam kintu',
#  'Duto khelam kintu',
#  'Hobe toh botel....60moto kheyechi...tao abar...desi daru',
#  '😁😁😁😁',
#  '😁😁😁😁',
#  'Ki moja',
#  'Ki moja',
#  'Kichu measure lekha nei',
#  'Kintu bishmall puro',
#  'Ki bolbo',
#  'Issh',
#  'Arrey lovely',
#  '😍',
#  'Hote parre',
#  'Ac chalai...gorom gorom laagche kintu halka halka',
#  '60 neat desi daru',
#  '😁😁😁',
#  '😁😁😁',
#  '😁😁😁',
#  '😁😁😁',
#  'Ki moja',
#  'Thank u so much',
#  'Idea tar jonno...',
#  'Jd khele kichui hoto na....bekar',
#  'Ei sob quarantine er din e desi daru chai',
#  'Mukher taste ta kemon change change hoye gelo....',
#  'Jd khujtey giea ee toh....asol maal ta pelam',
#  'Mukher taste ta kemon change change hoye gelo....',
#  'Jd khujtey giea ee toh....asol maal ta pelam',
#  'Mukher taste ta kemon change change hoye gelo....',
#  'Jd khujtey giea ee toh....asol maal ta pelam',
#  'Hidden gem\U0001f92d',
#  'Na na...kemon burnt taste',
#  'Sob korbo',
#  'Bol sudhu tui',
#  'Bol',
#  'Bol',
#  'Bole fel',
#  'Hoye jak',
#  'Aaj k',
#  'Bolei fel',
#  'Hok',
#  'Hok',
#  'Aaj k hok',
#  '😍😍😍😍😍😍😍😍😍😍😍😍😝😝😝😝😝😝😝😝😝😝😝😍😍😍😍',
#  'Ki idea re',
#  'Sabas',
#  'Sabas',
#  'Ekhhuni korchi',
#  'Ooooooooooooooooooooooo',
#  'Ki dili',
#  'Ooooooooooooooooooooooo',
#  'Ki dili',
#  'Pagol hoye jabo amo',
#  'Puro bishmaal',
#  'Rr oo bol',
#  'Ami Bonobo Kerala chalacchi',
#  'Ami Bonobo Kerala chalacchi',
#  'Mood',
#  'Mood',
#  '😍',
#  'Neck trick ta darun chilo',
#  'Just sera',
#  '😘😘😘',
#  'Pagol puro',
#  '🤤🤤🤤',
#  'Iss',
#  '🤤🤤🤤',
#  'Iss',
#  'Isshhhhhhh',
#  'R ekbar',
#  'Nahole puro ta mati hoye jabe',
#  'Ekhon just...peak hocche',
#  'Halka aasche',
#  'Halka',
#  'Just halka',
#  'Ami gems khacchi\U0001f92d\U0001f92d',
#  'I wish I could send an imgae for this!',
#  'Na na smell ta katatey hobe',
#  'Rr chocolate to process ta k enhance oo korbe',
#  '😁😁😁😁😁😁',
#  '😁😁😁😁😁😁',
#  '😁😁😁😁😁😁',
#  '😁😁😁😁😁😁',
#  '😁😁😁😁😁😁',
#  'Gems khacchi',
#  'Cadbury gems',
#  'Kire',
#  'Gems khasni konodin',
#  '😁😁😁😁😁😁',
#  '😁😁😁😁😁',
#  '😁😁😁😁😁',
#  '😁😁😁😁😁',
#  'Gems rrr oo achhe',
#  '2nd peg tar por khabo abar',
#  'Gems rrr oo achhe',
#  '2nd peg tar por khabo abar',
#  'Ami sober thakte thakte ekta kotha bol',
#  'Ami sober thakte thakte ekta kotha bol',
#  'Ami toh rr ekta peg maarbo',
#  'I wish I could send an imgae for this!',
#  'Ok??',
#  'I wish I could send an imgae for this!',
#  'Ok??',
#  'Ok ok',
#  'Shon ebar',
#  'Ebar ami eta tey jodi jol misiea di',
#  'Tahole jinis ta nosto hoye jabe na toh???',
#  'Becoz ami half bottle ta rakhte parbo na',
#  'PLZZ plz',
#  'Bol',
#  'Ama k shei moto plan korte hobe...',
#  'Nahole aaj kei sesh kore bottle ta fele debo',
#  'Bag ta dhuye dieache maa...bag nei amar ekhon',
#  'Bag ta dhuye dieache maa...bag nei amar ekhon',
#  'Bag ta dhuye dieache maa...bag nei amar ekhon',
#  'Bag ta dhuye dieache maa...bag nei amar ekhon',
#  'Bottle ta jekhanee chilo okhanei rakhte hobe',
#  'Jol mesano jay kinna bol',
#  'Ami eta next 2 -3 te sitting ee sesh kore debo',
#  'Ami eta next 2 -3 te sitting ee sesh kore debo',
#  'In that case porer sitting gulo ektu diluted hobe',
#  'Na keno',
#  'Bollam toh ek peg',
#  'Locker ee k rakhe...chabi ber korte gelei dhora porbo',
#  'Ekhon abar filter chalatey hobe????',
#  '😫',
#  'Emni jol  ??',
#  'Locker ee k rakhe...chabi ber korte gelei dhora porbo',
#  'Ekhon abar filter chalatey hobe????',
#  '😫',
#  'Emni jol  ??',
#  'Oh hya...same ee toh...tahole ki chap',
#  'Oh hya...same ee toh...tahole ki chap',
#  'Ok tahole ota sorted',
#  'Notun problem.',
#  'Smell ta ki korbo???',
#  'Rr ek peg khele bishal smell berobo😓',
#  'Seta ami jani😌',
#  'Seta ami jani😌',
#  'Seta ami jani😌',
#  'Mukh theke smell aasche....jali smell...petrol er moto😥',
#  '😮😮😮',
#  'Ki idea',
#  '👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻',
#  '👏🏻👏🏻👏🏻👏🏻👏🏻',
#  'Haldirams bhujia',
#  'Acche',
#  'Ooh....rr oo bhalo jinis acche 😍',
#  'Ooh....rr oo bhalo jinis acche 😍',
#  'I wish I could send an imgae for this!',
#  '😁😁😁',
#  'Uff',
#  'Ki mood😍😍😍',
#  'Jemon jemon???',
#  'Jemon jemon???',
#  '🤣🤣🤣',
#  '1.Neck trick 2. Laddu 3. Chocolate 4. Ritviz 5. Chakhna',
#  '🤣🤣🤣',
#  '1.Neck trick 2. Laddu 3. Chocolate 4. Ritviz 5. Chakhna',
#  'Ebaba...papad ta toh jhal',
#  'Ami khacchi keno😥',
#  'Fele dieachi😒',
#  'R khabo ma',
#  '*na',
#  'R khabo ma',
#  '*na',
#  'R khabo ma',
#  '*na',
#  'Halka j jinis ta esechilo....abar kintu shey cholle jacche😥',
#  'Taake aatkabo ki kore ??',
#  'Eto joldi...tahole toh party sesh 🙈',
#  'Ota ami last er jonno bachiea rakhtey chai',
#  'Right',
#  'Eto joldi...tahole toh party sesh 🙈',
#  'Ota ami last er jonno bachiea rakhtey chai',
#  'Right',
#  'Eto joldi...tahole toh party sesh 🙈',
#  'Ota ami last er jonno bachiea rakhtey chai',
#  'Right',
#  'With sage',
#  'Naa 😭😭',
#  'Arre dhur',
#  'Arre dhur',
#  'Neck trick ta rr kaaj korche na',
#  '😭',
#  'Eta teo resistance chole elo naki🙈',
#  'Naaaqaaaa',
#  'Naaaqaqq',
#  'Nananaanann',
#  'Nana',
#  'Naan',
#  'Jeet sunchi',
#  'Rr chobi dekchi...',
#  'Jodi kichu hoy😓',
#  'Chill',
#  'Chap nei',
#  'Neme geche puro ta...abar khela start korte hobe',
#  'Khela hobe aaj k...',
#  'Ekta jinis bujhlam',
#  'Bishal jol teshta pacche...',
#  'Dehydration hobe marattok',
#  'Chill',
#  'Chap nei',
#  'Neme geche puro ta...abar khela start korte hobe',
#  'Khela hobe aaj k...',
#  'Ekta jinis bujhlam',
#  'Bishal jol teshta pacche...',
#  'Dehydration hobe marattok',
#  'Chill',
#  'Chap nei',
#  'Neme geche puro ta...abar khela start korte hobe',
#  'Khela hobe aaj k...',
#  'Ekta jinis bujhlam',
#  'Bishal jol teshta pacche...',
#  'Dehydration hobe marattok',
#  'Rr oo ek bottle jol laagbe raat e',
#  'Last 30 min ee 1l jol khelam',
#  'Smell chole geche',
#  'Mood tao',
#  'I wish I could send an imgae for this!',
#  'Chalalam...',
#  'Asha kori mood aasbe',
#  'Kokhon maarbo bol next peg ta ???',
#  'Optimised ekta time bol',
#  '😮😮',
#  'Iccha nei...but monne hocche otai best hobe',
#  '😮😮',
#  'Iccha nei...but monne hocche otai best hobe',
#  'Sotti...salute to ur experience and suggestions',
#  'Wait korar iccha nei😒',
#  'Khawar iccha thakbena....ki bolis',
#  'Na na 12...',
#  "Don't negotiate",
#  'Ami nijeke control korchi',
#  'Help kor',
#  'Khawar iccha thakbena....ki bolis',
#  'Na na 12...',
#  "Don't negotiate",
#  'Ami nijeke control korchi',
#  'Help kor',
#  'Tui toh control bhenge dicchis',
#  'But ekta notul problem fell korchi',
#  'Ok...sure ....ekdom',
#  'Na na..ota porre. Ek din hobbe ..aaj na🙏🏻',
#  'Bole fel....',
#  'Tui toh guess korte paris',
#  "Let's c",
#  'Na na..ota porre. Ek din hobbe ..aaj na🙏🏻',
#  'Bole fel....',
#  'Tui toh guess korte paris',
#  "Let's c",
#  'Halka feel korchi',
#  'Na na....gorom er problem solved',
#  'Na na....ami ki kiddo naki😒',
#  'Ektu holeo experience acche',
#  'Naaaaaaaaaaaaa',
#  'Trina kiddo',
#  'Ami na',
#  'Seta alada byapar',
#  'But ami booze kiddo na',
#  'Ami booze pro',
#  'Agge gaan bol',
#  'Peye gechi',
#  'In lamho k daman mey',
#  'Bol tui bol',
#  'Dekhi guessing power',
#  'Buring🔥 halka',
#  'Mild',
#  'But acche',
#  'Persistence',
#  'Heart ee onk niche.... intestine er kache',
#  'Heart is fit',
#  'Orebaba',
#  'Eita ki game',
#  'Antacid khujtey gele ekhon abar bawal hobe...ota amar room ee nei🙈',
#  'Jigges korbe...ki hoyeche...keno kiser jonno',
#  'I wish I could send an imgae for this!',
#  'Major missing....',
#  'Oidin dokan ta tey giea amar mood ese gechilo😍',
#  'Hay re hay',
#  'Hay re hay',
#  'Mast magan',
#  'Ekhon rr bole ki hobe',
#  'Sesh hoye gelo',
#  'Bonobo type er kichu bol na...',
#  'Music video ja kichu',
#  'Mood ta halka fire pelam abar',
#  'Purono prem er moto',
#  'Aha😍',
#  'Hurr',
#  'Ekta darun jinis dekhlam....',
#  'Hurr',
#  'Ekta darun jinis dekhlam....',
#  'Just dkh eta',
#  'Ekbatmr',
#  'Plzzz',
#  'Ekbar',
#  '2 min at lest dkh',
#  'Puro pagol hoye jabi',
#  'Use headphone',
#  'Sound ta besi rrakis',
#  'https://youtu.be/ebzEEEdjHj0',
#  'Plzzz',
#  'Dkh',
#  'Puro out',
#  'Poro',
#  'Ami abar dekhchi',
#  '😁',
#  'Maza aa gaya',
#  '6 mins',
#  'Trpor',
#  'May udega',
#  "I'll fly",
#  'May udega',
#  "I'll fly",
#  'In the sky',
#  'Just to take off',
#  'Boarding complete',
#  'Kripya apna seat belt baandh ley',
#  'Kursi sidhe rakhe',
#  'Kripya apna seat belt baandh ley',
#  'Kursi sidhe rakhe',
#  'Hawa ka dawao kaam ho ne par mask pehene',
#  'Udan k samay apna saman uper k cabin pe rakhe',
#  'Indigo ke sath safar kar ne k liea aap k abhar',
#  'Aap ki safar subh ho',
#  'Hi ..this is subhasish your captain',
#  'With me there is Trisha co-pilot',
#  'We are going to hell',
#  'Travel time is 2 mins',
#  '🙃',
#  '🙂',
#  'Ei dutor difference ki??',
#  'Eta ki holo',
#  'Flight delay keno???',
#  'Keno??',
#  'Ulto keno',
#  'Eta ki holo',
#  'Flight delay keno???',
#  'Keno??',
#  'Ulto keno',
#  'Na ...erom korle hobena',
#  'Passenger ta rege jabe toh',
#  '1 min',
#  'Nana....',
#  'Ami eka chalatey parbo na',
#  'Accident hoye jabe',
#  '😫',
#  'Apatkalin stithi k karan hamara biman kuch deri se udega',
#  'Asubidha k liea khed hay',
#  'Korchi toh',
#  'Amar obostha ta bojh',
#  'Accelerator ee paa diea boshe acchi',
#  'Bollei full race',
#  '12:01 it is',
#  'Apatkalin stithi k karan hamara biman kuch deri se udega',
#  'Asubidha k liea khed hay',
#  'Korchi toh',
#  'Amar obostha ta bojh',
#  'Accelerator ee paa diea boshe acchi',
#  'Bollei full race',
#  '12:01 it is',
#  'Tab tak aap Indigo ke hello 6e magazine se aapne liea merchandise ka chayan kar sakte hay',
#  'Kuch der baad hum jal pan ka seva shuru karenge',
#  'BUT FOR THAT LET ME FLY',
#  'Aaj rr nei',
#  "It's already tomorrow",
#  '28th March it is',
#  'Whta well',
#  'Not well',
#  'Paa byatha korche amar',
#  'Cheating eta...',
#  'Booze ee din count hoy na',
#  'Sitting count hoy',
#  '1 sitting',
#  "That's it",
#  'Yep yep',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'R 5 mins',
#  'Ohh',
#  'What a coincidence',
#  '🤣🤣',
#  'Na na',
#  'Kichu ekta hocche',
#  'Accha agey suru hok. Tarpor dekhchi',
#  'R 5 mins',
#  'Ohh',
#  'What a coincidence',
#  '🤣🤣',
#  'Na na',
#  'Kichu ekta hocche',
#  'Ami laptop ee headphone connect kore gaan sunchi....but phone er volume button diea ta change korchi',
#  'Eta ki imply kore',
#  'I am above the ground 🤔??',
#  'Am o',
#  'Am i',
#  'Mujhe kis kis ne kya kya kaha ???',
#  'Ud kar char kar swet pavan ko',
#  'Oh yes',
#  'Naki eta sopno',
#  'Ritviz toh acchei',
#  'Aaae aaae aaee aaeee',
#  'Aaaaeee aaaaeee aaaeeee',
#  'Ami laptop ee headphone connect kore gaan sunchi....but phone er volume button diea ta change korchi',
#  'Eta ki imply kore',
#  'I am above the ground 🤔??',
#  'Am o',
#  'Am i',
#  'Mujhe kis kis ne kya kya kaha ???',
#  'Ud kar char kar swet pavan ko',
#  'Oh yes',
#  'Naki eta sopno',
#  'Ritviz toh acchei',
#  'Aaae aaae aaee aaeee',
#  'Aaaaeee aaaaeee aaaeeee',
#  'Chalo chale',
#  'Nil gagan ko',
#  '😮',
#  'Eto joldi',
#  'Start strat',
#  '😮',
#  'Eto joldi',
#  'Start strat',
#  'I wish I could send an imgae for this!',
#  'Back to normal',
#  '😁😁😁',
#  'I wish I could send an imgae for this!',
#  'Back to normal',
#  '😁😁😁',
#  'Ohh',
#  'Bhule gechi',
#  'Rr ekta laadu kheye nilam',
#  'Bottle dhukiea dieachi',
#  'Ohh',
#  'Bhule gechi',
#  'Rr ekta laadu kheye nilam',
#  'Bottle dhukiea dieachi',
#  'Na na',
#  'Na na',
#  'Bujhe gechi',
#  'I wish I could send an imgae for this!',
#  'I wish I could send an imgae for this!',
#  'Ebar ekta Bonobo dekhbo.....trpor neck trick',
#  'Chole eseche',
#  'Matha Jhim jhim',
#  'Raw alcohol bolle kotha....asbe na maane...oor baap aasbe',
#  'Ja cheyechi',
#  'Tai peyechi',
#  ...]
